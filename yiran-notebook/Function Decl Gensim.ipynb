# %%
# imports and setup
import json
from itertools import islice, imap

# %% [markdown]
# ## Helper Functions

# %%
def parse_ast_line(line, sep="\t"):
    script_id, ast_json = line.strip().split(sep, 1)
    return script_id, json.loads(ast_json)
      
def parse_ast(lines):
    for line in lines:
        if len(line) > 1:
            yield parse_ast_line(line)
            
def filter_ast_by_type(ast, type):
    if _is_node_of_type(ast, type):
        yield ast
    elif isinstance(ast, dict):
        for _, val in ast.iteritems():
            for x in filter_ast_by_type(val, type):
                yield x
    elif isinstance(ast, list):
        for val in ast:
            for x in filter_ast_by_type(val, type):
                yield x
      
def _is_node_of_type(d, type):
    return isinstance(d, dict) and \
           "type" in d and \
           d["type"] == type

# %% [markdown]
# ## Filter AST nodes with type of Identifier
#
# Here, try one program, and print out all its identifiers.

# %%
AST_FILE = '../lang/ast.json11'

with open(AST_FILE, 'r') as f:
    _, one_program = parse_ast(f.readlines()).next()

# %%
list(filter_ast_by_type(one_program, "Identifier"))[:10]
# Out:
# [{u'name': u'Number', u'type': u'Identifier'},
#  {u'name': u'$n', u'type': u'Identifier'},
#  {u'name': u'$n', u'type': u'Identifier'},
#  {u'name': u'locale', u'type': u'Identifier'},
#  {u'name': u'Drupal', u'type': u'Identifier'},
#  {u'name': u'renderItem', u'type': u'Identifier'},
#  {u'name': u'apachesolr_autocomplete', u'type': u'Identifier'},
#  {u'name': u'Drupal', u'type': u'Identifier'},
#  {u'name': u'_renderItem', u'type': u'Identifier'},
#  {u'name': u'data', u'type': u'Identifier'}]

# %% [markdown]
# ## Naive word2vec
#
# Use identifier names as vocabulary.

# %%
def load_sentences(filename, sentences):
    with open(filename, 'r') as f:
        for _, program in parse_ast(f.readlines()):
            sentence = filter_ast_by_type(program, type="Identifier")
            sentence = list( imap(lambda d:d["name"], sentence) )
            sentences.append(sentence)
    return sentences

# %%
import sys
paths = ['/home/yiran/.local/lib/python2.7/site-packages/PyOpenGL-3.0.1-py2.7.egg', '/home/yiran/.local/lib/python2.7/site-packages/ftputil-3.2-py2.7.egg', '/home/yiran/anaconda/lib/python27.zip', '/home/yiran/anaconda/lib/python2.7', '/home/yiran/anaconda/lib/python2.7/plat-linux2', '/home/yiran/anaconda/lib/python2.7/lib-tk', '/home/yiran/anaconda/lib/python2.7/lib-old', '/home/yiran/anaconda/lib/python2.7/lib-dynload', '/home/yiran/.local/lib/python2.7/site-packages', '/home/yiran/anaconda/lib/python2.7/site-packages/Sphinx-1.3.5-py2.7.egg', '/home/yiran/anaconda/lib/python2.7/site-packages/setuptools-19.6.2-py2.7.egg', '/home/yiran/anaconda/lib/python2.7/site-packages', '/home/yiran/anaconda/lib/python2.7/site-packages/cryptography-1.0.2-py2.7-linux-x86_64.egg']
for p in paths:
    sys.path.insert(0, p)

# %%
from gensim.models.word2vec import Word2Vec
import glob

# %%
sentences = []
for f in glob.glob("../lang/ast.json*"):
    print ("Loading %s" % f)
    load_sentences(f, sentences)
# Out:
# Loading ../lang/ast.json26
# Loading ../lang/ast.json45
# Loading ../lang/ast.json40
# Loading ../lang/ast.json36
# Loading ../lang/ast.json18
# Loading ../lang/ast.json02
# Loading ../lang/ast.json38
# Loading ../lang/ast.json47
# Loading ../lang/ast.json53
# Loading ../lang/ast.json66
# Loading ../lang/ast.json72
# Loading ../lang/ast.json04
# Loading ../lang/ast.json48
# Loading ../lang/ast.json65
# Loading ../lang/ast.json64
# Loading ../lang/ast.json49
# Loading ../lang/ast.json33
# Loading ../lang/ast.json30
# Loading ../lang/ast.json10
# Loading ../lang/ast.json51
# Loading ../lang/ast.json60
# Loading ../lang/ast.json31
# Loading ../lang/ast.json34
# Loading ../lang/ast.json75
# Loading ../lang/ast.json43
# Loading ../lang/ast.json73
# Loading ../lang/ast.json57
# Loading ../lang/ast.json14
# Loading ../lang/ast.json42
# Loading ../lang/ast.json08
# Loading ../lang/ast.json76
# Loading ../lang/ast.json63
# Loading ../lang/ast.json23
# Loading ../lang/ast.json71
# Loading ../lang/ast.json07
# Loading ../lang/ast.json50
# Loading ../lang/ast.json25
# Loading ../lang/ast.json39
# Loading ../lang/ast.json16
# Loading ../lang/ast.json28
# Loading ../lang/ast.json69
# Loading ../lang/ast.json74
# Loading ../lang/ast.json20
# Loading ../lang/ast.json13
# Loading ../lang/ast.json15
# Loading ../lang/ast.json70
# Loading ../lang/ast.json22
# Loading ../lang/ast.json05
# Loading ../lang/ast.json29
# Loading ../lang/ast.json32
# Loading ../lang/ast.json67
# Loading ../lang/ast.json21
# Loading ../lang/ast.json62
# Loading ../lang/ast.json27
# Loading ../lang/ast.json68
# Loading ../lang/ast.json61
# Loading ../lang/ast.json59
# Loading ../lang/ast.json35
# Loading ../lang/ast.json46
# Loading ../lang/ast.json58
# Loading ../lang/ast.json06
# Loading ../lang/ast.json00
# Loading ../lang/ast.json56
# Loading ../lang/ast.json19
# Loading ../lang/ast.json44
# Loading ../lang/ast.json09
# Loading ../lang/ast.json01
# Loading ../lang/ast.json54
# Loading ../lang/ast.json55
# Loading ../lang/ast.json03
# Loading ../lang/ast.json12
# Loading ../lang/ast.json41
# Loading ../lang/ast.json37
# Loading ../lang/ast.json17
# Loading ../lang/ast.json52
# Loading ../lang/ast.json11
# Loading ../lang/ast.json24

# %%
model = Word2Vec(sentences, size=100, window=5, min_count=5, workers=4)

# %%
model.vocab
# Out:
# {u'buttonOptions': <gensim.models.word2vec.Vocab at 0x7f641497d8d0>,
#  u'_jQuery': <gensim.models.word2vec.Vocab at 0x7f641497d910>,
#  u'sending2': <gensim.models.word2vec.Vocab at 0x7f63b324da50>,
#  u'show_description': <gensim.models.word2vec.Vocab at 0x7f63b274ba50>,
#  u'median_corrected': <gensim.models.word2vec.Vocab at 0x7f63f4877e90>,
#  u'$prevHtml': <gensim.models.word2vec.Vocab at 0x7f63fac194d0>,
#  u'endCh': <gensim.models.word2vec.Vocab at 0x7f63f4877ed0>,
#  u'fallbackNS': <gensim.models.word2vec.Vocab at 0x7f63fac19410>,
#  u'serviceFlag': <gensim.models.word2vec.Vocab at 0x7f63b30d84d0>,
#  u'mailAgence': <gensim.models.word2vec.Vocab at 0x7f63fac19110>,
#  u'hanging': <gensim.models.word2vec.Vocab at 0x7f63f4877f10>,
#  u'_show_authy': <gensim.models.word2vec.Vocab at 0x7f63f4877f50>,
#  u'myToggleClass': <gensim.models.word2vec.Vocab at 0x7f63c09a85d0>,
#  u'isLogged': <gensim.models.word2vec.Vocab at 0x7f63cf96a350>,
#  u'localized': <gensim.models.word2vec.Vocab at 0x7f640b7c8090>,
#  u'enableBackground': <gensim.models.word2vec.Vocab at 0x7f63f4877fd0>,
#  u'file_owners': <gensim.models.word2vec.Vocab at 0x7f63f4877e10>,
#  u'clearForm': <gensim.models.word2vec.Vocab at 0x7f63c2b0af90>,
#  u'_inherits': <gensim.models.word2vec.Vocab at 0x7f63b274bd90>,
#  u'forcePost': <gensim.models.word2vec.Vocab at 0x7f63b324d110>,
#  u'navNextVisible': <gensim.models.word2vec.Vocab at 0x7f63b324de50>,
#  u'isDebugUnsafe': <gensim.models.word2vec.Vocab at 0x7f63f70e5090>,
#  u'opener': <gensim.models.word2vec.Vocab at 0x7f63f70e50d0>,
#  u'gaa': <gensim.models.word2vec.Vocab at 0x7f63cf96a410>,
#  u'_show_validation_errors': <gensim.models.word2vec.Vocab at 0x7f63b324db50>,
#  u'scrollSpeed': <gensim.models.word2vec.Vocab at 0x7f63b19f6590>,
#  u'eX': <gensim.models.word2vec.Vocab at 0x7f63b274ba10>,
#  u'_applicator': <gensim.models.word2vec.Vocab at 0x7f63cc5cb390>,
#  u'padZeroes': <gensim.models.word2vec.Vocab at 0x7f63b2eeb950>,
#  u'isRestricted': <gensim.models.word2vec.Vocab at 0x7f63b4bcba10>,
#  u'DEFAULT_INFLOW': <gensim.models.word2vec.Vocab at 0x7f63c87c2f50>,
#  u'relatedArticleLimit': <gensim.models.word2vec.Vocab at 0x7f63f70e5110>,
#  u'replaces': <gensim.models.word2vec.Vocab at 0x7f63cf96a490>,
#  u'eT': <gensim.models.word2vec.Vocab at 0x7f63f70e5150>,
#  u'getLineHeight': <gensim.models.word2vec.Vocab at 0x7f63b324d710>,
#  u'twoWayBindings': <gensim.models.word2vec.Vocab at 0x7f63b324db90>,
#  u'AjaxLoadMore': <gensim.models.word2vec.Vocab at 0x7f63f70e51d0>,
#  u'_defaultFlashCreativeRenderer': <gensim.models.word2vec.Vocab at 0x7f63b2e16610>,
#  u'enddate': <gensim.models.word2vec.Vocab at 0x7f63f70e5210>,
#  u'loadEventBefore': <gensim.models.word2vec.Vocab at 0x7f63b30d87d0>,
#  u'html5video': <gensim.models.word2vec.Vocab at 0x7f63b3020050>,
#  u'createElementNSPlus': <gensim.models.word2vec.Vocab at 0x7f63b5799e10>,
#  u'embStr': <gensim.models.word2vec.Vocab at 0x7f63f70e5290>,
#  u'CommandEventArgs': <gensim.models.word2vec.Vocab at 0x7f63b30d81d0>,
#  u'registerCallback': <gensim.models.word2vec.Vocab at 0x7f63ad419b10>,
#  u'topEncrypted': <gensim.models.word2vec.Vocab at 0x7f63f70e52d0>,
#  u'_isFetched': <gensim.models.word2vec.Vocab at 0x7f63b5799e50>,
#  u'nullProps': <gensim.models.word2vec.Vocab at 0x7f63b30d8390>,
#  u'Transitions': <gensim.models.word2vec.Vocab at 0x7f63f70e5310>,
#  u'breakingTimestamp': <gensim.models.word2vec.Vocab at 0x7f63f70e5350>,
#  u'dynamicInsertion': <gensim.models.word2vec.Vocab at 0x7f63b30d8510>,
#  u'vBe': <gensim.models.word2vec.Vocab at 0x7f63b30d88d0>,
#  u'vBd': <gensim.models.word2vec.Vocab at 0x7f63b30d8350>,
#  u'$ChatproxyPresence3': <gensim.models.word2vec.Vocab at 0x7f63f70e53d0>,
#  u'error_': <gensim.models.word2vec.Vocab at 0x7f63f70e5410>,
#  u'hasVirtualBinding': <gensim.models.word2vec.Vocab at 0x7f63b30d8e90>,
#  u'incoming_call_window_busy': <gensim.models.word2vec.Vocab at 0x7f63f70e5450>,
#  u'user_callback': <gensim.models.word2vec.Vocab at 0x7f63b30d8bd0>,
#  u'SEARCH_CLEARED': <gensim.models.word2vec.Vocab at 0x7f63f70e5490>,
#  u'dropdown_config': <gensim.models.word2vec.Vocab at 0x7f63f70e54d0>,
#  u'VscaSafe': <gensim.models.word2vec.Vocab at 0x7f63b30d8fd0>,
#  u'setupFirstPlay': <gensim.models.word2vec.Vocab at 0x7f63f4877f90>,
#  u'ys_count': <gensim.models.word2vec.Vocab at 0x7f63b23fda90>,
#  u'$addTargetPageParams': <gensim.models.word2vec.Vocab at 0x7f63b30d8dd0>,
#  u'getRawResponseBySize': <gensim.models.word2vec.Vocab at 0x7f63b30d8150>,
#  u'moveCursorRight': <gensim.models.word2vec.Vocab at 0x7f63f70e55d0>,
#  u'isWriteBanned': <gensim.models.word2vec.Vocab at 0x7f63f70e5610>,
#  u'_viewType': <gensim.models.word2vec.Vocab at 0x7f6415823190>,
#  u'b_creator': <gensim.models.word2vec.Vocab at 0x7f63b2dc7150>,
#  u'defQueueMap': <gensim.models.word2vec.Vocab at 0x7f63b8582cd0>,
#  u'resetViewport_': <gensim.models.word2vec.Vocab at 0x7f63f70e5690>,
#  u'rollupItems': <gensim.models.word2vec.Vocab at 0x7f63f70e56d0>,
#  u'lmq': <gensim.models.word2vec.Vocab at 0x7f63b6dac550>,
#  u'numeral': <gensim.models.word2vec.Vocab at 0x7f63b8582810>,
#  u'BaseStyle': <gensim.models.word2vec.Vocab at 0x7f63b8e317d0>,
#  u'playWrapper': <gensim.models.word2vec.Vocab at 0x7f63f70e5750>,
#  u'seekTo': <gensim.models.word2vec.Vocab at 0x7f6416e0fd10>,
#  u'updateCursor': <gensim.models.word2vec.Vocab at 0x7f63cf96a5d0>,
#  u'A5a': <gensim.models.word2vec.Vocab at 0x7f63f70e57d0>,
#  u'A5c': <gensim.models.word2vec.Vocab at 0x7f63f70e5810>,
#  u'missingTop': <gensim.models.word2vec.Vocab at 0x7f63b2fd7b90>,
#  u'wLeft': <gensim.models.word2vec.Vocab at 0x7f63b2fd7510>,
#  u'setServerType': <gensim.models.word2vec.Vocab at 0x7f63cd330290>,
#  u'do_not_show_success_alert': <gensim.models.word2vec.Vocab at 0x7f63b2fd7e50>,
#  u'getVideoWidth': <gensim.models.word2vec.Vocab at 0x7f63b30b9ad0>,
#  u'extName': <gensim.models.word2vec.Vocab at 0x7f63b30b9a50>,
#  u'Draggable': <gensim.models.word2vec.Vocab at 0x7f63f70e58d0>,
#  u'adapterSettings': <gensim.models.word2vec.Vocab at 0x7f63f70e5910>,
#  u'extendRegExp': <gensim.models.word2vec.Vocab at 0x7f63b2ea6350>,
#  u'random_int': <gensim.models.word2vec.Vocab at 0x7f63b19f6710>,
#  u'addNumbers': <gensim.models.word2vec.Vocab at 0x7f63f70e5950>,
#  u'sessionLength': <gensim.models.word2vec.Vocab at 0x7f63f70e5990>,
#  u'error1': <gensim.models.word2vec.Vocab at 0x7f63b2ea6cd0>,
#  u'kids': <gensim.models.word2vec.Vocab at 0x7f63b2fd7c90>,
#  u'dialog2': <gensim.models.word2vec.Vocab at 0x7f63c21a2c10>,
#  u'charReceived': <gensim.models.word2vec.Vocab at 0x7f63b2bb40d0>,
#  u'elqErr': <gensim.models.word2vec.Vocab at 0x7f63f70e5a10>,
#  u'validateNonEmptyObject': <gensim.models.word2vec.Vocab at 0x7f63f70e5a50>,
#  u'viewThreshold': <gensim.models.word2vec.Vocab at 0x7f63f70e5a90>,
#  u'_crc32': <gensim.models.word2vec.Vocab at 0x7f63f70e5ad0>,
#  u'timePicker': <gensim.models.word2vec.Vocab at 0x7f63b287be10>,
#  u'takeOrdinalPosition': <gensim.models.word2vec.Vocab at 0x7f63b2fd7810>,
#  u'onPositionItems': <gensim.models.word2vec.Vocab at 0x7f63f70e5b50>,
#  u'UFICommentOrderingMode': <gensim.models.word2vec.Vocab at 0x7f63ad0427d0>,
#  u'content_css': <gensim.models.word2vec.Vocab at 0x7f63f70e5b90>,
#  u'projection': <gensim.models.word2vec.Vocab at 0x7f63f70e5bd0>,
#  u'validateDOMNesting': <gensim.models.word2vec.Vocab at 0x7f63f70e5c10>,
#  u'pidref': <gensim.models.word2vec.Vocab at 0x7f63b2fd7ed0>,
#  u'GeolocationErrorCode': <gensim.models.word2vec.Vocab at 0x7f63b2fd7610>,
#  u'audio_url': <gensim.models.word2vec.Vocab at 0x7f63b2fd7890>,
#  u'setStartEllipAt': <gensim.models.word2vec.Vocab at 0x7f63b2fd7950>,
#  u'lma': <gensim.models.word2vec.Vocab at 0x7f63b6dac690>,
#  u'flatCoordinates': <gensim.models.word2vec.Vocab at 0x7f63b2fd7710>,
#  u'dateFinDefault': <gensim.models.word2vec.Vocab at 0x7f63b374d190>,
#  u'dnd': <gensim.models.word2vec.Vocab at 0x7f63b2fd72d0>,
#  u'e6': <gensim.models.word2vec.Vocab at 0x7f63b287b810>,
#  u'dna': <gensim.models.word2vec.Vocab at 0x7f63b2fd79d0>,
#  u'FileTooLarge': <gensim.models.word2vec.Vocab at 0x7f63b2fd7290>,
#  u'buildImpressionRequestParams': <gensim.models.word2vec.Vocab at 0x7f63b2fd7310>,
#  u'cacheURL': <gensim.models.word2vec.Vocab at 0x7f63b2fd75d0>,
#  u'castToggle': <gensim.models.word2vec.Vocab at 0x7f63b2fd7c10>,
#  u'FJd': <gensim.models.word2vec.Vocab at 0x7f63b2fd7f50>,
#  u'dnt': <gensim.models.word2vec.Vocab at 0x7f63b2fd7a50>,
#  u'minPlaybackRate': <gensim.models.word2vec.Vocab at 0x7f63b2fd7050>,
#  u'serverResolutions': <gensim.models.word2vec.Vocab at 0x7f63b57a9090>,
#  u'dns': <gensim.models.word2vec.Vocab at 0x7f63b2fd7b50>,
#  u'tokenize': <gensim.models.word2vec.Vocab at 0x7f63c3c6fb90>,
#  u'videoSources': <gensim.models.word2vec.Vocab at 0x7f63b2eebc10>,
#  u'getPlayTypeGA': <gensim.models.word2vec.Vocab at 0x7f63b287b710>,
#  u'ajaxFormUnbind': <gensim.models.word2vec.Vocab at 0x7f63f70e5e10>,
#  u'noResultsText': <gensim.models.word2vec.Vocab at 0x7f63b57a90d0>,
#  u'dragPosition': <gensim.models.word2vec.Vocab at 0x7f63b2eeb310>,
#  u'suggestionsList': <gensim.models.word2vec.Vocab at 0x7f63b2eebd10>,
#  u'RecruitCandidateQuestionView': <gensim.models.word2vec.Vocab at 0x7f63b38c8c10>,
#  u'_doProgressWith': <gensim.models.word2vec.Vocab at 0x7f63b463eb90>,
#  u'yahoo': <gensim.models.word2vec.Vocab at 0x7f63b2eeb690>,
#  u'requestToProcess': <gensim.models.word2vec.Vocab at 0x7f63cdd6c510>,
#  u'tt_PosAlt': <gensim.models.word2vec.Vocab at 0x7f63c7fe4f50>,
#  u'buyBoxURL': <gensim.models.word2vec.Vocab at 0x7f63f70e5ed0>,
#  u'addTabSupport': <gensim.models.word2vec.Vocab at 0x7f63b2eeb150>,
#  u'playbackRateSupported': <gensim.models.word2vec.Vocab at 0x7f63b3091ed0>,
#  u'QuestionArea': <gensim.models.word2vec.Vocab at 0x7f63b3091d90>,
#  u'contextDataMapping': <gensim.models.word2vec.Vocab at 0x7f63b2eeb450>,
#  u'stateBySrc': <gensim.models.word2vec.Vocab at 0x7f63b2eebe10>,
#  u'_blobSlice': <gensim.models.word2vec.Vocab at 0x7f63f70e5f50>,
#  u'initializePostEngagementDisplay': <gensim.models.word2vec.Vocab at 0x7f63b2eeb350>,
#  u'_safeCall': <gensim.models.word2vec.Vocab at 0x7f63b2eebf90>,
#  u'ood': <gensim.models.word2vec.Vocab at 0x7f63be5e6610>,
#  u'site_name': <gensim.models.word2vec.Vocab at 0x7f6400c28050>,
#  u'isAccountMalformedAndScribe': <gensim.models.word2vec.Vocab at 0x7f63beb57950>,
#  u'objDateDeb': <gensim.models.word2vec.Vocab at 0x7f63d721fc90>,
#  u'xQc': <gensim.models.word2vec.Vocab at 0x7f63b2eebe90>,
#  u'xQd': <gensim.models.word2vec.Vocab at 0x7f63b2eeb790>,
#  u'PQb': <gensim.models.word2vec.Vocab at 0x7f63b57a9150>,
#  u'apply_url': <gensim.models.word2vec.Vocab at 0x7f63b2eebcd0>,
#  u'shouldShowReplyDelay': <gensim.models.word2vec.Vocab at 0x7f6400c28110>,
#  u'want': <gensim.models.word2vec.Vocab at 0x7f63b29732d0>,
#  u'epcounter': <gensim.models.word2vec.Vocab at 0x7f6400c28190>,
#  u'timeBeforeEndOfBuffer': <gensim.models.word2vec.Vocab at 0x7f6400c281d0>,
#  u'lightboxParams': <gensim.models.word2vec.Vocab at 0x7f63b2eeb850>,
#  u'travel': <gensim.models.word2vec.Vocab at 0x7f6400c28250>,
#  u'bluekai': <gensim.models.word2vec.Vocab at 0x7f63b6dac710>,
#  u'$dockedMouse': <gensim.models.word2vec.Vocab at 0x7f63b2eeb2d0>,
#  u'browserHash': <gensim.models.word2vec.Vocab at 0x7f63b287b7d0>,
#  u'pluginhost': <gensim.models.word2vec.Vocab at 0x7f6400c282d0>,
#  u'oTarget': <gensim.models.word2vec.Vocab at 0x7f63b2eeb7d0>,
#  u'_removeSelectedCellClass': <gensim.models.word2vec.Vocab at 0x7f6400c28310>,
#  u'QueryKey': <gensim.models.word2vec.Vocab at 0x7f63b2a438d0>,
#  u'gShareOnSteamDialog': <gensim.models.word2vec.Vocab at 0x7f6400c28350>,
#  u'orderingMode': <gensim.models.word2vec.Vocab at 0x7f63b2a43390>,
#  u'availableDay': <gensim.models.word2vec.Vocab at 0x7f63b2a43cd0>,
#  u'HEAD': <gensim.models.word2vec.Vocab at 0x7f6400c28390>,
#  u'PROTOCOL': <gensim.models.word2vec.Vocab at 0x7f63b2eeb650>,
#  u'history_is_being_fetched': <gensim.models.word2vec.Vocab at 0x7f63b3acbe10>,
#  u'CFd': <gensim.models.word2vec.Vocab at 0x7f63b3acb1d0>,
#  u'attachRefs': <gensim.models.word2vec.Vocab at 0x7f63b2eebd90>,
#  u'CFb': <gensim.models.word2vec.Vocab at 0x7f6400c283d0>,
#  u'dKey': <gensim.models.word2vec.Vocab at 0x7f63b2e57650>,
#  u'optionNames': <gensim.models.word2vec.Vocab at 0x7f63b2e574d0>,
#  u'oninit': <gensim.models.word2vec.Vocab at 0x7f63b2e579d0>,
#  u'quoteString': <gensim.models.word2vec.Vocab at 0x7f6400c28410>,
#  u'projectLatlngs': <gensim.models.word2vec.Vocab at 0x7f6400c28450>,
#  u'OptionSelectors': <gensim.models.word2vec.Vocab at 0x7f63b3625590>,
#  u'hashReadingTime': <gensim.models.word2vec.Vocab at 0x7f63b3625f50>,
#  u'_ref3': <gensim.models.word2vec.Vocab at 0x7f63b9910fd0>,
#  u'_ref2': <gensim.models.word2vec.Vocab at 0x7f63b9910ed0>,
#  u'_ref1': <gensim.models.word2vec.Vocab at 0x7f6400c28490>,
#  u'weakMapTag': <gensim.models.word2vec.Vocab at 0x7f63b2e57590>,
#  u'hasFixedLayer': <gensim.models.word2vec.Vocab at 0x7f63b2e57c10>,
#  u'borderRightStyle': <gensim.models.word2vec.Vocab at 0x7f6400c284d0>,
#  u'buildLightning': <gensim.models.word2vec.Vocab at 0x7f63b2e57050>,
#  u'setPropertyOnResults': <gensim.models.word2vec.Vocab at 0x7f63b37320d0>,
#  u'autoPanAnimation': <gensim.models.word2vec.Vocab at 0x7f63cad53e90>,
#  u'processUserPosition': <gensim.models.word2vec.Vocab at 0x7f63b2e57710>,
#  u'setVideoBoxClassName': <gensim.models.word2vec.Vocab at 0x7f6400c28550>,
#  u'prefix_id_navigPage': <gensim.models.word2vec.Vocab at 0x7f63b2e57250>,
#  u'analyticsType': <gensim.models.word2vec.Vocab at 0x7f63c9a0d950>,
#  u'sortLocaleCompare': <gensim.models.word2vec.Vocab at 0x7f63b2e576d0>,
#  u'm_strQuery': <gensim.models.word2vec.Vocab at 0x7f63b35e2a90>,
#  u'concurrency': <gensim.models.word2vec.Vocab at 0x7f63b2e57b90>,
#  u'ACTION_ARCHIVED': <gensim.models.word2vec.Vocab at 0x7f63ad419910>,
#  u'activating': <gensim.models.word2vec.Vocab at 0x7f63b2e57ad0>,
#  u'pushedData': <gensim.models.word2vec.Vocab at 0x7f63c36b2d50>,
#  u'isJavascript': <gensim.models.word2vec.Vocab at 0x7f63b2e57a10>,
#  u'scrollDeltaY': <gensim.models.word2vec.Vocab at 0x7f63cf96a8d0>,
#  u'levelLoadingRetryDelay': <gensim.models.word2vec.Vocab at 0x7f63f70e5190>,
#  u'escapeForHtml': <gensim.models.word2vec.Vocab at 0x7f6400c285d0>,
#  u'firedArgs': <gensim.models.word2vec.Vocab at 0x7f63b384d050>,
#  u'renderedChildren': <gensim.models.word2vec.Vocab at 0x7f63b63a2910>,
#  u'uoc': <gensim.models.word2vec.Vocab at 0x7f6400c28650>,
#  u'Hia': <gensim.models.word2vec.Vocab at 0x7f63b2e16710>,
#  u'uoa': <gensim.models.word2vec.Vocab at 0x7f6400c286d0>,
#  u'Hic': <gensim.models.word2vec.Vocab at 0x7f63b3161dd0>,
#  u'fif': <gensim.models.word2vec.Vocab at 0x7f63b2e16510>,
#  u'uof': <gensim.models.word2vec.Vocab at 0x7f6400c28710>,
#  u'fid': <gensim.models.word2vec.Vocab at 0x7f63b2e16790>,
#  u'fie': <gensim.models.word2vec.Vocab at 0x7f63b2e16d10>,
#  u'aMask': <gensim.models.word2vec.Vocab at 0x7f63c96800d0>,
#  u'fin': <gensim.models.word2vec.Vocab at 0x7f63b2e16d90>,
#  u'fil': <gensim.models.word2vec.Vocab at 0x7f63b2e16990>,
#  u'scroll_top': <gensim.models.word2vec.Vocab at 0x7f6400c28810>,
#  u'navigateDom': <gensim.models.word2vec.Vocab at 0x7f63d30f7590>,
#  u'Eua': <gensim.models.word2vec.Vocab at 0x7f63b2e16f10>,
#  u'server_call_id': <gensim.models.word2vec.Vocab at 0x7f63b2e16550>,
#  u'$portfolioDetails': <gensim.models.word2vec.Vocab at 0x7f63b2e16410>,
#  u'Signatures': <gensim.models.word2vec.Vocab at 0x7f63b57a9250>,
#  u'effects': <gensim.models.word2vec.Vocab at 0x7f6400c28890>,
#  u'debugmode': <gensim.models.word2vec.Vocab at 0x7f63bd96a990>,
#  u'templateClass': <gensim.models.word2vec.Vocab at 0x7f63b1024610>,
#  u'getPlid': <gensim.models.word2vec.Vocab at 0x7f63b2e16dd0>,
#  u'mergeObject': <gensim.models.word2vec.Vocab at 0x7f63b3020cd0>,
#  u'hideNext': <gensim.models.word2vec.Vocab at 0x7f63b3020950>,
#  u'mousewheelInvert': <gensim.models.word2vec.Vocab at 0x7f63be540810>,
#  u'channel_id': <gensim.models.word2vec.Vocab at 0x7f63c8c18310>,
#  u'accordionOpen': <gensim.models.word2vec.Vocab at 0x7f6400c28950>,
#  u'$overview': <gensim.models.word2vec.Vocab at 0x7f63b3020ad0>,
#  u'uprts': <gensim.models.word2vec.Vocab at 0x7f63b3020f10>,
#  u'ConfigurationError': <gensim.models.word2vec.Vocab at 0x7f63b30200d0>,
#  u'apiendpoint': <gensim.models.word2vec.Vocab at 0x7f63b3020890>,
#  u'widgetEventPrefix': <gensim.models.word2vec.Vocab at 0x7f63b3020610>,
#  u'webRequest': <gensim.models.word2vec.Vocab at 0x7f63be3a8450>,
#  u'subAttrName': <gensim.models.word2vec.Vocab at 0x7f6400c28a10>,
#  u'timeout': <gensim.models.word2vec.Vocab at 0x7f6400c28a50>,
#  u'dependsOn': <gensim.models.word2vec.Vocab at 0x7f63dd18b410>,
#  u'specific_month_beg': <gensim.models.word2vec.Vocab at 0x7f63ce335b10>,
#  u'jqName': <gensim.models.word2vec.Vocab at 0x7f63b3020e90>,
#  u'max_characters': <gensim.models.word2vec.Vocab at 0x7f63b3535e50>,
#  u'pin_image_url': <gensim.models.word2vec.Vocab at 0x7f6400c28b10>,
#  u'tooltipSelector': <gensim.models.word2vec.Vocab at 0x7f63b30208d0>,
#  u'START_TO_START': <gensim.models.word2vec.Vocab at 0x7f63b57a9290>,
#  u'isNavKey': <gensim.models.word2vec.Vocab at 0x7f6400c28b90>,
#  u'_fnMap': <gensim.models.word2vec.Vocab at 0x7f63b33e4590>,
#  u'v1_1': <gensim.models.word2vec.Vocab at 0x7f63b33e4d10>,
#  u'getConversationMessagesModule': <gensim.models.word2vec.Vocab at 0x7f63b3020f90>,
#  u'sya': <gensim.models.word2vec.Vocab at 0x7f63b2411350>,
#  u'updateMethod': <gensim.models.word2vec.Vocab at 0x7f63b3020f50>,
#  u'readChildNodes': <gensim.models.word2vec.Vocab at 0x7f63b3020a90>,
#  u'_applyCombination': <gensim.models.word2vec.Vocab at 0x7f63b3020410>,
#  u'getTypeFromExtension': <gensim.models.word2vec.Vocab at 0x7f63b2d80b50>,
#  u'Freezable': <gensim.models.word2vec.Vocab at 0x7f63c94aa090>,
#  u'wheelStartX': <gensim.models.word2vec.Vocab at 0x7f63b2d80cd0>,
#  u'wheelStartY': <gensim.models.word2vec.Vocab at 0x7f63b2d80890>,
#  u'origMaxHeight': <gensim.models.word2vec.Vocab at 0x7f63b357f750>,
#  u'recommendScores': <gensim.models.word2vec.Vocab at 0x7f6400c28c50>,
#  u'shouldLog': <gensim.models.word2vec.Vocab at 0x7f63b2d80dd0>,
#  u'addSlot': <gensim.models.word2vec.Vocab at 0x7f63b2d80ed0>,
#  u'queryId': <gensim.models.word2vec.Vocab at 0x7f63c81e4710>,
#  u'getFileAnchor': <gensim.models.word2vec.Vocab at 0x7f63b2d80250>,
#  u'm_knownMessageSources': <gensim.models.word2vec.Vocab at 0x7f63b2d80e50>,
#  u'clickTimer': <gensim.models.word2vec.Vocab at 0x7f6400c28d10>,
#  u'KEY_LOAD_TIMEOUT': <gensim.models.word2vec.Vocab at 0x7f63bb968210>,
#  u'_poly': <gensim.models.word2vec.Vocab at 0x7f63b1f2f650>,
#  u'markerZoomAnimation': <gensim.models.word2vec.Vocab at 0x7f63be3a8590>,
#  u'sDisplay': <gensim.models.word2vec.Vocab at 0x7f6400c28d90>,
#  u'prefilterHooks': <gensim.models.word2vec.Vocab at 0x7f63b2d80350>,
#  u'imageNode': <gensim.models.word2vec.Vocab at 0x7f63b2d80ad0>,
#  u'_poll': <gensim.models.word2vec.Vocab at 0x7f6400c28e10>,
#  u'Egc': <gensim.models.word2vec.Vocab at 0x7f6400c28e50>,
#  u'getBestAvailNavData': <gensim.models.word2vec.Vocab at 0x7f6400c28e90>,
#  u'autoFocus': <gensim.models.word2vec.Vocab at 0x7f63b2d80d10>,
#  u'adsResponse': <gensim.models.word2vec.Vocab at 0x7f63b8173a90>,
#  u'lastplayedvideos': <gensim.models.word2vec.Vocab at 0x7f6400c28f50>,
#  u'ModalBase': <gensim.models.word2vec.Vocab at 0x7f63ce915d50>,
#  u'gtm_onFailure': <gensim.models.word2vec.Vocab at 0x7f63b2d801d0>,
#  u'_nativeContainerInfo': <gensim.models.word2vec.Vocab at 0x7f6400c28f90>,
#  u'requesturl': <gensim.models.word2vec.Vocab at 0x7f63b1bd8390>,
#  u'inputHasSelection': <gensim.models.word2vec.Vocab at 0x7f63b32a1bd0>,
#  u'getY': <gensim.models.word2vec.Vocab at 0x7f63b72d9fd0>,
#  u'bookmark': <gensim.models.word2vec.Vocab at 0x7f63b2d80a50>,
#  u'wrap_around': <gensim.models.word2vec.Vocab at 0x7f6400c28fd0>,
#  u'_slidesContainer': <gensim.models.word2vec.Vocab at 0x7f63b2d80290>,
#  u'getFormValues': <gensim.models.word2vec.Vocab at 0x7f63b39dae10>,
#  u'getSelfURL': <gensim.models.word2vec.Vocab at 0x7f63b2d80e90>,
#  u'oldS': <gensim.models.word2vec.Vocab at 0x7f63b2d80950>,
#  u'numHeber': <gensim.models.word2vec.Vocab at 0x7f63b2d80150>,
#  u'errorClass': <gensim.models.word2vec.Vocab at 0x7f63b2d80c90>,
#  u'ifExists': <gensim.models.word2vec.Vocab at 0x7f63b632fed0>,
#  u'GetValue': <gensim.models.word2vec.Vocab at 0x7f640c2b70d0>,
#  u'OptionsFactory': <gensim.models.word2vec.Vocab at 0x7f63b2d803d0>,
#  u'arr_elm': <gensim.models.word2vec.Vocab at 0x7f63b3473790>,
#  u'rightContX': <gensim.models.word2vec.Vocab at 0x7f63b2ec4850>,
#  u'rightContY': <gensim.models.word2vec.Vocab at 0x7f63b2ec42d0>,
#  u'tagifyStyle': <gensim.models.word2vec.Vocab at 0x7f63b2ec4710>,
#  u'oldN': <gensim.models.word2vec.Vocab at 0x7f63b2ec4210>,
#  u'LANG': <gensim.models.word2vec.Vocab at 0x7f63b2ec4110>,
#  u'$registerBtn': <gensim.models.word2vec.Vocab at 0x7f63b3a6aed0>,
#  u'plugInWaitCount': <gensim.models.word2vec.Vocab at 0x7f63b1793750>,
#  u'droppedPositionElement': <gensim.models.word2vec.Vocab at 0x7f63b2ec4050>,
#  u'oldy': <gensim.models.word2vec.Vocab at 0x7f63b2ec4650>,
#  u'oldx': <gensim.models.word2vec.Vocab at 0x7f63b2ec4f10>,
#  u'ensureRightProtocol': <gensim.models.word2vec.Vocab at 0x7f640c2b7150>,
#  u'displayDetailPage': <gensim.models.word2vec.Vocab at 0x7f63b2ec4890>,
#  u'addClickHandler': <gensim.models.word2vec.Vocab at 0x7f63b2ec4190>,
#  u'storeUserVolume': <gensim.models.word2vec.Vocab at 0x7f63b2ec40d0>,
#  u'olda': <gensim.models.word2vec.Vocab at 0x7f63b2ec4610>,
#  u'needed': <gensim.models.word2vec.Vocab at 0x7f63b2ec4f90>,
#  u'oldc': <gensim.models.word2vec.Vocab at 0x7f63b2ec45d0>,
#  u'oldb': <gensim.models.word2vec.Vocab at 0x7f63b327aa50>,
#  u'master': <gensim.models.word2vec.Vocab at 0x7f63b2ec4ed0>,
#  u'oldd': <gensim.models.word2vec.Vocab at 0x7f63b2ec4950>,
#  u'moveRoot': <gensim.models.word2vec.Vocab at 0x7f640c2b71d0>,
#  u'numFormat': <gensim.models.word2vec.Vocab at 0x7f63b2ec4990>,
#  u'getNextId': <gensim.models.word2vec.Vocab at 0x7f640c2b7210>,
#  u'pushAd': <gensim.models.word2vec.Vocab at 0x7f63b2ec4510>,
#  u'openDetailPage': <gensim.models.word2vec.Vocab at 0x7f63b39df090>,
#  u'rewards': <gensim.models.word2vec.Vocab at 0x7f640c2b7290>,
#  u'HOT_LIKE_MEDIUM_STICKER_ID': <gensim.models.word2vec.Vocab at 0x7f63b1bb0950>,
#  u'_getElementsOrdered': <gensim.models.word2vec.Vocab at 0x7f63b3000350>,
#  u'q0c': <gensim.models.word2vec.Vocab at 0x7f63b30009d0>,
#  u'q0a': <gensim.models.word2vec.Vocab at 0x7f63b3000650>,
#  u'privateKey': <gensim.models.word2vec.Vocab at 0x7f640c2b7350>,
#  u'NewClass': <gensim.models.word2vec.Vocab at 0x7f63cccd7850>,
#  u'viewerHeight': <gensim.models.word2vec.Vocab at 0x7f63b30006d0>,
#  u'slideOffset': <gensim.models.word2vec.Vocab at 0x7f640c2b7390>,
#  u'lineNumWidth': <gensim.models.word2vec.Vocab at 0x7f640c2b73d0>,
#  u'qs2obj': <gensim.models.word2vec.Vocab at 0x7f640c2b7410>,
#  u'ParameterName': <gensim.models.word2vec.Vocab at 0x7f63b3000790>,
#  u'releaseTile': <gensim.models.word2vec.Vocab at 0x7f63b3000b90>,
#  u'streams': <gensim.models.word2vec.Vocab at 0x7f63b20caad0>,
#  u'SPAN': <gensim.models.word2vec.Vocab at 0x7f63b39447d0>,
#  u'SPAM': <gensim.models.word2vec.Vocab at 0x7f640c2b74d0>,
#  u'getCustomData': <gensim.models.word2vec.Vocab at 0x7f640c2b7510>,
#  u'$MercurySearchThreadResultOrderer2': <gensim.models.word2vec.Vocab at 0x7f63b19f6c50>,
#  u'initList': <gensim.models.word2vec.Vocab at 0x7f63b3000b50>,
#  u'map_canevas': <gensim.models.word2vec.Vocab at 0x7f63b3000290>,
#  u'markerPos': <gensim.models.word2vec.Vocab at 0x7f63b39df290>,
#  u'_display_name': <gensim.models.word2vec.Vocab at 0x7f63b3000e50>,
#  u'WebForms': <gensim.models.word2vec.Vocab at 0x7f63c019a610>,
#  u'_addTransition': <gensim.models.word2vec.Vocab at 0x7f63b31cd410>,
#  u'target_name': <gensim.models.word2vec.Vocab at 0x7f63b31cdf50>,
#  u'msg_ids': <gensim.models.word2vec.Vocab at 0x7f63b30002d0>,
#  u'translationManager': <gensim.models.word2vec.Vocab at 0x7f640c2b7590>,
#  u'_onEnded': <gensim.models.word2vec.Vocab at 0x7f640c2b75d0>,
#  u'dedupe': <gensim.models.word2vec.Vocab at 0x7f63b3000410>,
#  u'_updateAlternate': <gensim.models.word2vec.Vocab at 0x7f63b2da7bd0>,
#  u'is_qtext2': <gensim.models.word2vec.Vocab at 0x7f63b2da7b50>,
#  u'bJmpMod': <gensim.models.word2vec.Vocab at 0x7f63b2da7f50>,
#  u'vgd': <gensim.models.word2vec.Vocab at 0x7f640c2b7710>,
#  u'removeOnce': <gensim.models.word2vec.Vocab at 0x7f63b2da7810>,
#  u'vgf': <gensim.models.word2vec.Vocab at 0x7f640c2b7750>,
#  u'_appEnabled': <gensim.models.word2vec.Vocab at 0x7f63b2da7c50>,
#  u'vga': <gensim.models.word2vec.Vocab at 0x7f640c2b77d0>,
#  u'$scrollableElement': <gensim.models.word2vec.Vocab at 0x7f63b0c88d90>,
#  u'_isDestroyed': <gensim.models.word2vec.Vocab at 0x7f63b2da74d0>,
#  u'moreLayout': <gensim.models.word2vec.Vocab at 0x7f640c2b7850>,
#  u'lonlat': <gensim.models.word2vec.Vocab at 0x7f63aedaa410>,
#  u'updatePinInContainer': <gensim.models.word2vec.Vocab at 0x7f63b2da7490>,
#  u'y8e': <gensim.models.word2vec.Vocab at 0x7f63b57a9410>,
#  u'imageDataSelector': <gensim.models.word2vec.Vocab at 0x7f63b2da7110>,
#  u'cleanseUsername': <gensim.models.word2vec.Vocab at 0x7f640c2b78d0>,
#  u'applyCommand': <gensim.models.word2vec.Vocab at 0x7f63b2da7090>,
#  u'_updateScales': <gensim.models.word2vec.Vocab at 0x7f63b2da7e10>,
#  u'$searchForm': <gensim.models.word2vec.Vocab at 0x7f640c2b7910>,
#  u'_is_visible_cbs': <gensim.models.word2vec.Vocab at 0x7f63b2da75d0>,
#  u'cinematic': <gensim.models.word2vec.Vocab at 0x7f640c2b7950>,
#  u'initModal': <gensim.models.word2vec.Vocab at 0x7f63b2da77d0>,
#  u'simplify': <gensim.models.word2vec.Vocab at 0x7f640c2b79d0>,
#  u'errors': <gensim.models.word2vec.Vocab at 0x7f63f70e5510>,
#  u'txtLength': <gensim.models.word2vec.Vocab at 0x7f63b37e6750>,
#  u'attachDropdown': <gensim.models.word2vec.Vocab at 0x7f640c2b7a10>,
#  u'safe_require': <gensim.models.word2vec.Vocab at 0x7f640c2b7a50>,
#  u'currentStatus': <gensim.models.word2vec.Vocab at 0x7f640c2b7a90>,
#  u'refreshTimeout': <gensim.models.word2vec.Vocab at 0x7f63b2dc7090>,
#  u'radioClass': <gensim.models.word2vec.Vocab at 0x7f640c2b7ad0>,
#  u'addSeconds': <gensim.models.word2vec.Vocab at 0x7f640c2b7b10>,
#  u'___ERROR___': <gensim.models.word2vec.Vocab at 0x7f640c2b7b50>,
#  u'filter_cellFilter': <gensim.models.word2vec.Vocab at 0x7f640c2b7b90>,
#  u'vertices': <gensim.models.word2vec.Vocab at 0x7f640c2b7bd0>,
#  u'blurHandler': <gensim.models.word2vec.Vocab at 0x7f640c2b7c10>,
#  u'tech': <gensim.models.word2vec.Vocab at 0x7f63b3874d90>,
#  u'onAnimationEndCapture': <gensim.models.word2vec.Vocab at 0x7f63f70e5590>,
#  u'ErrorUtils': <gensim.models.word2vec.Vocab at 0x7f63cb189790>,
#  u'starOff': <gensim.models.word2vec.Vocab at 0x7f63b747e450>,
#  u'mediaDevices': <gensim.models.word2vec.Vocab at 0x7f63b2dc7750>,
#  u'updateDuration': <gensim.models.word2vec.Vocab at 0x7f640c2b7c90>,
#  u'scrollbarYHeight': <gensim.models.word2vec.Vocab at 0x7f63b2dc7110>,
#  u'sizeOld': <gensim.models.word2vec.Vocab at 0x7f63b39df450>,
#  u'fixHook': <gensim.models.word2vec.Vocab at 0x7f640c2b7d10>,
#  u'AD_LOADED': <gensim.models.word2vec.Vocab at 0x7f63b2dc7cd0>,
#  u'getPreloadHandlers': <gensim.models.word2vec.Vocab at 0x7f640c2b7d90>,
#  u'$LiveWWWFeedbackTypedLogger1': <gensim.models.word2vec.Vocab at 0x7f63b2dc7050>,
#  u'padded': <gensim.models.word2vec.Vocab at 0x7f63b747e750>,
#  u'makeRequestSrcData': <gensim.models.word2vec.Vocab at 0x7f640c2b7e50>,
#  u'slidesLoaded': <gensim.models.word2vec.Vocab at 0x7f63ccdd1750>,
#  u'kadfloor': <gensim.models.word2vec.Vocab at 0x7f63ad141f50>,
#  u'header_index': <gensim.models.word2vec.Vocab at 0x7f63b7d7e8d0>,
#  u'popinLoaded': <gensim.models.word2vec.Vocab at 0x7f63b2dc72d0>,
#  u'stringTo': <gensim.models.word2vec.Vocab at 0x7f640c2b7f10>,
#  u'_a1': <gensim.models.word2vec.Vocab at 0x7f63b38fbd90>,
#  u'clicked': <gensim.models.word2vec.Vocab at 0x7f640c2b7f50>,
#  u'deprecationType': <gensim.models.word2vec.Vocab at 0x7f63b2dc7350>,
#  u'replaceContent': <gensim.models.word2vec.Vocab at 0x7f63f70e5650>,
#  u'INVITATION_PERSONAL': <gensim.models.word2vec.Vocab at 0x7f63b75ed450>,
#  u'beforeMove': <gensim.models.word2vec.Vocab at 0x7f63b2dc7ad0>,
#  u'availableAdapters': <gensim.models.word2vec.Vocab at 0x7f63c2a23050>,
#  u'createCSS': <gensim.models.word2vec.Vocab at 0x7f63bed28090>,
#  u'anychoice': <gensim.models.word2vec.Vocab at 0x7f63b2dc7d10>,
#  u'getModuleAdditionalAuxData': <gensim.models.word2vec.Vocab at 0x7f63b2dc7490>,
#  u'rnum': <gensim.models.word2vec.Vocab at 0x7f63c2a23110>,
#  u'scrollspeed': <gensim.models.word2vec.Vocab at 0x7f63c2a23150>,
#  u'_hideunity_savedstyle': <gensim.models.word2vec.Vocab at 0x7f63ad419f10>,
#  u'closeAsChild': <gensim.models.word2vec.Vocab at 0x7f63b76d1990>,
#  u'FeatureSourceEvent': <gensim.models.word2vec.Vocab at 0x7f63b2f18350>,
#  u'closeOnDateSelection': <gensim.models.word2vec.Vocab at 0x7f63b57a95d0>,
#  u'reduxForm': <gensim.models.word2vec.Vocab at 0x7f63c2a23210>,
#  u'webloginUI': <gensim.models.word2vec.Vocab at 0x7f63b2f185d0>,
#  u'_onPlay': <gensim.models.word2vec.Vocab at 0x7f63f70e5710>,
#  u'choice_build': <gensim.models.word2vec.Vocab at 0x7f63c2a23250>,
#  u'exitedClassName': <gensim.models.word2vec.Vocab at 0x7f63b707c050>,
#  u'_gptError': <gensim.models.word2vec.Vocab at 0x7f63b2f18250>,
#  u'fileId': <gensim.models.word2vec.Vocab at 0x7f63b2f18f90>,
#  u'TRCParser': <gensim.models.word2vec.Vocab at 0x7f63c86f3750>,
#  u'obtainCustomDataResult': <gensim.models.word2vec.Vocab at 0x7f63b2f18d90>,
#  u'patch': <gensim.models.word2vec.Vocab at 0x7f63b2f18e10>,
#  u'test_script_elem': <gensim.models.word2vec.Vocab at 0x7f63c2a232d0>,
#  u'setSourceAttributes': <gensim.models.word2vec.Vocab at 0x7f63c2a23310>,
#  u'selectModule': <gensim.models.word2vec.Vocab at 0x7f63c2a23350>,
#  u'_onMouseWheel': <gensim.models.word2vec.Vocab at 0x7f63bbe97650>,
#  u'RecaptchaState': <gensim.models.word2vec.Vocab at 0x7f63b2f184d0>,
#  u'callInternal': <gensim.models.word2vec.Vocab at 0x7f63b2f183d0>,
#  u'hide_changed': <gensim.models.word2vec.Vocab at 0x7f63caae1a10>,
#  u'isOffline': <gensim.models.word2vec.Vocab at 0x7f63c2a233d0>,
#  u'$videoItem': <gensim.models.word2vec.Vocab at 0x7f63b19f6e50>,
#  u'active_slide_class': <gensim.models.word2vec.Vocab at 0x7f63bd1960d0>,
#  u'getButton': <gensim.models.word2vec.Vocab at 0x7f63c2a23450>,
#  u'_applyFilter': <gensim.models.word2vec.Vocab at 0x7f63b2f18590>,
#  u'$val': <gensim.models.word2vec.Vocab at 0x7f63b2f181d0>,
#  u'mountComponent': <gensim.models.word2vec.Vocab at 0x7f63c2a23490>,
#  u'obtainReferrer': <gensim.models.word2vec.Vocab at 0x7f63b2f18210>,
#  u'size_id': <gensim.models.word2vec.Vocab at 0x7f63cf1aead0>,
#  u'formatDay': <gensim.models.word2vec.Vocab at 0x7f63b30b97d0>,
#  u'iri': <gensim.models.word2vec.Vocab at 0x7f63b30b9950>,
#  u'xva': <gensim.models.word2vec.Vocab at 0x7f63c2a23510>,
#  u'ira': <gensim.models.word2vec.Vocab at 0x7f63b30b9290>,
#  u'_transTime': <gensim.models.word2vec.Vocab at 0x7f63aee97d90>,
#  u'xvb': <gensim.models.word2vec.Vocab at 0x7f63c2a23550>,
#  u'pbImage': <gensim.models.word2vec.Vocab at 0x7f63b30b9bd0>,
#  u'_chekboxBars': <gensim.models.word2vec.Vocab at 0x7f63b30b9350>,
#  u'$MessengerAdsWebTypedLogger1': <gensim.models.word2vec.Vocab at 0x7f63b30b9c50>,
#  u'extend': <gensim.models.word2vec.Vocab at 0x7f63b30b9250>,
#  u'prop48': <gensim.models.word2vec.Vocab at 0x7f63bef2bd90>,
#  u'fromInt': <gensim.models.word2vec.Vocab at 0x7f63f70e5850>,
#  u'pConfig': <gensim.models.word2vec.Vocab at 0x7f63b30b9210>,
#  u'buildSkeleton': <gensim.models.word2vec.Vocab at 0x7f63b30b93d0>,
#  u'gptloadset': <gensim.models.word2vec.Vocab at 0x7f63c2a235d0>,
#  u'extent': <gensim.models.word2vec.Vocab at 0x7f63b30b9450>,
#  u'searchsuggest': <gensim.models.word2vec.Vocab at 0x7f63f70e5890>,
#  u'_contexts': <gensim.models.word2vec.Vocab at 0x7f63b30b9910>,
#  u'isSorted': <gensim.models.word2vec.Vocab at 0x7f63b2ea6590>,
#  u'getStyleName': <gensim.models.word2vec.Vocab at 0x7f63c2a23610>,
#  u'internalns': <gensim.models.word2vec.Vocab at 0x7f63b2ea6ed0>,
#  u'_addReference': <gensim.models.word2vec.Vocab at 0x7f63b19f6f90>,
#  u'stackDest': <gensim.models.word2vec.Vocab at 0x7f63b2ea6290>,
#  u'inputProps': <gensim.models.word2vec.Vocab at 0x7f63c2a23650>,
#  u'defineMode': <gensim.models.word2vec.Vocab at 0x7f63b2ea6d50>,
#  u'removeLabel': <gensim.models.word2vec.Vocab at 0x7f63bef2b2d0>,
#  u'url_string': <gensim.models.word2vec.Vocab at 0x7f63c2a23690>,
#  u'getFlotOptions': <gensim.models.word2vec.Vocab at 0x7f63c2a236d0>,
#  u'stringSize': <gensim.models.word2vec.Vocab at 0x7f63b2ea6890>,
#  u'_handleLogin': <gensim.models.word2vec.Vocab at 0x7f63c2a23710>,
#  u'linewise': <gensim.models.word2vec.Vocab at 0x7f63c2a23750>,
#  u'chains': <gensim.models.word2vec.Vocab at 0x7f63b90efc10>,
#  u'daysPerWeek': <gensim.models.word2vec.Vocab at 0x7f63b2ea6f90>,
#  u'gopher': <gensim.models.word2vec.Vocab at 0x7f63b2ea6e90>,
#  u'pageHidden': <gensim.models.word2vec.Vocab at 0x7f63bd407490>,
#  u'$empty_product_view': <gensim.models.word2vec.Vocab at 0x7f63b39df710>,
#  u'latLngToCoords': <gensim.models.word2vec.Vocab at 0x7f63bd407c10>,
#  u'levelsMap': <gensim.models.word2vec.Vocab at 0x7f63b2ea6410>,
#  u'Wnb': <gensim.models.word2vec.Vocab at 0x7f63b2ea6910>,
#  u'Wnc': <gensim.models.word2vec.Vocab at 0x7f63b17ca690>,
#  u'ric_width': <gensim.models.word2vec.Vocab at 0x7f63b2ea6310>,
#  u'Wna': <gensim.models.word2vec.Vocab at 0x7f63b2ea6a10>,
#  u'getImageIconClass': <gensim.models.word2vec.Vocab at 0x7f63b42ba250>,
#  u'parsedInput': <gensim.models.word2vec.Vocab at 0x7f63b2ea6050>,
#  u'frd': <gensim.models.word2vec.Vocab at 0x7f63bd498250>,
#  u'pastInput': <gensim.models.word2vec.Vocab at 0x7f63c2a23950>,
#  u'animate_panels': <gensim.models.word2vec.Vocab at 0x7f63c2a23990>,
#  u'fro': <gensim.models.word2vec.Vocab at 0x7f63c2a239d0>,
#  u'frm': <gensim.models.word2vec.Vocab at 0x7f63c2a23a10>,
#  u'numRows': <gensim.models.word2vec.Vocab at 0x7f63b2ea60d0>,
#  u'frr': <gensim.models.word2vec.Vocab at 0x7f63c62909d0>,
#  u'frp': <gensim.models.word2vec.Vocab at 0x7f63c2a23a90>,
#  u'msInterpolationMode': <gensim.models.word2vec.Vocab at 0x7f63b2ea6950>,
#  u'ReactDOMContainerInfo': <gensim.models.word2vec.Vocab at 0x7f63c2a23ad0>,
#  u'text_elements': <gensim.models.word2vec.Vocab at 0x7f63bb673090>,
#  u'moveTitle': <gensim.models.word2vec.Vocab at 0x7f63b2ea6550>,
#  u'selectedItemType': <gensim.models.word2vec.Vocab at 0x7f63b2ea6990>,
#  u'$div': <gensim.models.word2vec.Vocab at 0x7f63f70e59d0>,
#  u'isCursorAtEnd': <gensim.models.word2vec.Vocab at 0x7f63b2bb4990>,
#  u'complete_channels': <gensim.models.word2vec.Vocab at 0x7f63cfde87d0>,
#  u'spid': <gensim.models.word2vec.Vocab at 0x7f63c2a23b50>,
#  u'removeFromStack': <gensim.models.word2vec.Vocab at 0x7f63b2bb4250>,
#  u'spin': <gensim.models.word2vec.Vocab at 0x7f63c2a23b90>,
#  u'uJa': <gensim.models.word2vec.Vocab at 0x7f63b2bb4c10>,
#  u'startTutorial': <gensim.models.word2vec.Vocab at 0x7f63be699f90>,
#  u'viewContainerEl': <gensim.models.word2vec.Vocab at 0x7f63b2bb4cd0>,
#  u'pixelPlacer': <gensim.models.word2vec.Vocab at 0x7f63c2a23c10>,
#  u'$UFIToplevelStreamedCommentList1': <gensim.models.word2vec.Vocab at 0x7f63c3c32510>,
#  u'$UFIToplevelStreamedCommentList2': <gensim.models.word2vec.Vocab at 0x7f63b2bb4950>,
#  u'midActivityThreshold': <gensim.models.word2vec.Vocab at 0x7f63c2a23c50>,
#  u'slideEaseFunction': <gensim.models.word2vec.Vocab at 0x7f63b2bb4bd0>,
#  u'_compositeLifeCycleState': <gensim.models.word2vec.Vocab at 0x7f63c2a23c90>,
#  u'Call': <gensim.models.word2vec.Vocab at 0x7f63b27a1090>,
#  u'sliderWidth': <gensim.models.word2vec.Vocab at 0x7f63b2bb4d10>,
#  u'zYf': <gensim.models.word2vec.Vocab at 0x7f63de798ad0>,
#  u'alertBox': <gensim.models.word2vec.Vocab at 0x7f63b2bb4910>,
#  u'zYb': <gensim.models.word2vec.Vocab at 0x7f63c2a23dd0>,
#  u'zYc': <gensim.models.word2vec.Vocab at 0x7f63c2a23e10>,
#  u'majorStream': <gensim.models.word2vec.Vocab at 0x7f63c2a23e50>,
#  u'dests': <gensim.models.word2vec.Vocab at 0x7f63b2bb4150>,
#  u'CROSS_WINDOW_TARGET_STOP_LISTENING': <gensim.models.word2vec.Vocab at 0x7f63b2bb4750>,
#  u'allowLinkDefault': <gensim.models.word2vec.Vocab at 0x7f63d1e8d850>,
#  u'forEachSubscription': <gensim.models.word2vec.Vocab at 0x7f63b2bb4850>,
#  u'tDims': <gensim.models.word2vec.Vocab at 0x7f63c2a23e90>,
#  u'classeAlternee': <gensim.models.word2vec.Vocab at 0x7f63b4f0df10>,
#  u'repArr': <gensim.models.word2vec.Vocab at 0x7f63c2a23ed0>,
#  u'ATFVideos': <gensim.models.word2vec.Vocab at 0x7f63b2bb4ed0>,
#  u'paintOrder': <gensim.models.word2vec.Vocab at 0x7f63b1024190>,
#  u'BID_STATUS': <gensim.models.word2vec.Vocab at 0x7f63c2a23f10>,
#  u'canAdvance': <gensim.models.word2vec.Vocab at 0x7f63c2a23f50>,
#  u'previousLibrary': <gensim.models.word2vec.Vocab at 0x7f63bb463fd0>,
#  u'getContainingTileCoords': <gensim.models.word2vec.Vocab at 0x7f63c2a23f90>,
#  u'destY': <gensim.models.word2vec.Vocab at 0x7f63b2bb4c50>,
#  u'destX': <gensim.models.word2vec.Vocab at 0x7f63b2bb4290>,
#  u'cMarkerClusterer': <gensim.models.word2vec.Vocab at 0x7f63bb344890>,
#  u'EBe': <gensim.models.word2vec.Vocab at 0x7f63b2bb4dd0>,
#  u'repositionSpeed': <gensim.models.word2vec.Vocab at 0x7f63b2bb4590>,
#  u'EBb': <gensim.models.word2vec.Vocab at 0x7f63b2bb4810>,
#  u'_positionDialogAtTopWhenPortrait': <gensim.models.word2vec.Vocab at 0x7f63b2d01490>,
#  u'JWPLAYER_AUDIO_TRACK_CHANGED': <gensim.models.word2vec.Vocab at 0x7f63b10241d0>,
#  u'placementDivId': <gensim.models.word2vec.Vocab at 0x7f63b2d01810>,
#  u'reset_forms': <gensim.models.word2vec.Vocab at 0x7f63b2d01b10>,
#  u'webkitLineClamp': <gensim.models.word2vec.Vocab at 0x7f63d85f2150>,
#  u'normalizeArrayResponse': <gensim.models.word2vec.Vocab at 0x7f63b6daccd0>,
#  u'snapGrid': <gensim.models.word2vec.Vocab at 0x7f63b2d01150>,
#  u'formResetHandler': <gensim.models.word2vec.Vocab at 0x7f63d85f2190>,
#  u'handlerName': <gensim.models.word2vec.Vocab at 0x7f63d85f21d0>,
#  u'calendarCtrl': <gensim.models.word2vec.Vocab at 0x7f63b57a9850>,
#  u'wsParameters': <gensim.models.word2vec.Vocab at 0x7f63bb045f10>,
#  u'adfJson': <gensim.models.word2vec.Vocab at 0x7f63b2d01250>,
#  u'_jsver': <gensim.models.word2vec.Vocab at 0x7f63b2d012d0>,
#  u'getXY': <gensim.models.word2vec.Vocab at 0x7f63b2d01910>,
#  u'resetVideoState': <gensim.models.word2vec.Vocab at 0x7f63d85f2210>,
#  u'EBG': <gensim.models.word2vec.Vocab at 0x7f63b2d01a10>,
#  u'asapEnqueued': <gensim.models.word2vec.Vocab at 0x7f63b39df490>,
#  u'wrapCallback': <gensim.models.word2vec.Vocab at 0x7f63b2d017d0>,
#  u'getInitialClientOffset': <gensim.models.word2vec.Vocab at 0x7f63b2d01e50>,
#  u'_pc': <gensim.models.word2vec.Vocab at 0x7f63b27a1810>,
#  u'filterXSS': <gensim.models.word2vec.Vocab at 0x7f63dfee1810>,
#  u'getXO': <gensim.models.word2vec.Vocab at 0x7f63b2d01b90>,
#  u'Table': <gensim.models.word2vec.Vocab at 0x7f63d85f2290>,
#  u'zgites': <gensim.models.word2vec.Vocab at 0x7f63d85f22d0>,
#  u'hasMoreItems': <gensim.models.word2vec.Vocab at 0x7f63b73d2990>,
#  u'SomePromiseArray': <gensim.models.word2vec.Vocab at 0x7f63b2d01390>,
#  u'$CallbackDependencyManager2': <gensim.models.word2vec.Vocab at 0x7f63b57a9890>,
#  u'_result': <gensim.models.word2vec.Vocab at 0x7f63b2d01f50>,
#  u'customPosition': <gensim.models.word2vec.Vocab at 0x7f63d85f23d0>,
#  u'aPageStart': <gensim.models.word2vec.Vocab at 0x7f63b2d01c90>,
#  u'mobileDetectRules': <gensim.models.word2vec.Vocab at 0x7f63b2d01bd0>,
#  u'updateInputText': <gensim.models.word2vec.Vocab at 0x7f63b2d018d0>,
#  u'cookie_contents': <gensim.models.word2vec.Vocab at 0x7f63b2d01f10>,
#  u'isfixed': <gensim.models.word2vec.Vocab at 0x7f63caa774d0>,
#  u'SLUG_DETECTOR_CALLBACKS': <gensim.models.word2vec.Vocab at 0x7f63d85f24d0>,
#  u'p_l_id': <gensim.models.word2vec.Vocab at 0x7f63d85f2510>,
#  u'data_retention_changed_sig': <gensim.models.word2vec.Vocab at 0x7f63d85f2550>,
#  u'file_belongs_to_user': <gensim.models.word2vec.Vocab at 0x7f63b3824b10>,
#  u'unseenNetworkNotifCount': <gensim.models.word2vec.Vocab at 0x7f63b3824b90>,
#  u'_onArrowPress': <gensim.models.word2vec.Vocab at 0x7f63c69e56d0>,
#  u'finishDisplay': <gensim.models.word2vec.Vocab at 0x7f63b7366850>,
#  u'hai': <gensim.models.word2vec.Vocab at 0x7f63d85f2610>,
#  u'hak': <gensim.models.word2vec.Vocab at 0x7f63d85f2650>,
#  u'linkToResa': <gensim.models.word2vec.Vocab at 0x7f63b3824050>,
#  u'Jqf': <gensim.models.word2vec.Vocab at 0x7f63d85f26d0>,
#  u'haa': <gensim.models.word2vec.Vocab at 0x7f63d85f2710>,
#  u'hab': <gensim.models.word2vec.Vocab at 0x7f63d85f2750>,
#  u'hac': <gensim.models.word2vec.Vocab at 0x7f63d85f2790>,
#  u'Jqb': <gensim.models.word2vec.Vocab at 0x7f63b7366c50>,
#  u'scayt_uiTabs': <gensim.models.word2vec.Vocab at 0x7f63b7366890>,
#  u'haf': <gensim.models.word2vec.Vocab at 0x7f63d85f2810>,
#  u'Jqa': <gensim.models.word2vec.Vocab at 0x7f63d85f2850>,
#  u'handleResizeWindow': <gensim.models.word2vec.Vocab at 0x7f63d85f2890>,
#  u'cancelNextDblclick': <gensim.models.word2vec.Vocab at 0x7f63b7366d90>,
#  u'handleQuery': <gensim.models.word2vec.Vocab at 0x7f63d85f28d0>,
#  u'setSpace': <gensim.models.word2vec.Vocab at 0x7f63be36e150>,
#  u'has': <gensim.models.word2vec.Vocab at 0x7f63d85f2910>,
#  u'mapPx': <gensim.models.word2vec.Vocab at 0x7f63b3824c90>,
#  u'GetObjectSize': <gensim.models.word2vec.Vocab at 0x7f63b7283f50>,
#  u'user_profile_url': <gensim.models.word2vec.Vocab at 0x7f63bebff2d0>,
#  u'_featureId': <gensim.models.word2vec.Vocab at 0x7f63b7283750>,
#  u'REQUEST': <gensim.models.word2vec.Vocab at 0x7f63b38243d0>,
#  u'_serializeWithBuilder': <gensim.models.word2vec.Vocab at 0x7f63d85f2a50>,
#  u'advertiser_id': <gensim.models.word2vec.Vocab at 0x7f63b3824350>,
#  u'gvjs_mR': <gensim.models.word2vec.Vocab at 0x7f63bb82f950>,
#  u'eventTriggers': <gensim.models.word2vec.Vocab at 0x7f63b3824bd0>,
#  u'onFocusCapture': <gensim.models.word2vec.Vocab at 0x7f63b38249d0>,
#  u'proxyInfo': <gensim.models.word2vec.Vocab at 0x7f63b74ba050>,
#  u'LUMINANCE': <gensim.models.word2vec.Vocab at 0x7f63d85f2a90>,
#  u'ctime': <gensim.models.word2vec.Vocab at 0x7f63b3824150>,
#  u'portfolio_pagination_type': <gensim.models.word2vec.Vocab at 0x7f63d85f2ad0>,
#  u'source_interest': <gensim.models.word2vec.Vocab at 0x7f63b3824450>,
#  u'parentFragment': <gensim.models.word2vec.Vocab at 0x7f63b3824f10>,
#  u'attachDetachOlderEventListeners': <gensim.models.word2vec.Vocab at 0x7f63b3824650>,
#  u'activeIDPrivacy': <gensim.models.word2vec.Vocab at 0x7f63b9f34050>,
#  u'dateDisabled': <gensim.models.word2vec.Vocab at 0x7f63d85f2b10>,
#  u'buildMenu': <gensim.models.word2vec.Vocab at 0x7f63d85f2b50>,
#  u'_initializeAds': <gensim.models.word2vec.Vocab at 0x7f63b3824810>,
#  u'_handleTargetOver': <gensim.models.word2vec.Vocab at 0x7f63cab89990>,
#  u'stickyStyle': <gensim.models.word2vec.Vocab at 0x7f63b3824cd0>,
#  u'winningLength': <gensim.models.word2vec.Vocab at 0x7f63b721ad90>,
#  u'fancybox': <gensim.models.word2vec.Vocab at 0x7f63d85f2b90>,
#  u'p49': <gensim.models.word2vec.Vocab at 0x7f63b57a99d0>,
#  u'gvjs_ob': <gensim.models.word2vec.Vocab at 0x7f63b9f5e710>,
#  u'feature_sli_channel_priority': <gensim.models.word2vec.Vocab at 0x7f63b1acc8d0>,
#  u'setPlayStatus': <gensim.models.word2vec.Vocab at 0x7f63d85f2bd0>,
#  u'_global2': <gensim.models.word2vec.Vocab at 0x7f63d85f2c10>,
#  u'getDefaultAvatar': <gensim.models.word2vec.Vocab at 0x7f63b374db50>,
#  u'_saveDialog': <gensim.models.word2vec.Vocab at 0x7f63b74e1b10>,
#  u'createFilter': <gensim.models.word2vec.Vocab at 0x7f63c655da90>,
#  u'getUserFirstName': <gensim.models.word2vec.Vocab at 0x7f63b374d350>,
#  u'objLightbox': <gensim.models.word2vec.Vocab at 0x7f63b57a9a10>,
#  u'bottom': <gensim.models.word2vec.Vocab at 0x7f63d85f2c50>,
#  u'tmpArr': <gensim.models.word2vec.Vocab at 0x7f63b374d8d0>,
#  u'$normalizer': <gensim.models.word2vec.Vocab at 0x7f63b374d390>,
#  u'prepareMustache': <gensim.models.word2vec.Vocab at 0x7f63b374d2d0>,
#  u'Facebook': <gensim.models.word2vec.Vocab at 0x7f63d85f2c90>,
#  u'queryParamsFor': <gensim.models.word2vec.Vocab at 0x7f63b374ddd0>,
#  u'timelineController': <gensim.models.word2vec.Vocab at 0x7f63b374d510>,
#  u'mediaQueryIndex': <gensim.models.word2vec.Vocab at 0x7f63b374d890>,
#  u'lastState': <gensim.models.word2vec.Vocab at 0x7f63aede00d0>,
#  u'_parseSelector': <gensim.models.word2vec.Vocab at 0x7f63b39dfd90>,
#  u'dne': <gensim.models.word2vec.Vocab at 0x7f63b2fd76d0>,
#  u'hD': <gensim.models.word2vec.Vocab at 0x7f63b4b1ba10>,
#  u'getViewportWidth': <gensim.models.word2vec.Vocab at 0x7f63d85f2cd0>,
#  u'WrappedTextRange': <gensim.models.word2vec.Vocab at 0x7f63f70e5c90>,
#  u'bufferingTimeAccumulated': <gensim.models.word2vec.Vocab at 0x7f63b374d610>,
#  u'Gsa': <gensim.models.word2vec.Vocab at 0x7f63b726b8d0>,
#  u'Gsc': <gensim.models.word2vec.Vocab at 0x7f63b374d850>,
#  u'Gsb': <gensim.models.word2vec.Vocab at 0x7f63b374d9d0>,
#  u'Gse': <gensim.models.word2vec.Vocab at 0x7f63b2b68210>,
#  u'_defined': <gensim.models.word2vec.Vocab at 0x7f63b2b68390>,
#  u'sNb': <gensim.models.word2vec.Vocab at 0x7f63f70e5d10>,
#  u'integersOnly': <gensim.models.word2vec.Vocab at 0x7f63d85f2dd0>,
#  u'_calculateCurrentDimensions': <gensim.models.word2vec.Vocab at 0x7f63d85f2e10>,
#  u'elSuggestion': <gensim.models.word2vec.Vocab at 0x7f63b2b685d0>,
#  u'$trackEvent': <gensim.models.word2vec.Vocab at 0x7f63b72b9990>,
#  u'Font': <gensim.models.word2vec.Vocab at 0x7f63b2b68250>,
#  u'_latestSavedState': <gensim.models.word2vec.Vocab at 0x7f63b2b689d0>,
#  u'BLACKLIST': <gensim.models.word2vec.Vocab at 0x7f63b2b68350>,
#  u'FJc': <gensim.models.word2vec.Vocab at 0x7f63b2b688d0>,
#  u'FJb': <gensim.models.word2vec.Vocab at 0x7f63b2b68810>,
#  u'get_address_coordinates': <gensim.models.word2vec.Vocab at 0x7f63b7061990>,
#  u'disableDeduping': <gensim.models.word2vec.Vocab at 0x7f63f70e5d90>,
#  u'removeOverlappingEntities': <gensim.models.word2vec.Vocab at 0x7f63b2b68490>,
#  u'inputGroup': <gensim.models.word2vec.Vocab at 0x7f63b2b68450>,
#  u'interest_name': <gensim.models.word2vec.Vocab at 0x7f63b2b68710>,
#  u'shouldReject': <gensim.models.word2vec.Vocab at 0x7f63b8a72b10>,
#  u'_getWidthOfChar': <gensim.models.word2vec.Vocab at 0x7f63d85f2f90>,
#  u'createCache': <gensim.models.word2vec.Vocab at 0x7f63d85f2fd0>,
#  u'attrNames': <gensim.models.word2vec.Vocab at 0x7f63b2b68910>,
#  u'interactionsCallbacks': <gensim.models.word2vec.Vocab at 0x7f63b2b687d0>,
#  u'originalWidth': <gensim.models.word2vec.Vocab at 0x7f63b2b68c50>,
#  u'MIN_VISIBLE_ITMES': <gensim.models.word2vec.Vocab at 0x7f63b2b68b50>,
#  u'fabric': <gensim.models.word2vec.Vocab at 0x7f63b2b68f10>,
#  u'_findPageTags': <gensim.models.word2vec.Vocab at 0x7f63b2b68c10>,
#  u'ActivityUpdateValueType': <gensim.models.word2vec.Vocab at 0x7f63b717d6d0>,
#  u'FOCUSABLE': <gensim.models.word2vec.Vocab at 0x7f63b2b68dd0>,
#  u'descriptionHtml': <gensim.models.word2vec.Vocab at 0x7f63b2b68f50>,
#  u'flyoutOptions': <gensim.models.word2vec.Vocab at 0x7f63b71d4ad0>,
#  u'removeRows': <gensim.models.word2vec.Vocab at 0x7f63b2b68d50>,
#  u'jLb': <gensim.models.word2vec.Vocab at 0x7f6401da40d0>,
#  u'$secondaryItems': <gensim.models.word2vec.Vocab at 0x7f63b2b68950>,
#  u'_initializeThumbs': <gensim.models.word2vec.Vocab at 0x7f6401da4110>,
#  u'pathEndIndex': <gensim.models.word2vec.Vocab at 0x7f6401da4150>,
#  u'turnOffSpinner': <gensim.models.word2vec.Vocab at 0x7f63b57a9c50>,
#  u's8a': <gensim.models.word2vec.Vocab at 0x7f6401da41d0>,
#  u's8d': <gensim.models.word2vec.Vocab at 0x7f6401da4210>,
#  u'_getOffset': <gensim.models.word2vec.Vocab at 0x7f63b2b682d0>,
#  u'stayOpen': <gensim.models.word2vec.Vocab at 0x7f6401da4250>,
#  u'calculatedDependencies': <gensim.models.word2vec.Vocab at 0x7f6401da4290>,
#  u'imageDimensions': <gensim.models.word2vec.Vocab at 0x7f63c1708550>,
#  u'getAttributionInfo': <gensim.models.word2vec.Vocab at 0x7f6401da42d0>,
#  u'GEOGCS': <gensim.models.word2vec.Vocab at 0x7f6401da4310>,
#  u'_setSharedInvitesIntoModel': <gensim.models.word2vec.Vocab at 0x7f63ad03a1d0>,
#  u'chrdefcheckbox': <gensim.models.word2vec.Vocab at 0x7f6401da4390>,
#  u'$currentcaption': <gensim.models.word2vec.Vocab at 0x7f6401da43d0>,
#  u'pluginQueue': <gensim.models.word2vec.Vocab at 0x7f6401da4410>,
#  u'bigEnd': <gensim.models.word2vec.Vocab at 0x7f63b2b68fd0>,
#  u'_initNode': <gensim.models.word2vec.Vocab at 0x7f63b1024450>,
#  u'handleForbidden': <gensim.models.word2vec.Vocab at 0x7f6401da4490>,
#  u'setCollapsible': <gensim.models.word2vec.Vocab at 0x7f6401da44d0>,
#  u'fullsubopen': <gensim.models.word2vec.Vocab at 0x7f63b2b68c90>,
#  u'Ura': <gensim.models.word2vec.Vocab at 0x7f63f5d744d0>,
#  u'lenMove': <gensim.models.word2vec.Vocab at 0x7f6401da4550>,
# ...
#  u'ariaHidden': <gensim.models.word2vec.Vocab at 0x7f6401da4b90>,
#  u'_count': <gensim.models.word2vec.Vocab at 0x7f6401da4bd0>,
#  u'commSwf': <gensim.models.word2vec.Vocab at 0x7f63be3a8f10>,
#  u'JetpackLikesWidgetQueueHandler': <gensim.models.word2vec.Vocab at 0x7f63b38c8e90>,
#  u'is_retina': <gensim.models.word2vec.Vocab at 0x7f63b32208d0>,
#  u'hasAvis': <gensim.models.word2vec.Vocab at 0x7f63b3220310>,
#  u'pasteFilter': <gensim.models.word2vec.Vocab at 0x7f63b3220dd0>,
#  u'activeHandleIdx': <gensim.models.word2vec.Vocab at 0x7f6401da4c50>,
#  u'childs': <gensim.models.word2vec.Vocab at 0x7f6401da4c90>,
#  u'chain': <gensim.models.word2vec.Vocab at 0x7f63b3220410>,
#  u'service_name': <gensim.models.word2vec.Vocab at 0x7f6401da4cd0>,
#  u'maxCount': <gensim.models.word2vec.Vocab at 0x7f63b57a9e50>,
#  u'onTimeUpdateCapture': <gensim.models.word2vec.Vocab at 0x7f63b32207d0>,
#  u'oldWidth': <gensim.models.word2vec.Vocab at 0x7f63b7721b10>,
#  u'initiatorType': <gensim.models.word2vec.Vocab at 0x7f63b3220950>,
#  u'search_string': <gensim.models.word2vec.Vocab at 0x7f63b3220ed0>,
#  u'__trcJSONify': <gensim.models.word2vec.Vocab at 0x7f63b3220ad0>,
#  u'slides_container': <gensim.models.word2vec.Vocab at 0x7f6401da4d50>,
#  u'retargetingPixels': <gensim.models.word2vec.Vocab at 0x7f63b3220c50>,
#  u'privateAddMentalistAction': <gensim.models.word2vec.Vocab at 0x7f63b3220d10>,
#  u'_enableDatepicker': <gensim.models.word2vec.Vocab at 0x7f63b3220d90>,
#  u'multi_expand': <gensim.models.word2vec.Vocab at 0x7f6401da4dd0>,
#  u'appendSuccess': <gensim.models.word2vec.Vocab at 0x7f6401da4e10>,
#  u'QUOTE': <gensim.models.word2vec.Vocab at 0x7f6401da4e50>,
#  u'_savedProps': <gensim.models.word2vec.Vocab at 0x7f6401da4e90>,
#  u'pagerFirstSelector': <gensim.models.word2vec.Vocab at 0x7f63b3220090>,
#  u'AudioSegmentStream': <gensim.models.word2vec.Vocab at 0x7f63b3220390>,
#  u'page_name': <gensim.models.word2vec.Vocab at 0x7f63b6c3d610>,
#  u'timerInterval': <gensim.models.word2vec.Vocab at 0x7f6401da4f10>,
#  u'baseHasDuplicate': <gensim.models.word2vec.Vocab at 0x7f63b3091390>,
#  u'dataQuery': <gensim.models.word2vec.Vocab at 0x7f63b3091450>,
#  u'is_submission': <gensim.models.word2vec.Vocab at 0x7f6401da4f50>,
#  u'separator_before': <gensim.models.word2vec.Vocab at 0x7f63b6af45d0>,
#  u'_zimIndex': <gensim.models.word2vec.Vocab at 0x7f63b6af48d0>,
#  u'createTimeRange': <gensim.models.word2vec.Vocab at 0x7f6411505050>,
#  u'images': <gensim.models.word2vec.Vocab at 0x7f63b4ac7d10>,
#  u'bidRpmCurr': <gensim.models.word2vec.Vocab at 0x7f63b3091dd0>,
#  u'onHtmlFailure': <gensim.models.word2vec.Vocab at 0x7f63b30910d0>,
#  u'WUb': <gensim.models.word2vec.Vocab at 0x7f64115050d0>,
#  u'_parseFnName': <gensim.models.word2vec.Vocab at 0x7f63b3091610>,
#  u'uniqueTrace': <gensim.models.word2vec.Vocab at 0x7f6411505110>,
#  u'getTimeStamp': <gensim.models.word2vec.Vocab at 0x7f63b3091250>,
#  u'exact': <gensim.models.word2vec.Vocab at 0x7f63b30915d0>,
#  u'minute': <gensim.models.word2vec.Vocab at 0x7f63b30913d0>,
#  u'win_ssb_version_minor': <gensim.models.word2vec.Vocab at 0x7f63b3091b90>,
#  u'dailyHours': <gensim.models.word2vec.Vocab at 0x7f63b3091690>,
#  u'cachePoisoning': <gensim.models.word2vec.Vocab at 0x7f63abc6fbd0>,
#  u'xMouse': <gensim.models.word2vec.Vocab at 0x7f63b3091c50>,
#  u'khtml': <gensim.models.word2vec.Vocab at 0x7f63b2d520d0>,
#  u'enableOnFocus': <gensim.models.word2vec.Vocab at 0x7f63b2d52890>,
#  u'_isToggled': <gensim.models.word2vec.Vocab at 0x7f6411505190>,
#  u'topbarContainer': <gensim.models.word2vec.Vocab at 0x7f63b2d529d0>,
#  u'fnDone': <gensim.models.word2vec.Vocab at 0x7f63b2d52cd0>,
#  u'postEvent': <gensim.models.word2vec.Vocab at 0x7f6411505210>,
#  u'autoplaySpeed': <gensim.models.word2vec.Vocab at 0x7f6411505250>,
#  u'resetControls': <gensim.models.word2vec.Vocab at 0x7f63b2d52490>,
#  u'M$': <gensim.models.word2vec.Vocab at 0x7f63b6a47990>,
#  u'isDestroying': <gensim.models.word2vec.Vocab at 0x7f63b2d52dd0>,
#  u'conditionShow': <gensim.models.word2vec.Vocab at 0x7f6411505290>,
#  u'onScrollMove': <gensim.models.word2vec.Vocab at 0x7f64115052d0>,
#  u'getPositionValue': <gensim.models.word2vec.Vocab at 0x7f63b2d52a90>,
#  u'M5': <gensim.models.word2vec.Vocab at 0x7f63b2d52e10>,
#  u'M4': <gensim.models.word2vec.Vocab at 0x7f63b2d527d0>,
#  u'M7': <gensim.models.word2vec.Vocab at 0x7f63b2d52ad0>,
#  u'M6': <gensim.models.word2vec.Vocab at 0x7f63b2c05290>,
#  u'TRACKING_SCRIPT': <gensim.models.word2vec.Vocab at 0x7f63b2c05810>,
#  u'M0': <gensim.models.word2vec.Vocab at 0x7f63b2c05990>,
#  u'M3': <gensim.models.word2vec.Vocab at 0x7f63b2c057d0>,
#  u'M2': <gensim.models.word2vec.Vocab at 0x7f63b2c05610>,
#  u'playerAspectRatio': <gensim.models.word2vec.Vocab at 0x7f63b2c05dd0>,
#  u'M9': <gensim.models.word2vec.Vocab at 0x7f63b2c05ed0>,
#  u'M8': <gensim.models.word2vec.Vocab at 0x7f63b2c05450>,
#  u'is3d': <gensim.models.word2vec.Vocab at 0x7f63b2c05fd0>,
#  u'delurkWinPhone': <gensim.models.word2vec.Vocab at 0x7f63b57a9f50>,
#  u'ReadZipEntries': <gensim.models.word2vec.Vocab at 0x7f63afbdb050>,
#  u'$flyoutWindow': <gensim.models.word2vec.Vocab at 0x7f63b19adcd0>,
#  u'write_wmc_Layer': <gensim.models.word2vec.Vocab at 0x7f6411505310>,
#  u'zra': <gensim.models.word2vec.Vocab at 0x7f63b2c05910>,
#  u'cssFn': <gensim.models.word2vec.Vocab at 0x7f63b2c05a10>,
#  u'_LOG_PRI': <gensim.models.word2vec.Vocab at 0x7f63b2c05f90>,
#  u'Me': <gensim.models.word2vec.Vocab at 0x7f63b2c05890>,
#  u'Md': <gensim.models.word2vec.Vocab at 0x7f63b2c05c10>,
#  u'Mg': <gensim.models.word2vec.Vocab at 0x7f63b2c05510>,
#  u'Mf': <gensim.models.word2vec.Vocab at 0x7f63b2df7810>,
#  u'Ma': <gensim.models.word2vec.Vocab at 0x7f63b2df7a90>,
#  u'newEvent': <gensim.models.word2vec.Vocab at 0x7f63b57a9f90>,
#  u'Mc': <gensim.models.word2vec.Vocab at 0x7f63b2df7890>,
#  u'Mb': <gensim.models.word2vec.Vocab at 0x7f63b2df7650>,
#  u'durationHours': <gensim.models.word2vec.Vocab at 0x7f63b2df78d0>,
#  u'Ml': <gensim.models.word2vec.Vocab at 0x7f63b2df7190>,
#  u'Mo': <gensim.models.word2vec.Vocab at 0x7f63b2df7bd0>,
#  u'Mn': <gensim.models.word2vec.Vocab at 0x7f63b2df79d0>,
#  u'Mi': <gensim.models.word2vec.Vocab at 0x7f63b2df7cd0>,
#  u'Mh': <gensim.models.word2vec.Vocab at 0x7f63b2df76d0>,
#  u'Mk': <gensim.models.word2vec.Vocab at 0x7f63b2df7610>,
#  u'Mj': <gensim.models.word2vec.Vocab at 0x7f63b2df7590>,
#  u'Mu': <gensim.models.word2vec.Vocab at 0x7f63b2df7d10>,
#  u'Mt': <gensim.models.word2vec.Vocab at 0x7f63b2df7910>,
#  u'Mw': <gensim.models.word2vec.Vocab at 0x7f63b2df7e10>,
#  u'Mv': <gensim.models.word2vec.Vocab at 0x7f63b2df7a50>,
#  u'Mq': <gensim.models.word2vec.Vocab at 0x7f63b2df7310>,
#  u'Mp': <gensim.models.word2vec.Vocab at 0x7f63b2df7ed0>,
#  u'Ms': <gensim.models.word2vec.Vocab at 0x7f63b2df7a10>,
#  u'defineSlot': <gensim.models.word2vec.Vocab at 0x7f63b6857e10>,
#  u'httpCall': <gensim.models.word2vec.Vocab at 0x7f6411505510>,
#  u'jwSetVolume': <gensim.models.word2vec.Vocab at 0x7f63b6857cd0>,
#  u'My': <gensim.models.word2vec.Vocab at 0x7f63b2df7550>,
#  u'Mx': <gensim.models.word2vec.Vocab at 0x7f63b2a29410>,
#  u'Mz': <gensim.models.word2vec.Vocab at 0x7f63b2a296d0>,
#  u'ME': <gensim.models.word2vec.Vocab at 0x7f63b2a29850>,
#  u'MD': <gensim.models.word2vec.Vocab at 0x7f63b2a29210>,
#  u'MG': <gensim.models.word2vec.Vocab at 0x7f63b2a29590>,
#  u'MF': <gensim.models.word2vec.Vocab at 0x7f63b2a29950>,
#  u'MA': <gensim.models.word2vec.Vocab at 0x7f63b2a29f50>,
#  u'MC': <gensim.models.word2vec.Vocab at 0x7f63b2a299d0>,
#  u'MB': <gensim.models.word2vec.Vocab at 0x7f63b2a29e50>,
#  u'MM': <gensim.models.word2vec.Vocab at 0x7f63b2a298d0>,
#  u'ML': <gensim.models.word2vec.Vocab at 0x7f63b2a29bd0>,
#  u'MO': <gensim.models.word2vec.Vocab at 0x7f63b2a29890>,
#  u'MN': <gensim.models.word2vec.Vocab at 0x7f63b2a294d0>,
#  u'MI': <gensim.models.word2vec.Vocab at 0x7f63b2a29110>,
#  u'MH': <gensim.models.word2vec.Vocab at 0x7f63b2a29d10>,
#  u'MK': <gensim.models.word2vec.Vocab at 0x7f63b2a29490>,
#  u'MJ': <gensim.models.word2vec.Vocab at 0x7f63b2a29710>,
#  u'MU': <gensim.models.word2vec.Vocab at 0x7f63b2a29a90>,
#  u'MT': <gensim.models.word2vec.Vocab at 0x7f63b2a29790>,
#  u'MW': <gensim.models.word2vec.Vocab at 0x7f63b2a29d90>,
#  u'MV': <gensim.models.word2vec.Vocab at 0x7f63b89b8090>,
#  u'MQ': <gensim.models.word2vec.Vocab at 0x7f63b89b8790>,
#  u'MP': <gensim.models.word2vec.Vocab at 0x7f63b89b8050>,
#  u'MS': <gensim.models.word2vec.Vocab at 0x7f63b89b8710>,
#  u'MR': <gensim.models.word2vec.Vocab at 0x7f63b2acb510>,
#  u'visibleChild': <gensim.models.word2vec.Vocab at 0x7f63b1024710>,
#  u'M_': <gensim.models.word2vec.Vocab at 0x7f63b2acb490>,
#  u'MY': <gensim.models.word2vec.Vocab at 0x7f63b2acb650>,
#  u'MX': <gensim.models.word2vec.Vocab at 0x7f63b2acb950>,
#  u'containerHoverID': <gensim.models.word2vec.Vocab at 0x7f64115057d0>,
#  u'MZ': <gensim.models.word2vec.Vocab at 0x7f63b2acb0d0>,
#  u'sAdDivName': <gensim.models.word2vec.Vocab at 0x7f63b2acb390>,
#  u'bulletActiveClass': <gensim.models.word2vec.Vocab at 0x7f64115058d0>,
#  u'bkwd': <gensim.models.word2vec.Vocab at 0x7f6411505910>,
#  u'mouseOutUtility': <gensim.models.word2vec.Vocab at 0x7f6411505950>,
#  u'setQueryAddition': <gensim.models.word2vec.Vocab at 0x7f63b2acb350>,
#  u'inRegion': <gensim.models.word2vec.Vocab at 0x7f63b682b690>,
#  u'AnimMgr': <gensim.models.word2vec.Vocab at 0x7f63b2acb250>,
#  u'usingCSS': <gensim.models.word2vec.Vocab at 0x7f63b2acb450>,
#  u'isZeroDecimalCurrency': <gensim.models.word2vec.Vocab at 0x7f63b2acb7d0>,
#  u'bundleId': <gensim.models.word2vec.Vocab at 0x7f63b682bfd0>,
#  u'errorCallbacks': <gensim.models.word2vec.Vocab at 0x7f63b2acb610>,
#  u'maxPromotions': <gensim.models.word2vec.Vocab at 0x7f63b88ff850>,
#  u'hasDOM': <gensim.models.word2vec.Vocab at 0x7f63cdea8f10>,
#  u'La': <gensim.models.word2vec.Vocab at 0x7f6411505a10>,
#  u'videoid': <gensim.models.word2vec.Vocab at 0x7f63b2acb1d0>,
#  u'sourceEvent': <gensim.models.word2vec.Vocab at 0x7f6411505a50>,
#  u'mYb': <gensim.models.word2vec.Vocab at 0x7f63b32f52d0>,
#  u'volumeBarDimensions': <gensim.models.word2vec.Vocab at 0x7f6411505a90>,
#  u'twitterAccount': <gensim.models.word2vec.Vocab at 0x7f6411505b10>,
#  u'publicApi': <gensim.models.word2vec.Vocab at 0x7f6411505b90>,
#  u'getExperiments': <gensim.models.word2vec.Vocab at 0x7f63bf436250>,
#  u'idPrefix': <gensim.models.word2vec.Vocab at 0x7f63b2acbc90>,
#  u'requestURL': <gensim.models.word2vec.Vocab at 0x7f63b2acb890>,
#  u'Lk': <gensim.models.word2vec.Vocab at 0x7f63c9f2b490>,
#  u'CONTENT': <gensim.models.word2vec.Vocab at 0x7f63b2acb710>,
#  u'updateChartXML': <gensim.models.word2vec.Vocab at 0x7f63f74c0450>,
#  u'hoverContext': <gensim.models.word2vec.Vocab at 0x7f63b2acbe50>,
#  u'Lh': <gensim.models.word2vec.Vocab at 0x7f6411505bd0>,
#  u'buildHeaderRight': <gensim.models.word2vec.Vocab at 0x7f63bb732290>,
#  u'wvb': <gensim.models.word2vec.Vocab at 0x7f6411505c10>,
#  u'Yba': <gensim.models.word2vec.Vocab at 0x7f6411505c50>,
#  u'wizardryConfig': <gensim.models.word2vec.Vocab at 0x7f63b66d6710>,
#  u'cardinality': <gensim.models.word2vec.Vocab at 0x7f63b2acbb90>,
#  u'HtmlMediaElementShim': <gensim.models.word2vec.Vocab at 0x7f63b2acbed0>,
#  u'JJb': <gensim.models.word2vec.Vocab at 0x7f63ca029650>,
#  u'JJa': <gensim.models.word2vec.Vocab at 0x7f63b2acb6d0>,
#  u'wve': <gensim.models.word2vec.Vocab at 0x7f6411505cd0>,
#  u'sgGetEventTarget': <gensim.models.word2vec.Vocab at 0x7f6411505d10>,
#  u'lowercase': <gensim.models.word2vec.Vocab at 0x7f6411505d50>,
#  u'defaultVariant': <gensim.models.word2vec.Vocab at 0x7f6411505d90>,
#  u'formEventDelegate': <gensim.models.word2vec.Vocab at 0x7f63b2acb3d0>,
#  u'tweetMonthInt': <gensim.models.word2vec.Vocab at 0x7f6411505dd0>,
#  u'memTarget': <gensim.models.word2vec.Vocab at 0x7f6411505e10>,
#  u'srcIndex': <gensim.models.word2vec.Vocab at 0x7f63b2acba10>,
#  u'getFileExtension': <gensim.models.word2vec.Vocab at 0x7f63b4dc0390>,
#  u'following': <gensim.models.word2vec.Vocab at 0x7f63b2973c10>,
#  u'campaignMedium': <gensim.models.word2vec.Vocab at 0x7f63b2973110>,
#  u'getItemExternalTrackingURLsList': <gensim.models.word2vec.Vocab at 0x7f63b3437110>,
#  u'_limits': <gensim.models.word2vec.Vocab at 0x7f6411505e90>,
#  u'boundaryIsStart': <gensim.models.word2vec.Vocab at 0x7f6411505ed0>,
#  u'isBig': <gensim.models.word2vec.Vocab at 0x7f6411505f10>,
#  u'notifyWasDismissed': <gensim.models.word2vec.Vocab at 0x7f63b2973590>,
#  u'seoUnauthExperiments': <gensim.models.word2vec.Vocab at 0x7f6411505f90>,
#  u'buildNumberOption': <gensim.models.word2vec.Vocab at 0x7f6411505fd0>,
#  u'CSSRule': <gensim.models.word2vec.Vocab at 0x7f63b2973b10>,
#  u'validateDay': <gensim.models.word2vec.Vocab at 0x7f63afe45390>,
#  u'noZoomMetaTag': <gensim.models.word2vec.Vocab at 0x7f640338f090>,
#  u'skipOffset': <gensim.models.word2vec.Vocab at 0x7f640338f0d0>,
#  u'extendToEQ': <gensim.models.word2vec.Vocab at 0x7f640338f110>,
#  u'getScrollParent': <gensim.models.word2vec.Vocab at 0x7f63b2973350>,
#  u'loadingHelper': <gensim.models.word2vec.Vocab at 0x7f63b2973a50>,
#  u'ReactUpdateQueue': <gensim.models.word2vec.Vocab at 0x7f63b2973390>,
#  u'related_pins_feed': <gensim.models.word2vec.Vocab at 0x7f63b2973050>,
#  u'randomColor': <gensim.models.word2vec.Vocab at 0x7f63b2973ad0>,
#  u'Ly': <gensim.models.word2vec.Vocab at 0x7f640338f210>,
#  u'tiffHeader': <gensim.models.word2vec.Vocab at 0x7f63b1cd0d90>,
#  u'isDdInT3': <gensim.models.word2vec.Vocab at 0x7f63cf3f24d0>,
#  u'Vbc': <gensim.models.word2vec.Vocab at 0x7f63b2973b90>,
#  u'nb_s': <gensim.models.word2vec.Vocab at 0x7f63b662a6d0>,
#  u'onTimeoutPause': <gensim.models.word2vec.Vocab at 0x7f63b2973490>,
#  u'GetQS': <gensim.models.word2vec.Vocab at 0x7f63b3437190>,
#  u'getItems': <gensim.models.word2vec.Vocab at 0x7f63b2973d50>,
#  u'_lastID': <gensim.models.word2vec.Vocab at 0x7f63b662a990>,
#  u'closePortal': <gensim.models.word2vec.Vocab at 0x7f640338f290>,
#  u'astBuilder': <gensim.models.word2vec.Vocab at 0x7f63b662a090>,
#  u'filter_placeholder': <gensim.models.word2vec.Vocab at 0x7f63b29736d0>,
#  u'symbolAttr': <gensim.models.word2vec.Vocab at 0x7f63b2973710>,
#  u'message_target': <gensim.models.word2vec.Vocab at 0x7f63b34371d0>,
#  u'Paa': <gensim.models.word2vec.Vocab at 0x7f63ca974750>,
#  u'slideController': <gensim.models.word2vec.Vocab at 0x7f63b2973f90>,
#  u'_sandCrawlerMargin': <gensim.models.word2vec.Vocab at 0x7f640338f350>,
#  u'getContainerRect': <gensim.models.word2vec.Vocab at 0x7f63b2973e10>,
#  u'majorDirectInbox': <gensim.models.word2vec.Vocab at 0x7f640338f3d0>,
#  u'setPrefixCount': <gensim.models.word2vec.Vocab at 0x7f63b65fe490>,
#  u'changed_name_sig': <gensim.models.word2vec.Vocab at 0x7f640338f410>,
#  u'valueMethod': <gensim.models.word2vec.Vocab at 0x7f63b2973a10>,
#  u'directCallRules': <gensim.models.word2vec.Vocab at 0x7f63b4dc0a10>,
#  u'check_mime_type': <gensim.models.word2vec.Vocab at 0x7f63b2973450>,
#  u'KM_SKIP_FORM_FIELDS': <gensim.models.word2vec.Vocab at 0x7f63b2973f10>,
#  u'visual_edit': <gensim.models.word2vec.Vocab at 0x7f640338f450>,
#  u'AmazonPopoverImages': <gensim.models.word2vec.Vocab at 0x7f640338f490>,
#  u'chartRangeMin': <gensim.models.word2vec.Vocab at 0x7f63b2973fd0>,
#  u'LIM': <gensim.models.word2vec.Vocab at 0x7f63b2973690>,
#  u'filterDisabled': <gensim.models.word2vec.Vocab at 0x7f640338f550>,
#  u'getHistoryData': <gensim.models.word2vec.Vocab at 0x7f640338f590>,
#  u'hideMenuHandler': <gensim.models.word2vec.Vocab at 0x7f63b29734d0>,
#  u'y_bottom': <gensim.models.word2vec.Vocab at 0x7f63b2973210>,
#  u'INITIALIZE': <gensim.models.word2vec.Vocab at 0x7f63b2973890>,
#  u'canOpenTab': <gensim.models.word2vec.Vocab at 0x7f63b2973ed0>,
#  u'findNodesHavingCssClass': <gensim.models.word2vec.Vocab at 0x7f63b391c210>,
#  u'LId': <gensim.models.word2vec.Vocab at 0x7f63bf2ab750>,
#  u'jig': <gensim.models.word2vec.Vocab at 0x7f63b391cb90>,
#  u'jid': <gensim.models.word2vec.Vocab at 0x7f63b391ce10>,
#  u'yGd': <gensim.models.word2vec.Vocab at 0x7f640338f690>,
#  u'disconnect': <gensim.models.word2vec.Vocab at 0x7f640338f6d0>,
#  u'chatVersion': <gensim.models.word2vec.Vocab at 0x7f640338f710>,
#  u'LIb': <gensim.models.word2vec.Vocab at 0x7f63b65122d0>,
#  u'jia': <gensim.models.word2vec.Vocab at 0x7f63b391c7d0>,
#  ...}

# %%
model.most_similar(positive="createElement")
# Out:
# [(u'appendChild', 0.619277834892273),
#  (u'createTextNode', 0.604455292224884),
#  (u'createText', 0.576920211315155),
#  (u'trcGetChildByClassName', 0.5707101225852966),
#  (u'body', 0.5525359511375427),
#  (u'$MessengerVideoPlayer1', 0.5305860042572021),
#  (u'waitingScripts', 0.52565997838974),
#  (u'byUrl', 0.5249150991439819),
#  (u'currentScript', 0.5237258672714233),
#  (u'safeFragment', 0.5164779424667358)]

# %%
model.most_similar("ajax")
# Out:
# [(u'getJSON', 0.7115294337272644),
#  (u'success', 0.710839033126831),
#  (u'dataType', 0.6964539289474487),
#  (u'errorCb', 0.6803914308547974),
#  (u'posturl', 0.6754568815231323),
#  (u'url', 0.6729618310928345),
#  (u'rfsh', 0.6606138944625854),
#  (u'ajaxOptions', 0.6587070226669312),
#  (u'dataParam', 0.6557852029800415),
#  (u'$cf', 0.6461215019226074)]

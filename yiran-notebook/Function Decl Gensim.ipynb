# %%
# imports and setup
import json
from itertools import islice, imap

# %% [markdown]
# ## Helper Functions

# %%
def parse_ast_line(line, sep="\t"):
    script_id, ast_json = line.strip().split(sep, 1)
    return script_id, json.loads(ast_json)
      
def parse_ast(lines):
    for line in lines:
        if len(line) > 1:
            yield parse_ast_line(line)
            
def filter_ast_by_type(ast, type):
    if _is_node_of_type(ast, type):
        yield ast
    elif isinstance(ast, dict):
        for _, val in ast.iteritems():
            for x in filter_ast_by_type(val, type):
                yield x
    elif isinstance(ast, list):
        for val in ast:
            for x in filter_ast_by_type(val, type):
                yield x
      
def _is_node_of_type(d, type):
    return isinstance(d, dict) and \
           "type" in d and \
           d["type"] == type

# %% [markdown]
# ## Filter AST nodes with type of Identifier
#
# Here, try one program, and print out all its identifiers.

# %%
AST_FILE = '../lang/ast.json11'

with open(AST_FILE, 'r') as f:
    _, one_program = parse_ast(f.readlines()).next()

# %%
list(filter_ast_by_type(one_program, "Identifier"))[:10]
# Out:
# [{u'name': u'Number', u'type': u'Identifier'},
#  {u'name': u'$n', u'type': u'Identifier'},
#  {u'name': u'$n', u'type': u'Identifier'},
#  {u'name': u'locale', u'type': u'Identifier'},
#  {u'name': u'Drupal', u'type': u'Identifier'},
#  {u'name': u'renderItem', u'type': u'Identifier'},
#  {u'name': u'apachesolr_autocomplete', u'type': u'Identifier'},
#  {u'name': u'Drupal', u'type': u'Identifier'},
#  {u'name': u'_renderItem', u'type': u'Identifier'},
#  {u'name': u'data', u'type': u'Identifier'}]

# %% [markdown]
# ## Naive word2vec
#
# Use identifier names as vocabulary.

# %%
def load_sentences(filename, sentences):
    with open(filename, 'r') as f:
        for _, program in parse_ast(f.readlines()):
            sentence = filter_ast_by_type(program, type="Identifier")
            sentence = list( imap(lambda d:d["name"], sentence) )
            sentences.append(sentence)
    return sentences

# %%
import sys
paths = ['/home/yiran/.local/lib/python2.7/site-packages/PyOpenGL-3.0.1-py2.7.egg', '/home/yiran/.local/lib/python2.7/site-packages/ftputil-3.2-py2.7.egg', '/home/yiran/anaconda/lib/python27.zip', '/home/yiran/anaconda/lib/python2.7', '/home/yiran/anaconda/lib/python2.7/plat-linux2', '/home/yiran/anaconda/lib/python2.7/lib-tk', '/home/yiran/anaconda/lib/python2.7/lib-old', '/home/yiran/anaconda/lib/python2.7/lib-dynload', '/home/yiran/.local/lib/python2.7/site-packages', '/home/yiran/anaconda/lib/python2.7/site-packages/Sphinx-1.3.5-py2.7.egg', '/home/yiran/anaconda/lib/python2.7/site-packages/setuptools-19.6.2-py2.7.egg', '/home/yiran/anaconda/lib/python2.7/site-packages', '/home/yiran/anaconda/lib/python2.7/site-packages/cryptography-1.0.2-py2.7-linux-x86_64.egg']
for p in paths:
    sys.path.insert(0, p)

# %%
from gensim.models.word2vec import Word2Vec
import glob

# %%
sentences = []
for f in glob.glob("../lang/ast.json*"):
    print ("Loading %s" % f)
    load_sentences(f, sentences)
# Out:
# Loading ../lang/ast.json26
# Loading ../lang/ast.json45
# Loading ../lang/ast.json40
# Loading ../lang/ast.json36
# Loading ../lang/ast.json18
# Loading ../lang/ast.json02
# Loading ../lang/ast.json38
# Loading ../lang/ast.json47
# Loading ../lang/ast.json53
# Loading ../lang/ast.json66
# Loading ../lang/ast.json72
# Loading ../lang/ast.json04
# Loading ../lang/ast.json48

# %%
model = Word2Vec(sentences, size=100, window=5, min_count=5, workers=4)

# %%
model.vocab
# Out:
# {u'onMemberItemClick': <gensim.models.word2vec.Vocab at 0x7f6402ee3c90>,
#  u'wrapperElement': <gensim.models.word2vec.Vocab at 0x7f63f97ea650>,
#  u'canModerate': <gensim.models.word2vec.Vocab at 0x7f63f97ea290>,
#  u'u0': <gensim.models.word2vec.Vocab at 0x7f63fedd9350>,
#  u'_jQuery': <gensim.models.word2vec.Vocab at 0x7f6400582c90>,
#  u'handleLoginClick': <gensim.models.word2vec.Vocab at 0x7f63ff4a3610>,
#  u'removeMap': <gensim.models.word2vec.Vocab at 0x7f63fc188cd0>,
#  u'show_description': <gensim.models.word2vec.Vocab at 0x7f63ffc79ad0>,
#  u'canUserCreateAndDeleteUserGroups': <gensim.models.word2vec.Vocab at 0x7f64007e5d90>,
#  u'callbackHash': <gensim.models.word2vec.Vocab at 0x7f641ae31650>,
#  u'jqDeferred': <gensim.models.word2vec.Vocab at 0x7f64005827d0>,
#  u'$prevHtml': <gensim.models.word2vec.Vocab at 0x7f6400582190>,
#  u'yellow': <gensim.models.word2vec.Vocab at 0x7f63f97eadd0>,
#  u'factory': <gensim.models.word2vec.Vocab at 0x7f641ef6d1d0>,
#  u'DELAY': <gensim.models.word2vec.Vocab at 0x7f63f97eae90>,
#  u'topSeeking': <gensim.models.word2vec.Vocab at 0x7f63f9727e50>,
#  u'createElementNSPlus': <gensim.models.word2vec.Vocab at 0x7f6400582690>,
#  u'is_open': <gensim.models.word2vec.Vocab at 0x7f63f97ea950>,
#  u'_clearReconnectUrl': <gensim.models.word2vec.Vocab at 0x7f63ff4a3690>,
#  u'NDP': <gensim.models.word2vec.Vocab at 0x7f641aa4c290>,
#  u'c_original': <gensim.models.word2vec.Vocab at 0x7f63ff4a3050>,
#  u'encodeURI': <gensim.models.word2vec.Vocab at 0x7f641ae31390>,
#  u'paginationButton': <gensim.models.word2vec.Vocab at 0x7f63f8d13250>,
#  u'valueText': <gensim.models.word2vec.Vocab at 0x7f63f97eae50>,
#  u'Foundation': <gensim.models.word2vec.Vocab at 0x7f640b761d90>,
#  u'html5': <gensim.models.word2vec.Vocab at 0x7f641f485b50>,
#  u'return_response_headers': <gensim.models.word2vec.Vocab at 0x7f63f97eaf10>,
#  u'file_owners': <gensim.models.word2vec.Vocab at 0x7f6400582ad0>,
#  u'rgb_match': <gensim.models.word2vec.Vocab at 0x7f63ff4a35d0>,
#  u'COLLECTION_SORT_OPTIONS': <gensim.models.word2vec.Vocab at 0x7f6406586390>,
#  u'call_window_dims': <gensim.models.word2vec.Vocab at 0x7f6406586ed0>,
#  u'display_w': <gensim.models.word2vec.Vocab at 0x7f63ff4a3410>,
#  u'forcePost': <gensim.models.word2vec.Vocab at 0x7f6406586790>,
#  u'nextAll': <gensim.models.word2vec.Vocab at 0x7f6406586510>,
#  u'logdata': <gensim.models.word2vec.Vocab at 0x7f63ff4a3890>,
#  u'display_h': <gensim.models.word2vec.Vocab at 0x7f63ff4a37d0>,
#  u'getMessage': <gensim.models.word2vec.Vocab at 0x7f6404f59fd0>,
#  u'$menu_anchor': <gensim.models.word2vec.Vocab at 0x7f63ff4a39d0>,
#  u'noResultsText': <gensim.models.word2vec.Vocab at 0x7f6406586350>,
#  u'_getEntityFromFile': <gensim.models.word2vec.Vocab at 0x7f63f97ead90>,
#  u'loid_created': <gensim.models.word2vec.Vocab at 0x7f63faacc7d0>,
#  u'after_ts': <gensim.models.word2vec.Vocab at 0x7f63f97eaf50>,
#  u'api_key': <gensim.models.word2vec.Vocab at 0x7f64007e5950>,
#  u'appendToUrl': <gensim.models.word2vec.Vocab at 0x7f64007e5990>,
#  u'swapClass': <gensim.models.word2vec.Vocab at 0x7f63f97eaed0>,
#  u'trackPixel': <gensim.models.word2vec.Vocab at 0x7f6400606610>,
#  u'wads': <gensim.models.word2vec.Vocab at 0x7f64088e5fd0>,
#  u'digit': <gensim.models.word2vec.Vocab at 0x7f64007e5e10>,
#  u'onsubmit': <gensim.models.word2vec.Vocab at 0x7f63f975d1d0>,
#  u'groupDomain': <gensim.models.word2vec.Vocab at 0x7f641ef6d7d0>,
#  u'isRestricted': <gensim.models.word2vec.Vocab at 0x7f63fdc74110>,
#  u'_elem': <gensim.models.word2vec.Vocab at 0x7f63fdd0abd0>,
#  u'setAccount': <gensim.models.word2vec.Vocab at 0x7f64007e5e50>,
#  u'sizeDefaultReplies': <gensim.models.word2vec.Vocab at 0x7f63f975d190>,
#  u'registerBidAdapter': <gensim.models.word2vec.Vocab at 0x7f64152d4210>,
#  u'analyticsClients': <gensim.models.word2vec.Vocab at 0x7f63ff4a3950>,
#  u'pev1': <gensim.models.word2vec.Vocab at 0x7f640b2ca350>,
#  u'$domain_el': <gensim.models.word2vec.Vocab at 0x7f63f975d110>,
#  u'pendingRequests': <gensim.models.word2vec.Vocab at 0x7f63ff4a3550>,
#  u'getLineHeight': <gensim.models.word2vec.Vocab at 0x7f63fdc74150>,
#  u'compatibilityRatingSummary': <gensim.models.word2vec.Vocab at 0x7f63f975d0d0>,
#  u'tickInterval': <gensim.models.word2vec.Vocab at 0x7f63ffd78f90>,
#  u'resizeStop': <gensim.models.word2vec.Vocab at 0x7f6400606910>,
#  u'failedUploadTextDisplay': <gensim.models.word2vec.Vocab at 0x7f63fdc74290>,
#  u'drawingHole': <gensim.models.word2vec.Vocab at 0x7f63f975d050>,
#  u'opsgenie': <gensim.models.word2vec.Vocab at 0x7f63f975d310>,
#  u'_mouseStarted': <gensim.models.word2vec.Vocab at 0x7f63ff4a3c10>,
#  u'querySelectorAll': <gensim.models.word2vec.Vocab at 0x7f63f975d210>,
#  u'CHECKSUM_ATTR_NAME': <gensim.models.word2vec.Vocab at 0x7f63f975d590>,
#  u'resizeFrame': <gensim.models.word2vec.Vocab at 0x7f63f975d410>,
#  u'setInputVal': <gensim.models.word2vec.Vocab at 0x7f63fdc74cd0>,
#  u'innerHtml': <gensim.models.word2vec.Vocab at 0x7f63ff3e6a50>,
#  u'labelFor': <gensim.models.word2vec.Vocab at 0x7f63f975d4d0>,
#  u'setEvent': <gensim.models.word2vec.Vocab at 0x7f63f975d350>,
#  u'suffix_regex': <gensim.models.word2vec.Vocab at 0x7f640b1bb290>,
#  u'registerCallback': <gensim.models.word2vec.Vocab at 0x7f6400606410>,
#  u'topEncrypted': <gensim.models.word2vec.Vocab at 0x7f63fdc74ed0>,
#  u'awrap': <gensim.models.word2vec.Vocab at 0x7f640b1bb3d0>,
#  u'Transitions': <gensim.models.word2vec.Vocab at 0x7f6403c42110>,
#  u'adSlots': <gensim.models.word2vec.Vocab at 0x7f641ad1c250>,
#  u'_kill': <gensim.models.word2vec.Vocab at 0x7f6405dd49d0>,
#  u'Playlist': <gensim.models.word2vec.Vocab at 0x7f63f975d7d0>,
#  u'storeItems': <gensim.models.word2vec.Vocab at 0x7f63f975d510>,
#  u'requireBase': <gensim.models.word2vec.Vocab at 0x7f63ff4a3290>,
#  u'avatar_class': <gensim.models.word2vec.Vocab at 0x7f63f965ee90>,
#  u'COMPILED': <gensim.models.word2vec.Vocab at 0x7f63f975d710>,
#  u'attachment_args': <gensim.models.word2vec.Vocab at 0x7f6400105810>,
#  u'DEFAULT_OPTIONS': <gensim.models.word2vec.Vocab at 0x7f63fbe3f090>,
#  u'scroller_id': <gensim.models.word2vec.Vocab at 0x7f63f975d810>,
#  u'error_': <gensim.models.word2vec.Vocab at 0x7f6403c42550>,
#  u'second': <gensim.models.word2vec.Vocab at 0x7f64007e55d0>,
#  u'repEl': <gensim.models.word2vec.Vocab at 0x7f63ff4a3510>,
#  u'_getItemLayoutPosition': <gensim.models.word2vec.Vocab at 0x7f63f975d750>,
#  u'incoming_call_window_busy': <gensim.models.word2vec.Vocab at 0x7f6403c42f10>,
#  u'END': <gensim.models.word2vec.Vocab at 0x7f64053d4a50>,
#  u'actorid': <gensim.models.word2vec.Vocab at 0x7f6400105e10>,
#  u'onFocusedKeydown': <gensim.models.word2vec.Vocab at 0x7f63f975d610>,
#  u'contextData': <gensim.models.word2vec.Vocab at 0x7f63f975d890>,
#  u'errors': <gensim.models.word2vec.Vocab at 0x7f6403c42890>,
#  u'_profileTasks': <gensim.models.word2vec.Vocab at 0x7f63ff4a3990>,
#  u'RESIZE': <gensim.models.word2vec.Vocab at 0x7f63f9727410>,
#  u'account_type': <gensim.models.word2vec.Vocab at 0x7f6414a1d290>,
#  u'duplicate': <gensim.models.word2vec.Vocab at 0x7f64005c7190>,
#  u'$edit_form': <gensim.models.word2vec.Vocab at 0x7f640a3c4d90>,
#  u'inViewStart': <gensim.models.word2vec.Vocab at 0x7f6403c42450>,
#  u'unit_size': <gensim.models.word2vec.Vocab at 0x7f63f975d8d0>,
#  u'_determineDate': <gensim.models.word2vec.Vocab at 0x7f63f975d910>,
#  u'replaceContent': <gensim.models.word2vec.Vocab at 0x7f6403c42bd0>,
#  u'b_creator': <gensim.models.word2vec.Vocab at 0x7f6403c42250>,
#  u'specialEasing': <gensim.models.word2vec.Vocab at 0x7f63f975dad0>,
#  u'render_template': <gensim.models.word2vec.Vocab at 0x7f63fbe3f190>,
#  u'twttr': <gensim.models.word2vec.Vocab at 0x7f63f975da90>,
#  u'_layoutItems': <gensim.models.word2vec.Vocab at 0x7f63f8847410>,
#  u'_hostNode': <gensim.models.word2vec.Vocab at 0x7f641aa4c190>,
#  u'ErrorEvent': <gensim.models.word2vec.Vocab at 0x7f64007e5cd0>,
#  u'seekTo': <gensim.models.word2vec.Vocab at 0x7f64001de510>,
#  u'stepFiles': <gensim.models.word2vec.Vocab at 0x7f640051c510>,
#  u'autoRotation': <gensim.models.word2vec.Vocab at 0x7f64001de6d0>,
#  u'resetEditUI': <gensim.models.word2vec.Vocab at 0x7f63ff4a30d0>,
#  u'new_val': <gensim.models.word2vec.Vocab at 0x7f63ff3b7610>,
#  u'widget': <gensim.models.word2vec.Vocab at 0x7f64001de850>,
#  u'args': <gensim.models.word2vec.Vocab at 0x7f63fe303cd0>,
#  u'wLeft': <gensim.models.word2vec.Vocab at 0x7f64001de950>,
#  u'UFICallbackStore': <gensim.models.word2vec.Vocab at 0x7f64007e5590>,
#  u'jwGetFullscreen': <gensim.models.word2vec.Vocab at 0x7f63ff4a3ad0>,
#  u'only_channels': <gensim.models.word2vec.Vocab at 0x7f63f975da50>,
#  u'RecruitFacebookResumeView': <gensim.models.word2vec.Vocab at 0x7f63fc656590>,
#  u'active_channel_id': <gensim.models.word2vec.Vocab at 0x7f63ff4a3e90>,
#  u'fromInt': <gensim.models.word2vec.Vocab at 0x7f64001de0d0>,
#  u'toolTip': <gensim.models.word2vec.Vocab at 0x7f64007e5050>,
#  u'atoms': <gensim.models.word2vec.Vocab at 0x7f63ff4a3f90>,
#  u'doScroll': <gensim.models.word2vec.Vocab at 0x7f64007e5d50>,
#  u'adapterSettings': <gensim.models.word2vec.Vocab at 0x7f64001de390>,
#  u'screen_name': <gensim.models.word2vec.Vocab at 0x7f6402c07850>,
#  u'contextTypes': <gensim.models.word2vec.Vocab at 0x7f63ff4a3850>,
#  u'argv': <gensim.models.word2vec.Vocab at 0x7f63fe3035d0>,
#  u'onValidation': <gensim.models.word2vec.Vocab at 0x7f63f975d650>,
#  u'enqueueCallback': <gensim.models.word2vec.Vocab at 0x7f64001ded50>,
#  u'_filters': <gensim.models.word2vec.Vocab at 0x7f64007e53d0>,
#  u'activeCues_': <gensim.models.word2vec.Vocab at 0x7f6400b00090>,
#  u'clearCache': <gensim.models.word2vec.Vocab at 0x7f63f97ea250>,
#  u'error1': <gensim.models.word2vec.Vocab at 0x7f64001de990>,
#  u'getCurrentLocation': <gensim.models.word2vec.Vocab at 0x7f6400b00410>,
#  u'active_im_id': <gensim.models.word2vec.Vocab at 0x7f6400b00110>,
#  u'InputOutputInfoView': <gensim.models.word2vec.Vocab at 0x7f64001de8d0>,
#  u'_lastEventTime': <gensim.models.word2vec.Vocab at 0x7f63f975d5d0>,
#  u'k': <gensim.models.word2vec.Vocab at 0x7f6400b00290>,
#  u'_attr': <gensim.models.word2vec.Vocab at 0x7f63f975db10>,
#  u'reports': <gensim.models.word2vec.Vocab at 0x7f64007e50d0>,
#  u'oGlobals': <gensim.models.word2vec.Vocab at 0x7f641aa4c590>,
#  u'$ProfilingCounters2': <gensim.models.word2vec.Vocab at 0x7f63f89f7a10>,
#  u'nil': <gensim.models.word2vec.Vocab at 0x7f63f942aa90>,
#  u'timePicker': <gensim.models.word2vec.Vocab at 0x7f6403da1050>,
#  u'stopContent': <gensim.models.word2vec.Vocab at 0x7f64001decd0>,
#  u'Cf': <gensim.models.word2vec.Vocab at 0x7f63f8778c10>,
#  u'NOT': <gensim.models.word2vec.Vocab at 0x7f63f975db90>,
#  u'_removeClass': <gensim.models.word2vec.Vocab at 0x7f63f975db50>,
#  u'getElements': <gensim.models.word2vec.Vocab at 0x7f6400b00450>,
#  u'cancellation': <gensim.models.word2vec.Vocab at 0x7f64007e5110>,
#  u'bDone': <gensim.models.word2vec.Vocab at 0x7f64007e5690>,
#  u'$CallbackDependencyManager2': <gensim.models.word2vec.Vocab at 0x7f64001dea90>,
#  u'UFICommentOrderingMode': <gensim.models.word2vec.Vocab at 0x7f63ffbf8290>,
#  u'$CallbackDependencyManager1': <gensim.models.word2vec.Vocab at 0x7f63ffbf8490>,
#  u'projection': <gensim.models.word2vec.Vocab at 0x7f64001dedd0>,
#  u'$CallbackDependencyManager4': <gensim.models.word2vec.Vocab at 0x7f64001dee10>,
#  u'$profileHeaderBgImage': <gensim.models.word2vec.Vocab at 0x7f641679e8d0>,
#  u'GeolocationErrorCode': <gensim.models.word2vec.Vocab at 0x7f64001de610>,
#  u'replace': <gensim.models.word2vec.Vocab at 0x7f6400b004d0>,
#  u'audio_url': <gensim.models.word2vec.Vocab at 0x7f64001de690>,
#  u'setStartEllipAt': <gensim.models.word2vec.Vocab at 0x7f6404f59790>,
#  u'excludeTopic': <gensim.models.word2vec.Vocab at 0x7f6400b00390>,
#  u'num_failures': <gensim.models.word2vec.Vocab at 0x7f640332f790>,
#  u'getServerIDFromClientID': <gensim.models.word2vec.Vocab at 0x7f6400b00210>,
#  u'jsTags': <gensim.models.word2vec.Vocab at 0x7f63f975dc10>,
#  u'topPause': <gensim.models.word2vec.Vocab at 0x7f6406ee9ad0>,
#  u'txt': <gensim.models.word2vec.Vocab at 0x7f63f975dd50>,
#  u'txs': <gensim.models.word2vec.Vocab at 0x7f63f975ddd0>,
#  u'SMARTTV': <gensim.models.word2vec.Vocab at 0x7f63ff148e10>,
#  u'CATEGORIES': <gensim.models.word2vec.Vocab at 0x7f641b4d0a10>,
#  u'ufiInstanceID': <gensim.models.word2vec.Vocab at 0x7f63ffd785d0>,
#  u'elemdisplay': <gensim.models.word2vec.Vocab at 0x7f640332f4d0>,
#  u'_onModelEvent': <gensim.models.word2vec.Vocab at 0x7f6400b00490>,
#  u'cacheURL': <gensim.models.word2vec.Vocab at 0x7f63ffd784d0>,
#  u'abbreviations': <gensim.models.word2vec.Vocab at 0x7f6404f59d50>,
#  u'disableDeduping': <gensim.models.word2vec.Vocab at 0x7f6404f59890>,
#  u'_mouseMoved': <gensim.models.word2vec.Vocab at 0x7f6409330450>,
#  u'undf': <gensim.models.word2vec.Vocab at 0x7f63f8c0d110>,
#  u'altField': <gensim.models.word2vec.Vocab at 0x7f63f975dc50>,
#  u'dnt': <gensim.models.word2vec.Vocab at 0x7f6404f590d0>,
#  u'serverResolutions': <gensim.models.word2vec.Vocab at 0x7f63fc077d90>,
#  u'productViewed': <gensim.models.word2vec.Vocab at 0x7f64006fddd0>,
#  u'hljs': <gensim.models.word2vec.Vocab at 0x7f63f9975790>,
#  u'_getOffset': <gensim.models.word2vec.Vocab at 0x7f64006fd650>,
#  u'tokenize': <gensim.models.word2vec.Vocab at 0x7f64006fd6d0>,
#  u'sidebar_behavior': <gensim.models.word2vec.Vocab at 0x7f640332fb10>,
#  u'makeInternalInlineImg': <gensim.models.word2vec.Vocab at 0x7f63ff10bf90>,
#  u'runBackwards': <gensim.models.word2vec.Vocab at 0x7f63f975dfd0>,
#  u'getBoxObjectFor': <gensim.models.word2vec.Vocab at 0x7f6400b00590>,
#  u'until': <gensim.models.word2vec.Vocab at 0x7f640332fcd0>,
#  u'insertInDom': <gensim.models.word2vec.Vocab at 0x7f640832af50>,
#  u'atOffset': <gensim.models.word2vec.Vocab at 0x7f63fbe3f1d0>,
#  u'RecruitCandidateQuestionView': <gensim.models.word2vec.Vocab at 0x7f64006fd510>,
#  u'mouseup': <gensim.models.word2vec.Vocab at 0x7f641ab2cd90>,
#  u'getPluginName': <gensim.models.word2vec.Vocab at 0x7f63f975df90>,
#  u'toIndexedSeq': <gensim.models.word2vec.Vocab at 0x7f6400b00810>,
#  u'expm1': <gensim.models.word2vec.Vocab at 0x7f64053d4d90>,
#  u'Rule': <gensim.models.word2vec.Vocab at 0x7f6400b00990>,
#  u'requestToProcess': <gensim.models.word2vec.Vocab at 0x7f64006fdc10>,
#  u'message_changed_sig': <gensim.models.word2vec.Vocab at 0x7f63ff258950>,
#  u'$animLayers': <gensim.models.word2vec.Vocab at 0x7f63f975de10>,
#  u'isCorGMuted': <gensim.models.word2vec.Vocab at 0x7f63ff2584d0>,
#  u'clientid': <gensim.models.word2vec.Vocab at 0x7f63fecd23d0>,
#  u'snippets_cbm': <gensim.models.word2vec.Vocab at 0x7f63f9185f90>,
#  u'_handleIndex': <gensim.models.word2vec.Vocab at 0x7f64029da110>,
#  u'BinaryExpression': <gensim.models.word2vec.Vocab at 0x7f63f975de50>,
#  u'_osType': <gensim.models.word2vec.Vocab at 0x7f63f975ded0>,
#  u'isEmptyObject': <gensim.models.word2vec.Vocab at 0x7f64006fd850>,
#  u'unpack': <gensim.models.word2vec.Vocab at 0x7f64006fde50>,
#  u'feedbackTargetID': <gensim.models.word2vec.Vocab at 0x7f6400b00c90>,
#  u'trackCategorizedPages': <gensim.models.word2vec.Vocab at 0x7f6400b006d0>,
#  u'getShimContainer': <gensim.models.word2vec.Vocab at 0x7f640881b690>,
#  u'bidderCode': <gensim.models.word2vec.Vocab at 0x7f640832a950>,
#  u'locked': <gensim.models.word2vec.Vocab at 0x7f64047adf10>,
#  u'listWidth': <gensim.models.word2vec.Vocab at 0x7f640332f810>,
#  u'contextDataMapping': <gensim.models.word2vec.Vocab at 0x7f6403dd8150>,
#  u'checkMemberMatch': <gensim.models.word2vec.Vocab at 0x7f6400b00a50>,
#  u'sizeId': <gensim.models.word2vec.Vocab at 0x7f63f97c8110>,
#  u'error_markers': <gensim.models.word2vec.Vocab at 0x7f63f9280790>,
#  u'backBufferTimerId': <gensim.models.word2vec.Vocab at 0x7f63f97c81d0>,
#  u'_proportionallyResize': <gensim.models.word2vec.Vocab at 0x7f63f97c8150>,
#  u'urlValidator': <gensim.models.word2vec.Vocab at 0x7f63f97c8090>,
#  u'sStatId': <gensim.models.word2vec.Vocab at 0x7f63f97c80d0>,
#  u'View': <gensim.models.word2vec.Vocab at 0x7f63ff4d54d0>,
#  u'getLayerRoot': <gensim.models.word2vec.Vocab at 0x7f6400b00890>,
#  u'isRegisteredUser': <gensim.models.word2vec.Vocab at 0x7f6400b00910>,
#  u'_slicedToArray': <gensim.models.word2vec.Vocab at 0x7f640781a310>,
#  u'RLQ': <gensim.models.word2vec.Vocab at 0x7f64047ad150>,
#  u'example': <gensim.models.word2vec.Vocab at 0x7f6400b00a90>,
#  u'Lf': <gensim.models.word2vec.Vocab at 0x7f64047ad350>,
#  u'Lg': <gensim.models.word2vec.Vocab at 0x7f64047adad0>,
#  u'Ld': <gensim.models.word2vec.Vocab at 0x7f64047ad990>,
#  u'Le': <gensim.models.word2vec.Vocab at 0x7f64047ad250>,
#  u'Lb': <gensim.models.word2vec.Vocab at 0x7f64047adbd0>,
#  u'Lc': <gensim.models.word2vec.Vocab at 0x7f64047ad290>,
#  u'maxWidth': <gensim.models.word2vec.Vocab at 0x7f640332fd50>,
#  u'La': <gensim.models.word2vec.Vocab at 0x7f64047ad690>,
#  u'Ln': <gensim.models.word2vec.Vocab at 0x7f64047ad2d0>,
#  u'Lo': <gensim.models.word2vec.Vocab at 0x7f64047aded0>,
#  u'Ll': <gensim.models.word2vec.Vocab at 0x7f64047ad550>,
#  u'Lm': <gensim.models.word2vec.Vocab at 0x7f64047ad0d0>,
#  u'Lj': <gensim.models.word2vec.Vocab at 0x7f63fc4800d0>,
#  u'Lk': <gensim.models.word2vec.Vocab at 0x7f63fc480510>,
#  u'Lh': <gensim.models.word2vec.Vocab at 0x7f63fc480110>,
#  u'Li': <gensim.models.word2vec.Vocab at 0x7f63fc4801d0>,
#  u'currency': <gensim.models.word2vec.Vocab at 0x7f6400b005d0>,
#  u'Lt': <gensim.models.word2vec.Vocab at 0x7f63fc480090>,
#  u'Lu': <gensim.models.word2vec.Vocab at 0x7f63fc4809d0>,
#  u'Lr': <gensim.models.word2vec.Vocab at 0x7f63fc480910>,
#  u'Ls': <gensim.models.word2vec.Vocab at 0x7f63fc480490>,
#  u'Lp': <gensim.models.word2vec.Vocab at 0x7f63fc480190>,
#  u'elqMs': <gensim.models.word2vec.Vocab at 0x7f64027c96d0>,
#  u'SoldOutDealFilter': <gensim.models.word2vec.Vocab at 0x7f6403da1850>,
#  u'clearQueue': <gensim.models.word2vec.Vocab at 0x7f6400b009d0>,
#  u'AUI_BUILD_DATE': <gensim.models.word2vec.Vocab at 0x7f63f86ca810>,
#  u'senderName': <gensim.models.word2vec.Vocab at 0x7f63f97c83d0>,
#  u'indentUnit': <gensim.models.word2vec.Vocab at 0x7f6401896250>,
#  u'absolute': <gensim.models.word2vec.Vocab at 0x7f63fc4806d0>,
#  u'motion': <gensim.models.word2vec.Vocab at 0x7f641ef6d650>,
#  u'LD': <gensim.models.word2vec.Vocab at 0x7f63fc4807d0>,
#  u'defaultAttributes': <gensim.models.word2vec.Vocab at 0x7f6400b00e10>,
#  u'LA': <gensim.models.word2vec.Vocab at 0x7f63fc480390>,
#  u'wIn': <gensim.models.word2vec.Vocab at 0x7f63fbf10bd0>,
#  u'feature': <gensim.models.word2vec.Vocab at 0x7f6400b00f50>,
#  u'dm_member_name': <gensim.models.word2vec.Vocab at 0x7f63fc480250>,
#  u'instantiateToString': <gensim.models.word2vec.Vocab at 0x7f63f97c8390>,
#  u'_adexc': <gensim.models.word2vec.Vocab at 0x7f6400b00b90>,
#  u'LW': <gensim.models.word2vec.Vocab at 0x7f6403bde250>,
#  u'LT': <gensim.models.word2vec.Vocab at 0x7f63fc480290>,
#  u'omit_link': <gensim.models.word2vec.Vocab at 0x7f6403bde690>,
#  u'LR': <gensim.models.word2vec.Vocab at 0x7f63fc480a90>,
#  u'LS': <gensim.models.word2vec.Vocab at 0x7f6403bde850>,
#  u'isoWeekYear': <gensim.models.word2vec.Vocab at 0x7f6400b00a10>,
#  u'_setOption': <gensim.models.word2vec.Vocab at 0x7f640332fd10>,
#  u'cellspacing': <gensim.models.word2vec.Vocab at 0x7f640332fa10>,
#  u'orderingMode': <gensim.models.word2vec.Vocab at 0x7f63fc480d50>,
#  u'getFeatureInfo': <gensim.models.word2vec.Vocab at 0x7f6414a1d150>,
#  u'idsubstr': <gensim.models.word2vec.Vocab at 0x7f63ff788490>,
#  u'availableDay': <gensim.models.word2vec.Vocab at 0x7f63fc4802d0>,
#  u'regional': <gensim.models.word2vec.Vocab at 0x7f63f975d290>,
#  u'_css3d': <gensim.models.word2vec.Vocab at 0x7f63fba62ad0>,
#  u'mousewheelTimer': <gensim.models.word2vec.Vocab at 0x7f63f8bdd050>,
#  u'RecruitCandidateMcqView': <gensim.models.word2vec.Vocab at 0x7f640332fd90>,
#  u'changed_deleted_sig': <gensim.models.word2vec.Vocab at 0x7f6400b00c10>,
#  u'_resetButton': <gensim.models.word2vec.Vocab at 0x7f6400891610>,
#  u'history_is_being_fetched': <gensim.models.word2vec.Vocab at 0x7f63fc480210>,
#  u'suppressUnhandledRejections': <gensim.models.word2vec.Vocab at 0x7f6421edb950>,
#  u'swing': <gensim.models.word2vec.Vocab at 0x7f6405e77490>,
#  u'currentTarget': <gensim.models.word2vec.Vocab at 0x7f6421e530d0>,
#  u'oldCache': <gensim.models.word2vec.Vocab at 0x7f6400b00d10>,
#  u'_isScrolling': <gensim.models.word2vec.Vocab at 0x7f63f97c8490>,
#  u'$pick': <gensim.models.word2vec.Vocab at 0x7f63f97c8450>,
#  u'trunc': <gensim.models.word2vec.Vocab at 0x7f63f900e490>,
#  u'setAccessToken': <gensim.models.word2vec.Vocab at 0x7f64167605d0>,
#  u'elPos': <gensim.models.word2vec.Vocab at 0x7f6400b00f90>,
#  u'_timeScale': <gensim.models.word2vec.Vocab at 0x7f63ff258bd0>,
#  u'$$isolateBindings': <gensim.models.word2vec.Vocab at 0x7f6400891950>,
#  u'did_choose_video': <gensim.models.word2vec.Vocab at 0x7f63fc480c50>,
#  u'constants': <gensim.models.word2vec.Vocab at 0x7f63f97ea790>,
#  u'needsClick': <gensim.models.word2vec.Vocab at 0x7f63ff7888d0>,
#  u'RecruitCandidateCodingCodeshellxView': <gensim.models.word2vec.Vocab at 0x7f64008915d0>,
#  u'$activeItems': <gensim.models.word2vec.Vocab at 0x7f6400891750>,
#  u'_calcEnd': <gensim.models.word2vec.Vocab at 0x7f63f97c8950>,
#  u'swfObjectId': <gensim.models.word2vec.Vocab at 0x7f63ff4d59d0>,
#  u'featureMember': <gensim.models.word2vec.Vocab at 0x7f63ff788fd0>,
#  u'postState': <gensim.models.word2vec.Vocab at 0x7f63fe303410>,
#  u'whenReady': <gensim.models.word2vec.Vocab at 0x7f63f97c8a10>,
#  u'_handleError': <gensim.models.word2vec.Vocab at 0x7f6400b00d50>,
#  u'pAdCfg': <gensim.models.word2vec.Vocab at 0x7f6403da1390>,
#  u'_typingEventController': <gensim.models.word2vec.Vocab at 0x7f63fc34af90>,
#  u'merge_mode': <gensim.models.word2vec.Vocab at 0x7f63fb8f6e50>,
#  u'splitText': <gensim.models.word2vec.Vocab at 0x7f63fc34aed0>,
#  u'$msg_inline_media_toggler': <gensim.models.word2vec.Vocab at 0x7f6400b00e90>,
#  u'CursorLegendRenderer': <gensim.models.word2vec.Vocab at 0x7f6400891790>,
#  u'textBaseline': <gensim.models.word2vec.Vocab at 0x7f64007e5150>,
#  u'setPropertyOnResults': <gensim.models.word2vec.Vocab at 0x7f63fc480950>,
#  u'tooltipProgressBar': <gensim.models.word2vec.Vocab at 0x7f63f8afb8d0>,
#  u'_getObjectProperty': <gensim.models.word2vec.Vocab at 0x7f63fd01e110>,
#  u'backdrop': <gensim.models.word2vec.Vocab at 0x7f6400891850>,
#  u'_hasString': <gensim.models.word2vec.Vocab at 0x7f63f97c8910>,
#  u'xj': <gensim.models.word2vec.Vocab at 0x7f6400b00310>,
#  u'cdwb': <gensim.models.word2vec.Vocab at 0x7f6400b000d0>,
#  u'_Y': <gensim.models.word2vec.Vocab at 0x7f63fa5b8d90>,
#  u'xk': <gensim.models.word2vec.Vocab at 0x7f63fe303350>,
#  u'_W': <gensim.models.word2vec.Vocab at 0x7f63f97c8990>,
#  u'MediaUpload': <gensim.models.word2vec.Vocab at 0x7f6400f42250>,
#  u'_T': <gensim.models.word2vec.Vocab at 0x7f63f97c8ad0>,
#  u'$rxn': <gensim.models.word2vec.Vocab at 0x7f6400b00690>,
#  u'xh': <gensim.models.word2vec.Vocab at 0x7f63fe303090>,
#  u'_Q': <gensim.models.word2vec.Vocab at 0x7f63f97c8b10>,
#  u'likeCount': <gensim.models.word2vec.Vocab at 0x7f6400469f90>,
#  u'_dom_service': <gensim.models.word2vec.Vocab at 0x7f63ff3e6050>,
#  u'_M': <gensim.models.word2vec.Vocab at 0x7f63f97c8c10>,
#  u'cancelAnimationFrame': <gensim.models.word2vec.Vocab at 0x7f63f9280d50>,
#  u'$MercuryAttachmentSnippet17': <gensim.models.word2vec.Vocab at 0x7f63ff616410>,
#  u'byte_string': <gensim.models.word2vec.Vocab at 0x7f63ff616690>,
#  u'concurrency': <gensim.models.word2vec.Vocab at 0x7f63fc480b50>,
#  u'_H': <gensim.models.word2vec.Vocab at 0x7f63fa4ee1d0>,
#  u'xn': <gensim.models.word2vec.Vocab at 0x7f63fe303c50>,
#  u'_E': <gensim.models.word2vec.Vocab at 0x7f63f97c8a90>,
#  u'parserConfig': <gensim.models.word2vec.Vocab at 0x7f63f97c8bd0>,
#  u'activating': <gensim.models.word2vec.Vocab at 0x7f63fc480750>,
#  u'LABEL_ID_SUFFIX': <gensim.models.word2vec.Vocab at 0x7f63ff3e6090>,
#  u'xo': <gensim.models.word2vec.Vocab at 0x7f63fe303990>,
#  u'byteLength': <gensim.models.word2vec.Vocab at 0x7f63fc480610>,
#  u'escapeChar': <gensim.models.word2vec.Vocab at 0x7f6400891dd0>,
#  u'goTo': <gensim.models.word2vec.Vocab at 0x7f6400469f10>,
#  u'fit': <gensim.models.word2vec.Vocab at 0x7f63fc480a10>,
#  u'_x': <gensim.models.word2vec.Vocab at 0x7f63feff7a10>,
#  u'_w': <gensim.models.word2vec.Vocab at 0x7f63f97c8cd0>,
#  u'_v': <gensim.models.word2vec.Vocab at 0x7f63f97c8dd0>,
#  u'fix': <gensim.models.word2vec.Vocab at 0x7f63fc480a50>,
#  u'_t': <gensim.models.word2vec.Vocab at 0x7f63f97c8d10>,
#  u'_s': <gensim.models.word2vec.Vocab at 0x7f63f97c8e10>,
#  u'_r': <gensim.models.word2vec.Vocab at 0x7f63f97c8e90>,
#  u'_q': <gensim.models.word2vec.Vocab at 0x7f63f97c8f50>,
#  u'_p': <gensim.models.word2vec.Vocab at 0x7f63f97c8fd0>,
#  u'_o': <gensim.models.word2vec.Vocab at 0x7f63f97c8e50>,
#  u'_n': <gensim.models.word2vec.Vocab at 0x7f63f97c8f10>,
#  u'cardContainer': <gensim.models.word2vec.Vocab at 0x7f6400891810>,
#  u'_l': <gensim.models.word2vec.Vocab at 0x7f63f97c8d90>,
#  u'_k': <gensim.models.word2vec.Vocab at 0x7f63f97c8ed0>,
#  u'maybeClearUsersCountsInfo': <gensim.models.word2vec.Vocab at 0x7f63ff3e6510>,
#  u'fid': <gensim.models.word2vec.Vocab at 0x7f63fc480e90>,
#  u'_h': <gensim.models.word2vec.Vocab at 0x7f63f97c8c50>,
#  u'sitepage': <gensim.models.word2vec.Vocab at 0x7f63fc480690>,
#  u'_f': <gensim.models.word2vec.Vocab at 0x7f6400330410>,
#  u'hidden': <gensim.models.word2vec.Vocab at 0x7f64003301d0>,
#  u'_d': <gensim.models.word2vec.Vocab at 0x7f6400330110>,
#  u'_c': <gensim.models.word2vec.Vocab at 0x7f64003303d0>,
#  u'_b': <gensim.models.word2vec.Vocab at 0x7f64003302d0>,
#  u'_a': <gensim.models.word2vec.Vocab at 0x7f6400330d50>,
#  u'Implements': <gensim.models.word2vec.Vocab at 0x7f63ff3e6550>,
#  u'Cs': <gensim.models.word2vec.Vocab at 0x7f63f8778e50>,
#  u'xa': <gensim.models.word2vec.Vocab at 0x7f63fe303910>,
#  u'scroll_top': <gensim.models.word2vec.Vocab at 0x7f64034bafd0>,
#  u'touchObject': <gensim.models.word2vec.Vocab at 0x7f63fab68e10>,
#  u'_da': <gensim.models.word2vec.Vocab at 0x7f63f873ce50>,
#  u'$siteNavigation': <gensim.models.word2vec.Vocab at 0x7f63fbd41450>,
#  u'currContent': <gensim.models.word2vec.Vocab at 0x7f63f8afb9d0>,
#  u'getString': <gensim.models.word2vec.Vocab at 0x7f640d370290>,
#  u'flattenDeep': <gensim.models.word2vec.Vocab at 0x7f64003304d0>,
#  u'hb': <gensim.models.word2vec.Vocab at 0x7f640231ac90>,
#  u'adBlockIsEnabled': <gensim.models.word2vec.Vocab at 0x7f6400891fd0>,
#  u'resize_image': <gensim.models.word2vec.Vocab at 0x7f6400891710>,
#  u'effects': <gensim.models.word2vec.Vocab at 0x7f64034ba150>,
#  u'byAttribute': <gensim.models.word2vec.Vocab at 0x7f641eb2b050>,
#  u'interrupt': <gensim.models.word2vec.Vocab at 0x7f63ff3e62d0>,
#  u'getComment': <gensim.models.word2vec.Vocab at 0x7f6400330c50>,
#  u'blink': <gensim.models.word2vec.Vocab at 0x7f63fb32a210>,
#  u'silver': <gensim.models.word2vec.Vocab at 0x7f64003306d0>,
#  u'ssl': <gensim.models.word2vec.Vocab at 0x7f641e88eb10>,
#  u'Cr': <gensim.models.word2vec.Vocab at 0x7f63f8778e90>,
#  u'_select': <gensim.models.word2vec.Vocab at 0x7f63fb802790>,
#  u'rrun': <gensim.models.word2vec.Vocab at 0x7f64088d59d0>,
#  u'isTabletStyle': <gensim.models.word2vec.Vocab at 0x7f63faf56c90>,
#  u'lSc': <gensim.models.word2vec.Vocab at 0x7f64034ba090>,
#  u'channel_id': <gensim.models.word2vec.Vocab at 0x7f63f94f0e50>,
#  u'_evt': <gensim.models.word2vec.Vocab at 0x7f64034ba810>,
#  u'spinCycle': <gensim.models.word2vec.Vocab at 0x7f64088d5910>,
#  u'$overview': <gensim.models.word2vec.Vocab at 0x7f64034bac90>,
#  u'hidePreEnd': <gensim.models.word2vec.Vocab at 0x7f64034ba110>,
#  u'widgetEventPrefix': <gensim.models.word2vec.Vocab at 0x7f64034ba050>,
#  u'_fake_ts_unique_incrementer': <gensim.models.word2vec.Vocab at 0x7f641a9f87d0>,
#  u'API': <gensim.models.word2vec.Vocab at 0x7f64088d5050>,
#  u'channel_handy_rxns': <gensim.models.word2vec.Vocab at 0x7f63fdd66590>,
#  u'timeout': <gensim.models.word2vec.Vocab at 0x7f64034bad50>,
#  u'isIdentifierStart': <gensim.models.word2vec.Vocab at 0x7f6402a01cd0>,
#  u'debug': <gensim.models.word2vec.Vocab at 0x7f6400891310>,
#  u'windowHeight': <gensim.models.word2vec.Vocab at 0x7f64088d5150>,
#  u'_$': <gensim.models.word2vec.Vocab at 0x7f64088d5710>,
#  u'sort_shared_channel_browser_by': <gensim.models.word2vec.Vocab at 0x7f63fef3ecd0>,
#  u'toggle_attribute': <gensim.models.word2vec.Vocab at 0x7f640c0c53d0>,
#  u'_scrollIntoView': <gensim.models.word2vec.Vocab at 0x7f63ff3e6ed0>,
#  u'commenter': <gensim.models.word2vec.Vocab at 0x7f63ff4a3a90>,
#  u'rP': <gensim.models.word2vec.Vocab at 0x7f63ff3e6410>,
#  u'fetchStart': <gensim.models.word2vec.Vocab at 0x7f6405e77690>,
#  u'previousId': <gensim.models.word2vec.Vocab at 0x7f63f8bdd550>,
#  u'v1_1': <gensim.models.word2vec.Vocab at 0x7f64034bac10>,
#  u'series': <gensim.models.word2vec.Vocab at 0x7f63ff3e6e10>,
#  u'pricingData': <gensim.models.word2vec.Vocab at 0x7f641e88e3d0>,
#  u'rX': <gensim.models.word2vec.Vocab at 0x7f63ff3e65d0>,
#  u'rY': <gensim.models.word2vec.Vocab at 0x7f63ff3e6990>,
#  u'redirectAction': <gensim.models.word2vec.Vocab at 0x7f63f8e02b50>,
#  u'last_pong_time': <gensim.models.word2vec.Vocab at 0x7f64007e5c10>,
#  u'rE': <gensim.models.word2vec.Vocab at 0x7f64018e4090>,
#  u'readChildNodes': <gensim.models.word2vec.Vocab at 0x7f64034ba390>,
#  u'validation_level': <gensim.models.word2vec.Vocab at 0x7f6421e53810>,
#  u'charCodeAt': <gensim.models.word2vec.Vocab at 0x7f64034ba650>,
#  u'xs': <gensim.models.word2vec.Vocab at 0x7f63fe717a10>,
#  u'team_name': <gensim.models.word2vec.Vocab at 0x7f64018e4f10>,
#  u'doesNotExists': <gensim.models.word2vec.Vocab at 0x7f6408533d90>,
#  u'getOptions': <gensim.models.word2vec.Vocab at 0x7f63ff3e6b50>,
#  u'message': <gensim.models.word2vec.Vocab at 0x7f63ff3e69d0>,
#  u'overwrite': <gensim.models.word2vec.Vocab at 0x7f6408533a90>,
#  u'rt': <gensim.models.word2vec.Vocab at 0x7f63ff3e6e50>,
#  u'activeIndex': <gensim.models.word2vec.Vocab at 0x7f64034ba250>,
#  u'rv': <gensim.models.word2vec.Vocab at 0x7f63ff3e6850>,
#  u'xq': <gensim.models.word2vec.Vocab at 0x7f63fe717490>,
#  u'rp': <gensim.models.word2vec.Vocab at 0x7f63ff3e6750>,
#  u'_updateClassName': <gensim.models.word2vec.Vocab at 0x7f64025ad050>,
#  u'rr': <gensim.models.word2vec.Vocab at 0x7f63ff3e6250>,
#  u'rs': <gensim.models.word2vec.Vocab at 0x7f63ff3e6950>,
#  u'getMedia': <gensim.models.word2vec.Vocab at 0x7f64034ba7d0>,
#  u'_applyActiveClass': <gensim.models.word2vec.Vocab at 0x7f6405e77750>,
#  u'dst': <gensim.models.word2vec.Vocab at 0x7f64025ad150>,
#  u'origMaxHeight': <gensim.models.word2vec.Vocab at 0x7f64034baf90>,
#  u'rx': <gensim.models.word2vec.Vocab at 0x7f63ff3e6ad0>,
#  u'inplace': <gensim.models.word2vec.Vocab at 0x7f63fefc6550>,
#  u'rel_style': <gensim.models.word2vec.Vocab at 0x7f64034bad90>,
#  u'moveMonthBy': <gensim.models.word2vec.Vocab at 0x7f64034ba350>,
#  u'rd': <gensim.models.word2vec.Vocab at 0x7f63ff3e6890>,
#  u're': <gensim.models.word2vec.Vocab at 0x7f63ff3e6210>,
#  u'rf': <gensim.models.word2vec.Vocab at 0x7f63ff3e6790>,
#  u'rg': <gensim.models.word2vec.Vocab at 0x7f63ff2d0150>,
#  u'ra': <gensim.models.word2vec.Vocab at 0x7f63ff2d0090>,
#  u'rb': <gensim.models.word2vec.Vocab at 0x7f63ff2d04d0>,
#  u'rc': <gensim.models.word2vec.Vocab at 0x7f63ff2d0390>,
#  u'rl': <gensim.models.word2vec.Vocab at 0x7f63ff2d0410>,
#  u'rm': <gensim.models.word2vec.Vocab at 0x7f63ff2d03d0>,
#  u'rn': <gensim.models.word2vec.Vocab at 0x7f63ff2d0450>,
#  u'size': <gensim.models.word2vec.Vocab at 0x7f6403da1510>,
#  u'rh': <gensim.models.word2vec.Vocab at 0x7f63ff2d05d0>,
#  u'ri': <gensim.models.word2vec.Vocab at 0x7f63ff2d0750>,
#  u'rj': <gensim.models.word2vec.Vocab at 0x7f63ff2d0850>,
#  u'superfeedr': <gensim.models.word2vec.Vocab at 0x7f64025adfd0>,
#  u'removePoint': <gensim.models.word2vec.Vocab at 0x7f64034ba490>,
#  u'strato': <gensim.models.word2vec.Vocab at 0x7f640200da50>,
#  u'iOffY': <gensim.models.word2vec.Vocab at 0x7f63ff2d0290>,
#  u'scrollWidgetBuilder': <gensim.models.word2vec.Vocab at 0x7f6400891210>,
#  u'payloadSource': <gensim.models.word2vec.Vocab at 0x7f6400891f50>,
#  u'_capture': <gensim.models.word2vec.Vocab at 0x7f6400891650>,
#  u'_addDescribedBy': <gensim.models.word2vec.Vocab at 0x7f6414a1d410>,
#  u'imageNode': <gensim.models.word2vec.Vocab at 0x7f640200d790>,
#  u'yesterday': <gensim.models.word2vec.Vocab at 0x7f641aa4cc10>,
#  u'NumberHandler': <gensim.models.word2vec.Vocab at 0x7f64025adbd0>,
#  u'_setPongTimeoutMs': <gensim.models.word2vec.Vocab at 0x7f6400891e10>,
#  u'scrollOverviewBy': <gensim.models.word2vec.Vocab at 0x7f63fbde6690>,
#  u'_makeRequest': <gensim.models.word2vec.Vocab at 0x7f6400891450>,
#  u'noRatedMsg': <gensim.models.word2vec.Vocab at 0x7f640200d650>,
#  u'asNavFor': <gensim.models.word2vec.Vocab at 0x7f63ff2d0690>,
#  u'csxName': <gensim.models.word2vec.Vocab at 0x7f64050b4610>,
#  u'autoFocus': <gensim.models.word2vec.Vocab at 0x7f640200d610>,
#  u'onToggle': <gensim.models.word2vec.Vocab at 0x7f640200de10>,
#  u'disableSelector': <gensim.models.word2vec.Vocab at 0x7f640200d1d0>,
#  u'maxBytes': <gensim.models.word2vec.Vocab at 0x7f6421f21810>,
#  u'startTimer': <gensim.models.word2vec.Vocab at 0x7f640ba31b10>,
#  u'MemberExpression': <gensim.models.word2vec.Vocab at 0x7f63fff6b1d0>,
#  u'pointLabelFontStyle': <gensim.models.word2vec.Vocab at 0x7f63fe8271d0>,
#  u'r1': <gensim.models.word2vec.Vocab at 0x7f63ff2d0950>,
#  u'r2': <gensim.models.word2vec.Vocab at 0x7f63ff2d0710>,
#  u'toggler': <gensim.models.word2vec.Vocab at 0x7f640bce9090>,
#  u'isBorderBox': <gensim.models.word2vec.Vocab at 0x7f64025adb90>,
#  u'_saveProfile': <gensim.models.word2vec.Vocab at 0x7f6401751650>,
#  u'participantImages': <gensim.models.word2vec.Vocab at 0x7f641ebe23d0>,
#  u'_notForMeFade': <gensim.models.word2vec.Vocab at 0x7f63ff2d0d50>,
#  u'ath': <gensim.models.word2vec.Vocab at 0x7f640076e190>,
#  u'_isInIncomingCall': <gensim.models.word2vec.Vocab at 0x7f63fa468150>,
#  u'att': <gensim.models.word2vec.Vocab at 0x7f640076e290>,
#  u'_model_ob': <gensim.models.word2vec.Vocab at 0x7f640076e2d0>,
#  u'speedy': <gensim.models.word2vec.Vocab at 0x7f63ff2d0f90>,
#  u'speedx': <gensim.models.word2vec.Vocab at 0x7f63ff2d0a50>,
#  u'gridSize_': <gensim.models.word2vec.Vocab at 0x7f640200ded0>,
#  u'pagerType': <gensim.models.word2vec.Vocab at 0x7f640076e650>,
#  u'timeZone': <gensim.models.word2vec.Vocab at 0x7f640200de50>,
#  u'setLoadedNode': <gensim.models.word2vec.Vocab at 0x7f640076e690>,
#  u'Bg': <gensim.models.word2vec.Vocab at 0x7f63f8bdded0>,
#  u'$body': <gensim.models.word2vec.Vocab at 0x7f640200d490>,
#  u'lastToken': <gensim.models.word2vec.Vocab at 0x7f6401c38090>,
#  u'nextUrl': <gensim.models.word2vec.Vocab at 0x7f63ff2d0c10>,
#  u'trillion': <gensim.models.word2vec.Vocab at 0x7f641ef6db10>,
#  u'mdown': <gensim.models.word2vec.Vocab at 0x7f640076e250>,
#  u'$toggle_button': <gensim.models.word2vec.Vocab at 0x7f63fbc39b90>,
#  u'subscriber_count': <gensim.models.word2vec.Vocab at 0x7f640076e790>,
#  u'errorClass': <gensim.models.word2vec.Vocab at 0x7f640200da10>,
#  u'your_user_group_regex': <gensim.models.word2vec.Vocab at 0x7f641e9bf090>,
#  u'removeFileSharesAndMentions': <gensim.models.word2vec.Vocab at 0x7f640b781390>,
#  u'scriptSrc': <gensim.models.word2vec.Vocab at 0x7f63fef88390>,
#  u'globalAdSurvey': <gensim.models.word2vec.Vocab at 0x7f64007e5210>,
#  u'pressedClass': <gensim.models.word2vec.Vocab at 0x7f63ff2d0810>,
#  u'channels': <gensim.models.word2vec.Vocab at 0x7f63ff2d0fd0>,
#  u'_start_request': <gensim.models.word2vec.Vocab at 0x7f640a593f90>,
#  u'TypePoint': <gensim.models.word2vec.Vocab at 0x7f63ff304990>,
#  u'pagerTemplate': <gensim.models.word2vec.Vocab at 0x7f63ff304f90>,
#  u'getCachedCenter': <gensim.models.word2vec.Vocab at 0x7f640076ebd0>,
#  u'channels_to_join': <gensim.models.word2vec.Vocab at 0x7f640200d150>,
#  u'xtn2': <gensim.models.word2vec.Vocab at 0x7f640076e410>,
#  u'force': <gensim.models.word2vec.Vocab at 0x7f63f89f74d0>,
#  u'menufocus': <gensim.models.word2vec.Vocab at 0x7f63fdc4be50>,
#  u'cssShow': <gensim.models.word2vec.Vocab at 0x7f6402bcb690>,
#  u'_processChildContext': <gensim.models.word2vec.Vocab at 0x7f64042b6590>,
#  u'setBulletText': <gensim.models.word2vec.Vocab at 0x7f640200d110>,
#  u'$registerBtn': <gensim.models.word2vec.Vocab at 0x7f64012c9f90>,
#  u'topicsQuery': <gensim.models.word2vec.Vocab at 0x7f641f55ed90>,
#  u'access_binary': <gensim.models.word2vec.Vocab at 0x7f640200d090>,
#  u'ngPattern': <gensim.models.word2vec.Vocab at 0x7f63fa2391d0>,
#  u'_scrollbarNodes': <gensim.models.word2vec.Vocab at 0x7f63ff304e90>,
#  u'service': <gensim.models.word2vec.Vocab at 0x7f6406fea290>,
#  u'makeMSRDomId': <gensim.models.word2vec.Vocab at 0x7f6406fea690>,
#  u'udpController': <gensim.models.word2vec.Vocab at 0x7f63fdc4b310>,
#  u'lastWordIndex': <gensim.models.word2vec.Vocab at 0x7f6406fea990>,
#  u'trackData': <gensim.models.word2vec.Vocab at 0x7f63ff3043d0>,
#  u'nextSequenceNumber': <gensim.models.word2vec.Vocab at 0x7f63fdc4b110>,
#  u'should_show_dropbox': <gensim.models.word2vec.Vocab at 0x7f63fdc4b350>,
#  u'thread_ids': <gensim.models.word2vec.Vocab at 0x7f64001050d0>,
#  u'JWPLAYER_FULLSCREEN': <gensim.models.word2vec.Vocab at 0x7f641f55e510>,
#  u'moveRoot': <gensim.models.word2vec.Vocab at 0x7f6400105ed0>,
#  u'useNative': <gensim.models.word2vec.Vocab at 0x7f640379b050>,
#  u'addUserKey': <gensim.models.word2vec.Vocab at 0x7f64083e3d90>,
#  u'CLICK': <gensim.models.word2vec.Vocab at 0x7f63fdc4b390>,
#  u'listen': <gensim.models.word2vec.Vocab at 0x7f63fdc4b690>,
#  u'aspectRatio_': <gensim.models.word2vec.Vocab at 0x7f63fdc4b790>,
#  u'disableFormElements': <gensim.models.word2vec.Vocab at 0x7f6400105750>,
#  u'extentRectangle': <gensim.models.word2vec.Vocab at 0x7f63ff3b7310>,
#  u'HOT_LIKE_MEDIUM_STICKER_ID': <gensim.models.word2vec.Vocab at 0x7f6400105710>,
#  u'moreMenuNavItem': <gensim.models.word2vec.Vocab at 0x7f63fec06dd0>,
#  u'VOTE_POST': <gensim.models.word2vec.Vocab at 0x7f63fdc4bd50>,
#  u'slideWindowSelector': <gensim.models.word2vec.Vocab at 0x7f63fdc4b450>,
#  u'_makeDraggable': <gensim.models.word2vec.Vocab at 0x7f63ff304190>,
#  u'eElem': <gensim.models.word2vec.Vocab at 0x7f63ff3045d0>,
#  u'dummyDiv': <gensim.models.word2vec.Vocab at 0x7f6404a6b8d0>,
#  u'email_regex': <gensim.models.word2vec.Vocab at 0x7f63fdb54590>,
#  u'slideOffset': <gensim.models.word2vec.Vocab at 0x7f6400105d90>,
#  u'timeOut': <gensim.models.word2vec.Vocab at 0x7f6400105250>,
#  u'_propLookup': <gensim.models.word2vec.Vocab at 0x7f641ef6d210>,
#  u'handleMsg': <gensim.models.word2vec.Vocab at 0x7f6402d694d0>,
#  u'ParameterName': <gensim.models.word2vec.Vocab at 0x7f64001058d0>,
#  u'_byCid': <gensim.models.word2vec.Vocab at 0x7f640bce9410>,
#  u'xOffset': <gensim.models.word2vec.Vocab at 0x7f641a9f8d50>,
#  u'trackLink': <gensim.models.word2vec.Vocab at 0x7f63fdc4be10>,
#  u'Code': <gensim.models.word2vec.Vocab at 0x7f63feed6e10>,
#  u'SPAN': <gensim.models.word2vec.Vocab at 0x7f64060b5610>,
#  u'SPAM': <gensim.models.word2vec.Vocab at 0x7f64001055d0>,
#  u'overBottom': <gensim.models.word2vec.Vocab at 0x7f63fee213d0>,
#  u'ampm': <gensim.models.word2vec.Vocab at 0x7f63fbc01050>,
#  u'tree': <gensim.models.word2vec.Vocab at 0x7f63ff304490>,
#  u'_storedCSS': <gensim.models.word2vec.Vocab at 0x7f63ff304090>,
#  u'all_members': <gensim.models.word2vec.Vocab at 0x7f6400105bd0>,
#  u'_fireMouseEvent': <gensim.models.word2vec.Vocab at 0x7f63fdc4b510>,
#  u'idle': <gensim.models.word2vec.Vocab at 0x7f6402153dd0>,
#  u'crossOriginKeyword': <gensim.models.word2vec.Vocab at 0x7f6402d69f90>,
#  u'switched_sig': <gensim.models.word2vec.Vocab at 0x7f63ff3049d0>,
#  u'_display_name': <gensim.models.word2vec.Vocab at 0x7f64001057d0>,
#  u'pagerLabel': <gensim.models.word2vec.Vocab at 0x7f63fee21990>,
#  u'derived': <gensim.models.word2vec.Vocab at 0x7f63f900efd0>,
#  u'deal_ids': <gensim.models.word2vec.Vocab at 0x7f6400105210>,
#  u'llbbox': <gensim.models.word2vec.Vocab at 0x7f63ff304050>,
#  u'mimeType': <gensim.models.word2vec.Vocab at 0x7f6402d69850>,
#  u'addFPI': <gensim.models.word2vec.Vocab at 0x7f63fdc4bb10>,
#  u'_update': <gensim.models.word2vec.Vocab at 0x7f6402d696d0>,
#  u'objects': <gensim.models.word2vec.Vocab at 0x7f6407fc8ad0>,
#  u'curCSSTop': <gensim.models.word2vec.Vocab at 0x7f641ef6d6d0>,
#  u'target_name': <gensim.models.word2vec.Vocab at 0x7f64021539d0>,
#  u'pauseVideo': <gensim.models.word2vec.Vocab at 0x7f63fdc4b150>,
#  u'$MercuryDeliveryState6': <gensim.models.word2vec.Vocab at 0x7f63fecd21d0>,
#  u'readFormat': <gensim.models.word2vec.Vocab at 0x7f63ff4a3d50>,
#  u'$MercuryDeliveryState1': <gensim.models.word2vec.Vocab at 0x7f63fecd24d0>,
#  u'utftext': <gensim.models.word2vec.Vocab at 0x7f641aa4c890>,
#  u'isReplacement': <gensim.models.word2vec.Vocab at 0x7f6400105b10>,
#  u'updateQuantity': <gensim.models.word2vec.Vocab at 0x7f63ff304110>,
#  u'msg_ids': <gensim.models.word2vec.Vocab at 0x7f6400105610>,
#  u'onInsert': <gensim.models.word2vec.Vocab at 0x7f63ff304410>,
#  u'outputFormat': <gensim.models.word2vec.Vocab at 0x7f6400891890>,
#  u'increment': <gensim.models.word2vec.Vocab at 0x7f64001059d0>,
#  u'marginRight': <gensim.models.word2vec.Vocab at 0x7f63ff3041d0>,
#  u'aisdef': <gensim.models.word2vec.Vocab at 0x7f63fe717510>,
#  u'primary_matches': <gensim.models.word2vec.Vocab at 0x7f63ff3040d0>,
#  u'addFPV': <gensim.models.word2vec.Vocab at 0x7f63fadf7810>,
#  u'_updateAlternate': <gensim.models.word2vec.Vocab at 0x7f64001051d0>,
#  u'image_192': <gensim.models.word2vec.Vocab at 0x7f6402d69c10>,
#  u'NUMPAD_SUBTRACT': <gensim.models.word2vec.Vocab at 0x7f6401a4bdd0>,
#  u'bJmpMod': <gensim.models.word2vec.Vocab at 0x7f6400105650>,
#  u'_process': <gensim.models.word2vec.Vocab at 0x7f6401640750>,
#  u'SearchButton': <gensim.models.word2vec.Vocab at 0x7f63fdc4b5d0>,
#  u'rubicontag': <gensim.models.word2vec.Vocab at 0x7f64001a98d0>,
#  u'clearMarks': <gensim.models.word2vec.Vocab at 0x7f63ff2d0e90>,
#  u'disallow_public_file_urls': <gensim.models.word2vec.Vocab at 0x7f63f873c6d0>,
#  u'reliableMarginLeft': <gensim.models.word2vec.Vocab at 0x7f6402d69590>,
#  u'Component': <gensim.models.word2vec.Vocab at 0x7f6400105fd0>,
#  u'phase': <gensim.models.word2vec.Vocab at 0x7f63f94f07d0>,
#  u'getResult': <gensim.models.word2vec.Vocab at 0x7f6400105c90>,
#  u'$scrollableElement': <gensim.models.word2vec.Vocab at 0x7f6400105d10>,
#  u'retainPath': <gensim.models.word2vec.Vocab at 0x7f64083e3110>,
#  u'raLabel': <gensim.models.word2vec.Vocab at 0x7f63f9280350>,
#  u'refreshStatus': <gensim.models.word2vec.Vocab at 0x7f6400105910>,
#  u'clientSpan': <gensim.models.word2vec.Vocab at 0x7f6402d69910>,
#  u'lonlat': <gensim.models.word2vec.Vocab at 0x7f6400105cd0>,
#  u'domCreateElement': <gensim.models.word2vec.Vocab at 0x7f641f55ec10>,
#  u'scheduleNext': <gensim.models.word2vec.Vocab at 0x7f641f43ecd0>,
#  u'tab_id': <gensim.models.word2vec.Vocab at 0x7f6407f36fd0>,
#  u'appendChildren': <gensim.models.word2vec.Vocab at 0x7f63ff304150>,
#  u'uxConfig': <gensim.models.word2vec.Vocab at 0x7f63fdd66a10>,
#  u'even': <gensim.models.word2vec.Vocab at 0x7f63f89f7850>,
#  u'a_name': <gensim.models.word2vec.Vocab at 0x7f63fff02e10>,
#  u'google_dre': <gensim.models.word2vec.Vocab at 0x7f63ff3046d0>,
#  u'Topics': <gensim.models.word2vec.Vocab at 0x7f64151dd610>,
#  u'filterToParams': <gensim.models.word2vec.Vocab at 0x7f6408e50f50>,
#  u'object': <gensim.models.word2vec.Vocab at 0x7f6408e50f90>,
#  u'oIfrm': <gensim.models.word2vec.Vocab at 0x7f63ff304650>,
#  u'debugAll': <gensim.models.word2vec.Vocab at 0x7f6401896d10>,
#  u'metrics': <gensim.models.word2vec.Vocab at 0x7f6400105e50>,
#  u'y': <gensim.models.word2vec.Vocab at 0x7f63fdd66d50>,
#  u'_marshaller': <gensim.models.word2vec.Vocab at 0x7f63fbe3f290>,
#  u'txtLength': <gensim.models.word2vec.Vocab at 0x7f6400105d50>,
#  u'letter': <gensim.models.word2vec.Vocab at 0x7f63fdc4ba50>,
#  u'breakpoint': <gensim.models.word2vec.Vocab at 0x7f63fdc4b490>,
#  u'handleBuildingQuery': <gensim.models.word2vec.Vocab at 0x7f6404bb0690>,
#  u'Login': <gensim.models.word2vec.Vocab at 0x7f6404bb0a90>,
#  u'autoUpdateInterval': <gensim.models.word2vec.Vocab at 0x7f640941ff90>,
#  u'keyA': <gensim.models.word2vec.Vocab at 0x7f63fe97c090>,
#  u'orderDayAsFirstDay': <gensim.models.word2vec.Vocab at 0x7f6408e507d0>,
#  u'dummy': <gensim.models.word2vec.Vocab at 0x7f63ff304ed0>,
#  u'numberWithCommas': <gensim.models.word2vec.Vocab at 0x7f6401b4d590>,
#  u'_min_value': <gensim.models.word2vec.Vocab at 0x7f63ff304b50>,
#  u'onItemFinish': <gensim.models.word2vec.Vocab at 0x7f641e88ee90>,
#  u'targetTagName': <gensim.models.word2vec.Vocab at 0x7f6404bb0290>,
#  u'vertices': <gensim.models.word2vec.Vocab at 0x7f640051c450>,
#  u'blurHandler': <gensim.models.word2vec.Vocab at 0x7f640051c250>,
#  u'_createIcons': <gensim.models.word2vec.Vocab at 0x7f6408e50810>,
#  u'tech': <gensim.models.word2vec.Vocab at 0x7f640051c050>,
#  u'jpLog': <gensim.models.word2vec.Vocab at 0x7f6402d62a50>,
#  u'getListeners': <gensim.models.word2vec.Vocab at 0x7f63f9280890>,
#  u'pagerActiveClass': <gensim.models.word2vec.Vocab at 0x7f63fec56790>,
#  u'WKT': <gensim.models.word2vec.Vocab at 0x7f6408e50890>,
#  u'getPort': <gensim.models.word2vec.Vocab at 0x7f641ebe2610>,
#  u'__debug': <gensim.models.word2vec.Vocab at 0x7f63fbf5aed0>,
#  u'pagePosition': <gensim.models.word2vec.Vocab at 0x7f6408e508d0>,
#  u'_isWatermarked': <gensim.models.word2vec.Vocab at 0x7f63f8332550>,
#  u'team_list_items': <gensim.models.word2vec.Vocab at 0x7f63ff304c90>,
#  u'getNow': <gensim.models.word2vec.Vocab at 0x7f6408e50990>,
#  u'fixHook': <gensim.models.word2vec.Vocab at 0x7f640051cfd0>,
#  u'resultNa': <gensim.models.word2vec.Vocab at 0x7f63ff304790>,
#  u'overlapLeft': <gensim.models.word2vec.Vocab at 0x7f6404bb0790>,
#  u'uaMatch': <gensim.models.word2vec.Vocab at 0x7f6404bb0810>,
#  u'aeon_mask': <gensim.models.word2vec.Vocab at 0x7f63f975d850>,
#  u'padded': <gensim.models.word2vec.Vocab at 0x7f640051ce50>,
#  u'x2': <gensim.models.word2vec.Vocab at 0x7f63fe717090>,
#  u'canMemberJoinChannel': <gensim.models.word2vec.Vocab at 0x7f6401069e90>,
#  u'widthStaticPopovers': <gensim.models.word2vec.Vocab at 0x7f63fbc010d0>,
#  u'volumeBar': <gensim.models.word2vec.Vocab at 0x7f63fec56510>,
#  u'BEHAVIOR_STATE': <gensim.models.word2vec.Vocab at 0x7f63f89f7950>,
#  u'Template': <gensim.models.word2vec.Vocab at 0x7f640051c550>,
#  u'transition3d': <gensim.models.word2vec.Vocab at 0x7f63ff304d50>,
#  u'currentSrc': <gensim.models.word2vec.Vocab at 0x7f63ff304e10>,
#  u'can_invite_by_link': <gensim.models.word2vec.Vocab at 0x7f63ff304b10>,
#  u'prevObject': <gensim.models.word2vec.Vocab at 0x7f63ff304750>,
#  u'_trackingInstances': <gensim.models.word2vec.Vocab at 0x7f63fe303310>,
#  u'c_m_id': <gensim.models.word2vec.Vocab at 0x7f63fec56410>,
#  u'adResponse': <gensim.models.word2vec.Vocab at 0x7f63ff4a3b90>,
#  u'touches': <gensim.models.word2vec.Vocab at 0x7f64091aea90>,
#  u'requestIdleCallback': <gensim.models.word2vec.Vocab at 0x7f6404bb0b90>,
#  u'clicked': <gensim.models.word2vec.Vocab at 0x7f640051c4d0>,
#  u'inputView': <gensim.models.word2vec.Vocab at 0x7f6404bb0510>,
#  u'allowscriptaccess': <gensim.models.word2vec.Vocab at 0x7f63ff4a3dd0>,
#  u'headline': <gensim.models.word2vec.Vocab at 0x7f63ff304250>,
#  u'menu': <gensim.models.word2vec.Vocab at 0x7f6404bb08d0>,
#  u'readyQueue_': <gensim.models.word2vec.Vocab at 0x7f6404bb0450>,
#  u'_nDataBytes': <gensim.models.word2vec.Vocab at 0x7f63ff304310>,
#  u'beforeMove': <gensim.models.word2vec.Vocab at 0x7f63fb7c7f50>,
#  u'CLIENT_SEND_MESSAGE': <gensim.models.word2vec.Vocab at 0x7f64091ae5d0>,
#  u'Translator': <gensim.models.word2vec.Vocab at 0x7f63fecf7d50>,
#  u'overTop': <gensim.models.word2vec.Vocab at 0x7f63fdb54210>,
#  u'LIVE': <gensim.models.word2vec.Vocab at 0x7f640051c090>,
#  u'FILTERS': <gensim.models.word2vec.Vocab at 0x7f63ff304e50>,
#  u'NREUM': <gensim.models.word2vec.Vocab at 0x7f6403a25c90>,
#  u'setDataSubmitted': <gensim.models.word2vec.Vocab at 0x7f6403128550>,
#  u'_hideunity_savedstyle': <gensim.models.word2vec.Vocab at 0x7f640ba313d0>,
#  u'last_search_query': <gensim.models.word2vec.Vocab at 0x7f63fb75a850>,
#  u'addRange': <gensim.models.word2vec.Vocab at 0x7f6405bc0410>,
#  u'playbtn': <gensim.models.word2vec.Vocab at 0x7f63ff645150>,
#  u'reportUserActivity': <gensim.models.word2vec.Vocab at 0x7f63ff258750>,
#  u'parseResponse': <gensim.models.word2vec.Vocab at 0x7f640051cb50>,
#  u'_popoverMenu': <gensim.models.word2vec.Vocab at 0x7f63ff3b71d0>,
#  u'_block': <gensim.models.word2vec.Vocab at 0x7f63fe303f10>,
#  u'ceil': <gensim.models.word2vec.Vocab at 0x7f640051c1d0>,
#  u'hideTitleOnSmallScreen': <gensim.models.word2vec.Vocab at 0x7f63ff3b7150>,
#  u'mention': <gensim.models.word2vec.Vocab at 0x7f641ab7a550>,
#  u'dhis': <gensim.models.word2vec.Vocab at 0x7f6403a25750>,
#  u'X': <gensim.models.word2vec.Vocab at 0x7f64091ae310>,
# ...
#  u'getZoom': <gensim.models.word2vec.Vocab at 0x7f6406f7a4d0>,
#  u'resolveContexts': <gensim.models.word2vec.Vocab at 0x7f63ff3b7650>,
#  u'radius': <gensim.models.word2vec.Vocab at 0x7f63ff3b7590>,
#  u'error_count': <gensim.models.word2vec.Vocab at 0x7f64033e5c50>,
#  u'disableInteraction': <gensim.models.word2vec.Vocab at 0x7f640c607a90>,
#  u'_TLD_TYPO': <gensim.models.word2vec.Vocab at 0x7f6406f7a610>,
#  u'fail': <gensim.models.word2vec.Vocab at 0x7f6406f7a990>,
#  u'per_page': <gensim.models.word2vec.Vocab at 0x7f63ff3b7290>,
#  u'isMap': <gensim.models.word2vec.Vocab at 0x7f641e88e050>,
#  u'getButton': <gensim.models.word2vec.Vocab at 0x7f64033e5850>,
#  u'mountComponent': <gensim.models.word2vec.Vocab at 0x7f64033e50d0>,
#  u'STARTED': <gensim.models.word2vec.Vocab at 0x7f6406411290>,
#  u'mime_types': <gensim.models.word2vec.Vocab at 0x7f641aa4c7d0>,
#  u'size_id': <gensim.models.word2vec.Vocab at 0x7f64033e5bd0>,
#  u'isIgnored': <gensim.models.word2vec.Vocab at 0x7f640204efd0>,
#  u'freeze': <gensim.models.word2vec.Vocab at 0x7f63fc019810>,
#  u'locationHref': <gensim.models.word2vec.Vocab at 0x7f640ba31650>,
#  u'hoverIntent': <gensim.models.word2vec.Vocab at 0x7f6415144810>,
#  u'helpMeFindModelNumber': <gensim.models.word2vec.Vocab at 0x7f640570d510>,
#  u'activePopoverButtonId': <gensim.models.word2vec.Vocab at 0x7f6402bcb190>,
#  u'RecruitCandidateMultipleFileView': <gensim.models.word2vec.Vocab at 0x7f640204e0d0>,
#  u'$ReactPopoverMenu3': <gensim.models.word2vec.Vocab at 0x7f63feb1c910>,
#  u'score': <gensim.models.word2vec.Vocab at 0x7f6406411590>,
#  u'pName': <gensim.models.word2vec.Vocab at 0x7f64033e5310>,
#  u'backingMap': <gensim.models.word2vec.Vocab at 0x7f63fe3e7e10>,
#  u'Fp': <gensim.models.word2vec.Vocab at 0x7f641b07cd10>,
#  u'cookieBaseUrl': <gensim.models.word2vec.Vocab at 0x7f64007e57d0>,
#  u'subarray': <gensim.models.word2vec.Vocab at 0x7f64033e5f10>,
#  u'_transTime': <gensim.models.word2vec.Vocab at 0x7f64033e5ed0>,
#  u'jobIds': <gensim.models.word2vec.Vocab at 0x7f641f43e310>,
#  u'boundry': <gensim.models.word2vec.Vocab at 0x7f63ff3b7550>,
#  u'isspatial': <gensim.models.word2vec.Vocab at 0x7f64033e5d50>,
#  u'$ULs': <gensim.models.word2vec.Vocab at 0x7f6406411490>,
#  u'castleIndex': <gensim.models.word2vec.Vocab at 0x7f63ff3b7810>,
#  u'$MessengerAdsWebTypedLogger1': <gensim.models.word2vec.Vocab at 0x7f640a391850>,
#  u'extend': <gensim.models.word2vec.Vocab at 0x7f640a3913d0>,
#  u'_el': <gensim.models.word2vec.Vocab at 0x7f6406411fd0>,
#  u'linkURL': <gensim.models.word2vec.Vocab at 0x7f63fbf94d90>,
#  u'hitCallback': <gensim.models.word2vec.Vocab at 0x7f64095f9a10>,
#  u'__sendRequest': <gensim.models.word2vec.Vocab at 0x7f64095f9b90>,
#  u'deepReplaceKeyName': <gensim.models.word2vec.Vocab at 0x7f63fea6e210>,
#  u'pConfig': <gensim.models.word2vec.Vocab at 0x7f640a391410>,
#  u'subopened': <gensim.models.word2vec.Vocab at 0x7f63ff3b7850>,
#  u'white': <gensim.models.word2vec.Vocab at 0x7f641ef6de50>,
#  u'mediaSuggestions': <gensim.models.word2vec.Vocab at 0x7f641aa4c710>,
#  u'animTime': <gensim.models.word2vec.Vocab at 0x7f63fb66f810>,
#  u'fileSize': <gensim.models.word2vec.Vocab at 0x7f63ff3b70d0>,
#  u'extent': <gensim.models.word2vec.Vocab at 0x7f640a3912d0>,
#  u'onImpressionResult': <gensim.models.word2vec.Vocab at 0x7f64049e0c90>,
#  u'_eq': <gensim.models.word2vec.Vocab at 0x7f6406411990>,
#  u'loopSlides': <gensim.models.word2vec.Vocab at 0x7f63fa2f6f50>,
#  u'_contexts': <gensim.models.word2vec.Vocab at 0x7f63ffe7dc50>,
#  u'_et': <gensim.models.word2vec.Vocab at 0x7f640c9b91d0>,
#  u'updateRequestedRange': <gensim.models.word2vec.Vocab at 0x7f63fb66fcd0>,
#  u'facetId': <gensim.models.word2vec.Vocab at 0x7f63ff3b7a10>,
#  u'other_enterprise_accounts': <gensim.models.word2vec.Vocab at 0x7f640c9b90d0>,
#  u'onSubmit': <gensim.models.word2vec.Vocab at 0x7f640c9b98d0>,
#  u'internalns': <gensim.models.word2vec.Vocab at 0x7f63ffe7d6d0>,
#  u'pinned_item': <gensim.models.word2vec.Vocab at 0x7f63f91857d0>,
#  u'triggers': <gensim.models.word2vec.Vocab at 0x7f63febd2150>,
#  u'country': <gensim.models.word2vec.Vocab at 0x7f63ff3b7bd0>,
#  u'adapter': <gensim.models.word2vec.Vocab at 0x7f640698e090>,
#  u'volumeSliderRail': <gensim.models.word2vec.Vocab at 0x7f63ff3b77d0>,
#  u'mediaItem': <gensim.models.word2vec.Vocab at 0x7f63ffe7d7d0>,
#  u'is_separator': <gensim.models.word2vec.Vocab at 0x7f63ff3b76d0>,
#  u'inputProps': <gensim.models.word2vec.Vocab at 0x7f63ffe7dad0>,
#  u'dragStart': <gensim.models.word2vec.Vocab at 0x7f63ff3b7b50>,
#  u'login': <gensim.models.word2vec.Vocab at 0x7f63ff3b73d0>,
#  u'browser': <gensim.models.word2vec.Vocab at 0x7f63fe717690>,
#  u'automaticallyCreateComponentsInside': <gensim.models.word2vec.Vocab at 0x7f63ffe7d550>,
#  u'$totalPriceDiv': <gensim.models.word2vec.Vocab at 0x7f63fb625b10>,
#  u'UFIActionType': <gensim.models.word2vec.Vocab at 0x7f63ff3b78d0>,
#  u'alternate': <gensim.models.word2vec.Vocab at 0x7f63ff3b7cd0>,
#  u'share_info_channel': <gensim.models.word2vec.Vocab at 0x7f6408d42990>,
#  u'measureColumns': <gensim.models.word2vec.Vocab at 0x7f63ff3b7e50>,
#  u'getResponsiveColumnClass': <gensim.models.word2vec.Vocab at 0x7f63fea554d0>,
#  u'menuWidth': <gensim.models.word2vec.Vocab at 0x7f6408d420d0>,
#  u'makeUnshareLink': <gensim.models.word2vec.Vocab at 0x7f63ff3b7c10>,
#  u'analytics50': <gensim.models.word2vec.Vocab at 0x7f63ff3b7fd0>,
#  u'moderationInfo': <gensim.models.word2vec.Vocab at 0x7f63fe717810>,
#  u'isConnected': <gensim.models.word2vec.Vocab at 0x7f63ff3b7b90>,
#  u'muted_channels': <gensim.models.word2vec.Vocab at 0x7f63fee21610>,
#  u'active': <gensim.models.word2vec.Vocab at 0x7f63f89f7ad0>,
#  u'autoPlaying': <gensim.models.word2vec.Vocab at 0x7f63ff3b7c50>,
#  u'$sbi_photo': <gensim.models.word2vec.Vocab at 0x7f63ff3b7f10>,
#  u'bEnableAutomaticUpdate': <gensim.models.word2vec.Vocab at 0x7f63ff3e6690>,
#  u'getPos': <gensim.models.word2vec.Vocab at 0x7f64012865d0>,
#  u'generatePagination': <gensim.models.word2vec.Vocab at 0x7f640698e890>,
#  u'diff': <gensim.models.word2vec.Vocab at 0x7f6408d42b90>,
#  u'hideElement': <gensim.models.word2vec.Vocab at 0x7f6414a1d190>,
#  u'iterable': <gensim.models.word2vec.Vocab at 0x7f63ff3b7d50>,
#  u'$EventHolder2': <gensim.models.word2vec.Vocab at 0x7f641ab2cf90>,
#  u'signals': <gensim.models.word2vec.Vocab at 0x7f6401b4d1d0>,
#  u'show_privacy': <gensim.models.word2vec.Vocab at 0x7f64166a7590>,
#  u'isHighlightedUser': <gensim.models.word2vec.Vocab at 0x7f63ffe7ded0>,
#  u'_latest_via_users_counts': <gensim.models.word2vec.Vocab at 0x7f63f8847450>,
#  u'withUserActions': <gensim.models.word2vec.Vocab at 0x7f6401c382d0>,
#  u'member_type_dropdown_instance': <gensim.models.word2vec.Vocab at 0x7f6408d423d0>,
#  u'updateAllStates': <gensim.models.word2vec.Vocab at 0x7f63ffe7d210>,
#  u'union': <gensim.models.word2vec.Vocab at 0x7f63ffe7d590>,
#  u'errorTypes': <gensim.models.word2vec.Vocab at 0x7f63f8d13190>,
#  u'_Exception2': <gensim.models.word2vec.Vocab at 0x7f641e88e450>,
#  u'eventReport': <gensim.models.word2vec.Vocab at 0x7f640698e9d0>,
#  u'frm': <gensim.models.word2vec.Vocab at 0x7f63ffe7d390>,
#  u'numRows': <gensim.models.word2vec.Vocab at 0x7f63ffe7dd50>,
#  u'publicotonHost': <gensim.models.word2vec.Vocab at 0x7f63ff3b7ed0>,
#  u'maxIdentifyId': <gensim.models.word2vec.Vocab at 0x7f63fb9b0e90>,
#  u'maxDate': <gensim.models.word2vec.Vocab at 0x7f63fe3e7110>,
#  u'userToken': <gensim.models.word2vec.Vocab at 0x7f640698e0d0>,
#  u'$EventHolder1': <gensim.models.word2vec.Vocab at 0x7f63ff3b7710>,
#  u'checkoutStarted': <gensim.models.word2vec.Vocab at 0x7f63fbacc910>,
#  u'dots': <gensim.models.word2vec.Vocab at 0x7f63ff3b7e10>,
#  u'storageKey': <gensim.models.word2vec.Vocab at 0x7f63ffe7d2d0>,
#  u'isAutoRefresh': <gensim.models.word2vec.Vocab at 0x7f63ff3b7a50>,
#  u'msg_dom': <gensim.models.word2vec.Vocab at 0x7f63fb5e1990>,
#  u'_rxns': <gensim.models.word2vec.Vocab at 0x7f64016ca990>,
#  u'$div': <gensim.models.word2vec.Vocab at 0x7f63ffe7d610>,
#  u'isCursorAtEnd': <gensim.models.word2vec.Vocab at 0x7f63ffe7d290>,
#  u'currentScale': <gensim.models.word2vec.Vocab at 0x7f63fdb54050>,
#  u'worker': <gensim.models.word2vec.Vocab at 0x7f63ff0d1210>,
#  u'targetfbid': <gensim.models.word2vec.Vocab at 0x7f6408d42050>,
#  u'easeInCirc': <gensim.models.word2vec.Vocab at 0x7f6404555a10>,
#  u'animateScale': <gensim.models.word2vec.Vocab at 0x7f6404555350>,
#  u'endTimeout': <gensim.models.word2vec.Vocab at 0x7f6400736210>,
#  u'$pager': <gensim.models.word2vec.Vocab at 0x7f640928d510>,
#  u'num_new': <gensim.models.word2vec.Vocab at 0x7f63fefc6b50>,
#  u'spid': <gensim.models.word2vec.Vocab at 0x7f6404555c50>,
#  u'requestObject': <gensim.models.word2vec.Vocab at 0x7f63fab68d90>,
#  u'PlusOne': <gensim.models.word2vec.Vocab at 0x7f6408d424d0>,
#  u'enterprise_id': <gensim.models.word2vec.Vocab at 0x7f6404555890>,
#  u'cvPx': <gensim.models.word2vec.Vocab at 0x7f6400736510>,
#  u'spin': <gensim.models.word2vec.Vocab at 0x7f6404555550>,
#  u'viewContainerEl': <gensim.models.word2vec.Vocab at 0x7f64045559d0>,
#  u'$UFIToplevelStreamedCommentList1': <gensim.models.word2vec.Vocab at 0x7f63f8207190>,
#  u'startDelete': <gensim.models.word2vec.Vocab at 0x7f63fa2f6390>,
#  u'$UFIToplevelStreamedCommentList2': <gensim.models.word2vec.Vocab at 0x7f6404555fd0>,
#  u'DocumentTouch': <gensim.models.word2vec.Vocab at 0x7f6404555a50>,
#  u'googleplus': <gensim.models.word2vec.Vocab at 0x7f6400736110>,
#  u'_$all_user_groups': <gensim.models.word2vec.Vocab at 0x7f641ef6d590>,
#  u'wrapAll': <gensim.models.word2vec.Vocab at 0x7f63f9185250>,
#  u'sort_by': <gensim.models.word2vec.Vocab at 0x7f63fb5ab0d0>,
#  u'existing_rxns': <gensim.models.word2vec.Vocab at 0x7f6400736050>,
#  u'arrivalDate': <gensim.models.word2vec.Vocab at 0x7f64007e5250>,
#  u'emoji_menu_columns': <gensim.models.word2vec.Vocab at 0x7f63fbb0fcd0>,
#  u'preselected': <gensim.models.word2vec.Vocab at 0x7f63ff0d1110>,
#  u'currentClass': <gensim.models.word2vec.Vocab at 0x7f6400736690>,
#  u'$disabled_parent': <gensim.models.word2vec.Vocab at 0x7f63ff0d1390>,
#  u'callbackName': <gensim.models.word2vec.Vocab at 0x7f63ff0d1810>,
#  u'_set': <gensim.models.word2vec.Vocab at 0x7f63ff0d13d0>,
#  u'sliderWidth': <gensim.models.word2vec.Vocab at 0x7f63ffc799d0>,
#  u'_loaded': <gensim.models.word2vec.Vocab at 0x7f63ff0d1510>,
#  u'_setUser': <gensim.models.word2vec.Vocab at 0x7f63f8247090>,
#  u'edited_text': <gensim.models.word2vec.Vocab at 0x7f6400736390>,
#  u'$active_parent': <gensim.models.word2vec.Vocab at 0x7f63ffc792d0>,
#  u'instanceId': <gensim.models.word2vec.Vocab at 0x7f63ff0d10d0>,
#  u'getRxnFromRxns': <gensim.models.word2vec.Vocab at 0x7f63fe827210>,
#  u'Nav': <gensim.models.word2vec.Vocab at 0x7f63f873c150>,
#  u'BASIC': <gensim.models.word2vec.Vocab at 0x7f63f9185050>,
#  u'selectedGroups': <gensim.models.word2vec.Vocab at 0x7f6400736f90>,
#  u'pagerEvent': <gensim.models.word2vec.Vocab at 0x7f640aecdc50>,
#  u'show_create_shared_channel_btn': <gensim.models.word2vec.Vocab at 0x7f63f8c8ee90>,
#  u'yOrigin': <gensim.models.word2vec.Vocab at 0x7f6400736350>,
#  u'player': <gensim.models.word2vec.Vocab at 0x7f640928dd90>,
#  u'releaseRequests': <gensim.models.word2vec.Vocab at 0x7f6409b90990>,
#  u'useJSONP': <gensim.models.word2vec.Vocab at 0x7f6407927c90>,
#  u'adUnitWidth': <gensim.models.word2vec.Vocab at 0x7f63ff0d1ed0>,
#  u'toleranceElement': <gensim.models.word2vec.Vocab at 0x7f63fecd2450>,
#  u'selectmenuId': <gensim.models.word2vec.Vocab at 0x7f640928d250>,
#  u'mobileFirst': <gensim.models.word2vec.Vocab at 0x7f6409b90f90>,
#  u'tResolutions': <gensim.models.word2vec.Vocab at 0x7f64150f2bd0>,
#  u'tzo': <gensim.models.word2vec.Vocab at 0x7f63ff0d15d0>,
#  u'cycleTimeout': <gensim.models.word2vec.Vocab at 0x7f63ff0d16d0>,
#  u'feedbackTarget': <gensim.models.word2vec.Vocab at 0x7f6409b90510>,
#  u'SMILParser': <gensim.models.word2vec.Vocab at 0x7f63ff0d1ad0>,
#  u'_prevHighlighter': <gensim.models.word2vec.Vocab at 0x7f63ff0d1150>,
#  u'flushable': <gensim.models.word2vec.Vocab at 0x7f63ff0d1a50>,
#  u'BID_STATUS': <gensim.models.word2vec.Vocab at 0x7f6405024390>,
#  u'things': <gensim.models.word2vec.Vocab at 0x7f640928d550>,
#  u'namedItem': <gensim.models.word2vec.Vocab at 0x7f6405024490>,
#  u'_showPreEnd': <gensim.models.word2vec.Vocab at 0x7f6405024fd0>,
#  u'subscription': <gensim.models.word2vec.Vocab at 0x7f641b07c8d0>,
#  u'isSuccess': <gensim.models.word2vec.Vocab at 0x7f63ff0d1b10>,
#  u'_week': <gensim.models.word2vec.Vocab at 0x7f6405024710>,
#  u'isAnimating': <gensim.models.word2vec.Vocab at 0x7f63ff0d1990>,
#  u'getContainingTileCoords': <gensim.models.word2vec.Vocab at 0x7f63fb59c7d0>,
#  u'canCreateComment': <gensim.models.word2vec.Vocab at 0x7f63f8247190>,
#  u'_setOnCancel': <gensim.models.word2vec.Vocab at 0x7f640928d950>,
#  u'_lazy_clones': <gensim.models.word2vec.Vocab at 0x7f63ff0d1d90>,
#  u'GPSInfoIFDPointer': <gensim.models.word2vec.Vocab at 0x7f63fe5940d0>,
#  u'elqTRun': <gensim.models.word2vec.Vocab at 0x7f63ff0d14d0>,
#  u'promptText': <gensim.models.word2vec.Vocab at 0x7f63ffcb4c10>,
#  u'classname': <gensim.models.word2vec.Vocab at 0x7f6409330290>,
#  u'templates': <gensim.models.word2vec.Vocab at 0x7f640928d190>,
#  u'AjaxControlToolkit': <gensim.models.word2vec.Vocab at 0x7f640bd6c810>,
#  u'setAttr': <gensim.models.word2vec.Vocab at 0x7f6405024150>,
#  u'_getMeasurement': <gensim.models.word2vec.Vocab at 0x7f63fb59cdd0>,
#  u'Oc': <gensim.models.word2vec.Vocab at 0x7f6407f363d0>,
#  u'eventCategory': <gensim.models.word2vec.Vocab at 0x7f640bf5b190>,
#  u'moveParallax': <gensim.models.word2vec.Vocab at 0x7f63f90ceed0>,
#  u'caret_html': <gensim.models.word2vec.Vocab at 0x7f63fb59cc50>,
#  u'trackOffline': <gensim.models.word2vec.Vocab at 0x7f63ffbf8850>,
#  u'xmlDocument': <gensim.models.word2vec.Vocab at 0x7f63f8e026d0>,
#  u'_change': <gensim.models.word2vec.Vocab at 0x7f63ff0d1490>,
#  u'pluginObj': <gensim.models.word2vec.Vocab at 0x7f63ffbf8310>,
#  u'KT_focusedEl': <gensim.models.word2vec.Vocab at 0x7f640928df50>,
#  u'utm_source': <gensim.models.word2vec.Vocab at 0x7f63fbc01790>,
#  u'onClickCapture': <gensim.models.word2vec.Vocab at 0x7f63ffbf82d0>,
#  u'JWPLAYER_MEDIA_COMPLETE': <gensim.models.word2vec.Vocab at 0x7f63ff0d1fd0>,
#  u'tileCacheIndex': <gensim.models.word2vec.Vocab at 0x7f640bd6c450>,
#  u'onAfterCheck': <gensim.models.word2vec.Vocab at 0x7f63ffbf89d0>,
#  u'handleSuccess': <gensim.models.word2vec.Vocab at 0x7f6414b95dd0>,
#  u'viewPortDiv': <gensim.models.word2vec.Vocab at 0x7f640bd6c050>,
#  u'navItems': <gensim.models.word2vec.Vocab at 0x7f63fa9a91d0>,
#  u'maskAutoSize': <gensim.models.word2vec.Vocab at 0x7f640b8dd310>,
#  u'yOffset': <gensim.models.word2vec.Vocab at 0x7f64060b5290>,
#  u'gmlns': <gensim.models.word2vec.Vocab at 0x7f63fb4f2850>,
#  u'__dispatcher': <gensim.models.word2vec.Vocab at 0x7f64060b5550>,
#  u'hiddenStyle': <gensim.models.word2vec.Vocab at 0x7f63f9573c10>,
#  u'owlCarousel': <gensim.models.word2vec.Vocab at 0x7f63ff0d1c10>,
#  u'doScrollLeftBy': <gensim.models.word2vec.Vocab at 0x7f63ff0d1e50>,
#  u'eventLabel': <gensim.models.word2vec.Vocab at 0x7f63ffbf8910>,
#  u'processImsg': <gensim.models.word2vec.Vocab at 0x7f64060b5d90>,
#  u'hasFlash': <gensim.models.word2vec.Vocab at 0x7f640b8dd810>,
#  u'$Arbiter4': <gensim.models.word2vec.Vocab at 0x7f63fbe3fc10>,
#  u'latest_ts': <gensim.models.word2vec.Vocab at 0x7f640b8dd750>,
#  u'_result': <gensim.models.word2vec.Vocab at 0x7f63ffbf87d0>,
#  u'transitionManager': <gensim.models.word2vec.Vocab at 0x7f64060b51d0>,
#  u'hasFocus': <gensim.models.word2vec.Vocab at 0x7f640b8ddcd0>,
#  u'_scheduleAxisPosition': <gensim.models.word2vec.Vocab at 0x7f63ffbf8a10>,
#  u'tz_label': <gensim.models.word2vec.Vocab at 0x7f63fb54b610>,
#  u'emoji_use': <gensim.models.word2vec.Vocab at 0x7f63ff0d1d10>,
#  u'siteSection': <gensim.models.word2vec.Vocab at 0x7f63ffbf8550>,
#  u'_uid': <gensim.models.word2vec.Vocab at 0x7f6401570350>,
#  u'data_retention_changed_sig': <gensim.models.word2vec.Vocab at 0x7f63ffbf8d10>,
#  u'UniqueClass': <gensim.models.word2vec.Vocab at 0x7f6401570e10>,
#  u'file_belongs_to_user': <gensim.models.word2vec.Vocab at 0x7f63fb54be10>,
#  u'zoomStopHeight': <gensim.models.word2vec.Vocab at 0x7f63ff0d1f50>,
#  ...}

# %%
model.most_similar(positive=["jQuery"], negative="lodash")
# Out:
# [(u'allowed', 0.6279492974281311),
#  (u'$msg_input', 0.60919588804245),
#  (u'Unknown', 0.6089186668395996),
#  (u'focusMessageInput', 0.6046967506408691),
#  (u'eagerLoadAssets', 0.5932580828666687),
#  (u'is_our_app', 0.5896718502044678),
#  (u'_bindUI', 0.5884132981300354),
#  (u'LinearRing', 0.5816546678543091),
#  (u'activateADA', 0.5615449547767639),
#  (u'ABTest', 0.558937132358551)]

# %%
REPO_ROOT = "/usr/src/app"

# Display matplotlib plots in the output
# %matplotlib inline

# Support for running R code in the same notebook as Python (see below)
# %load_ext rpy2.ipython

import pandas as pd
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
table_df = pd.read_csv("%s/results/linear_models.csv" % REPO_ROOT)
# %Rpush table_df

# %%
# %%R -w 40 -h 25 -u cm
#
# library(ggplot2)
# ggplot(aes(x=Training.set, color=Model, y=Accuracy), data=table_df) +
#     geom_line() +
#     xlab("Training set size") +
#     ylim(c(0.5, 1)) +
#     ylab("Accuracy") +
#     facet_grid(~ Model.Type)
